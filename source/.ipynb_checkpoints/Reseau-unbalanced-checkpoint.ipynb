# %%
import tensorflow as tf
import re
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
import itertools
import pickle
import os
import time
from threading import Thread, Semaphore, RLock
from shutil import copyfile
from keras.metrics import top_k_categorical_accuracy
from keras.utils import plot_model
from scipy import stats
import keras.preprocessing as prepro
from sklearn.model_selection import train_test_split

from keras.models import load_model
from keras import backend as K
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
zf_dir_path="../resultat/zf/zf_geocoq/"
dep_dir_path="../resultat/dependencies/dependencies_geocoq/"


def get_rewrites_definitions(tarski_def_file_path) :
    rewrite = dict()

    tarski_def_file=open(tarski_def_file_path,"r")

    for line in tarski_def_file.readlines():
        if line.startswith('rewrite') :
            words=re.findall(r"[\w']+", line)
            for w in words :
                if w in types :
                    type_rew=w
                    break
            try:
                rewrite[type_rew]=line
            except:
                print(line)
                break
                
    tarski_def_file.close()
    return rewrite

def get_ax_th_definitions(all_th_file_path) :
    th_decl = dict()
    all_th_file=open(all_th_file_path,"r")
    
    lines = all_th_file.readlines()
    
    for i in range(len(lines)) :
        if lines[i].startswith("#") :
            name_size = len(lines[i])
            th_decl[lines[i][1:name_size-1]]=lines[i+1]
    return th_decl


def list_or_dict_to_json(list_or_dict,file_path):
    import json
    with open(file_path, 'w') as file:
        file.write(json.dumps(list_or_dict))
        
def json_to_list_or_dict(file_path):
    import json
    with open(file_path, 'r') as file:
        list_or_dict = json.loads(file.read())
    return list_or_dict


def write_ax_th_def(all_th_file_path,ax_th_declaration) :
    all_th_file=open(all_th_file_path,"w")
    
    for th in ax_th_declaration :
        all_th_file.write("#"+th+"\n")
        all_th_file.write(ax_th_declaration[th]+"\n")
        
    all_th_file.close()
    
    
def types_to_json(rew_type_file_path) :
    types=[]
    with open(rew_type_file_path,"r") as file :
        for line in file.readlines() :
            if line.startswith("val") :
                words = line.split(" ")
                types.append(words[1])
    return types

# %%
th_valid_geocoq=['cong_symmetry', 'cong_4321', 'cong_3421', 'cong_reflexivity', 'cong_transitivity', 'cong_left_commutativity', 'cong_4312', 'cong_trivial_identity', 'cong_right_commutativity', 'cong_commutativity', 'cong_reverse_identity', 'not_cong_2134', 'not_cong_1243', 'not_cong_3412', 'not_cong_4312', 'not_cong_4321', 'not_cong_2143', 'not_cong_3421', 'five_segment_with_def', 'cong_diff', 'cong_diff_2', 'cong_diff_3', 'cong_3_sym', 'cong_diff_4', 'cong_3_swap_2', 'cong3_transitivity', 'eq_dec_points', 'cong_3_swap', 'l2_11', 'bet_cong3', 'Cong_cases', 'Cong_perm', 'construction_uniqueness', 'bet_col', 'between_trivial', 'Bet_cases', 'between_symmetry', 'Bet_perm', 'between_trivial2', 'between_equality_2', 'between_equality', 'bet_neq12__neq', 'between_exchange3', 'bet_neq23__neq', 'bet_neq21__neq', 'bet_neq32__neq', 'not_bet_distincts', 'outer_transitivity_between2', 'between_inner_transitivity', 'outer_transitivity_between', 'between_exchange2', 'between_exchange4', 'l_3_9_4', 'lower_dim_ex', 'two_distinct_points', 'point_construction_different', 'cong_dec_eq_dec_b', 'another_point', 'bet_dec_eq_dec_b', 'l2_11_b', 'BetSEq', 'l3_17', 'col_permutation_1', 'col_permutation_3', 'col_permutation_2', 'col_permutation_4', 'not_col_permutation_1', 'col_permutation_5', 'not_col_permutation_2', 'not_col_permutation_4', 'not_col_permutation_3', 'not_col_permutation_5', 'Col_perm', 'Col_cases', 'col_trivial_2', 'col_trivial_3', 'l4_13', 'col_trivial_1', 'l4_17', 'l4_14', 'l4_18', 'NCol_cases', 'not_col_distincts', 'l4_19', 'NCol_perm', 'col_cong_3_cong_3_eq', 'l4_3', 'l4_3_1', 'cong3_bet_eq', 'le_bet', 'l5_5_1', 'l5_5_2', 'le_reflexivity', 'le_transitivity', 'cong3_symmetry', 'bet_dec', 'Cong_dec', 'Col_dec', 'le_diff', 'le_trivial', 'le_zero', 'cong__le3412', 'bet_cong_eq', 'le_left_comm', 'le1221', 'le_right_comm', 'le_comm', 'ge_right_comm', 'ge_left_comm', 'ge_comm', 'lt_right_comm', 'lt_left_comm', 'lt_comm', 'gt_left_comm', 'gt_comm', 'gt_right_comm', 'l5_12_a', 'bet__le1213', 'bet__le2313', 'l5_12_b', 'bet_le_eq', 'or_lt_cong_gt', 'lt__le', 'lt_transitivity', 'nlt', 'le__nlt', 'cong__nlt', 'lt__nle', 'le_cases', 'l5_6', 'bet_out', 'out_diff1', 'out_dec', 'out_diff2', 'out_col', 'out_distinct', 'l6_3_1', 'l6_3_2', 'l6_4_1', 'l6_4_2', 'out_trivial', 'l6_2', 'l6_6', 'l6_7', 'segment_construction_3', 'l6_13_2', 'l6_11_existence', 'col_transitivity_2', 'l6_13_1', 'bet_out_out_bet', 'bet2_le2__le1245', 'cong_preserves_bet', 'or_bet_out', 'not_out_bet', 'l6_11_uniqueness', 'not_bet_out', 'col3', 'not_bet_and_out', 'out_cong_cong', 'out2_out_2', 'out_to_bet', 'out2_out_1', 'out_bet_out_2', 'out_bet_out_1', 'bet2_out_out', 'out2_bet_out', 'l6_21', 'col_transitivity_1', 'is_midpoint_dec', 'is_midpoint_id_2', 'is_midpoint_id', 'l7_2', 'l7_3', 'l7_3_2', 'symmetric_point_construction', 'symmetric_point_uniqueness', 'l7_9', 'l7_9_bis', 'Mid_cases', 'l7_15', 'Mid_perm', 'l7_16', 'l7_17_bis', 'l7_20_bis', 'cong_col_mid', 'bet_col1', 'midpoint_distinct_1', 'l7_22', 'midpoint_distinct_2', 'midpoint_def', 'midpoint_distinct_3', 'symmetry_preserves_midpoint', 'midpoint_bet', 'midpoint_col', 'midpoint_not_midpoint', 'midpoint_cong', 'l7_20', 'swap_diff', 'cong_cong_half_2', 'le_mid2__le12', 'midpoint_preserves_out', 'col_bet2_cong1', 'col_cong2_bet1', 'col_cong2_bet2', 'col_bet2_cong2', 'l7_17', 'cong_cong_half_1', 'Per_dec', 'Per_cases', 'Per_perm', 'l8_2', 'l8_4', 'l8_3', 'l8_5', 'l8_6', 'l8_8', 'l8_9', 'col_col_per_per', 'Perp_in_dec', 'perp_distinct', 'l8_12', 'l8_14_1', 'l8_14_2_1a', 'perp_in_distinct', 'l8_14_2_1b', 'l8_14_2_1b_bis', 'l8_15_1', 'l8_15_2', 'l8_14_2_2', 'perp_in_per', 'perp_sym', 'per_perp', 'perp_comm', 'perp_right_comm', 'perp_left_comm', 'perp_in_comm', 'perp_in_right_comm', 'Perp_cases', 'perp_in_sym', 'perp_in_left_comm', 'Perp_perm', 'Perp_in_cases', 'Perp_in_perm', 'midpoint_distinct', 'l8_16_2', 'l8_20_2', 'l8_21', 'perp_in_col', 'perp_per_1', 'perp_per_2', 'perp_col', 'perp_not_eq_1', 'perp_not_eq_2', 'diff_per_diff', 'per_not_colp', 'perp_cong', 'l8_22_bis', 'perp_in_perp', 'perp_not_col', 'l8_22', 'per_double_cong', 'perp_not_col2', 'col_per_perp', 'cong_perp_or_mid', 'l8_18_uniqueness', 'perp_perp_in', 'invert_two_sides', 'l9_2', 'sym_sym', 'distinct', 'diff_col_ex', 'sym_preserve_diff', 'l9_4_2', 'invert_one_side', 'l9_8_1', 'not_two_sides_id', 'l9_9_bis', 'l9_4_1', 'l9_9', 'one_side_chara', 'one_side_symmetry', 'diff_bet_ex3', 'col_eq', 'one_side_not_col123', 'one_side_not_col124', 'col_one_side', 'out_one_side', 'one_side_transitivity', 'col124__nos', 'col123__nos', 'col_two_sides', 'two_sides_not_col', 'l9_10', 'cong_on_bissect', 'l10_10', 'image_gen_preserves_bet', 'image_gen_preserves_col', 'image_gen_preserves_ncol', 'per_per_cong_1', 'per_per_cong_gen', 'image_preserves_midpoint', 'two_sides_dec', 'cong_mid_perp__col', 'image_preserves_bet', 'per_per_cong', 'image_in_col', 'is_image_is_image_spec', 'l10_4_spec', 'l10_4', 'l10_6_existence_spec', 'l10_5', 'l10_6_uniqueness', 'l10_7', 'l10_8', 'image_in_is_image_spec', 'image_in_col0', 'is_image_spec_rev', 'is_image_rev', 'image_col', 'is_image_spec_triv', 'is_image_spec_dec', 'perp_vector', 'osym_not_col', 'perp_exists', 'exists_cong_per', 'midpoint_preserves_per', 'cong3_diff', 'cong3_diff2', 'conga_sym', 'cong3_conga', 'conga_diff1', 'conga_diff2', 'conga_diff45', 'conga_diff56', 'conga_trivial_1', 'conga_pseudo_refl', 'conga_comm', 'l11_14', 'l11_18_1', 'cong3_preserves_out', 'l11_10', 'l11_24', 'l11_22', 'angle_construction_2', 'inangle1123', 'l11_15', 'inangle3123', 'in_angle_two_sides', 'inangle_distincts', 'segment_construction_0', 'angle_construction_3', 'inangle_one_side2', 'in_angle_trivial_2', 'ncol_conga_ncol', 'lea_line', 'bet_in_angle_bet', 'l11_31_1', 'out2__conga', 'lea_refl', 'conga__lea456123', 'conga__lea', 'lea121345', 'two_sides_in_angle', 'not_conga', 'not_conga_sym', 'not_and_lta', 'lea_right_comm', 'lea_comm', 'gta_trans', 'lea_left_comm', 'lta_right_comm', 'lta_left_comm', 'lta_comm', 'acute_sym', 'obtuse_sym', 'l11_43', 'not_lta_and_conga', 'not_gta_and_conga', 'l11_36', 'not_lta_and_gta', 'conga_sym_equiv', 'lta_not_conga', 'l11_44_1_b', 'l11_44_1', 'conga_dec', 'l11_44_2', 'conga_distinct', 'per2_cong2__cong_3', 'lta_diff', 'out_in_angle', 'os2__inangle', 'acute_conga__acute', 'out_lea__out', 'lta__lea', 'bet_lea__bet', 'bet2_lta__lta', 'lea_dec', 'inangle_dec', 'gea_dec', 'lta_dec', 'gta_dec', 'or_lta_conga_gta', 'nlta', 'cong__acute', 'acute_trivial', 'acute_not_per', 'conga_os__out', 'col_conga__conga', 'par_reflexivity', 'par_strict_irreflexivity', 'not_par_strict_id', 'par_id', 'par_strict_not_col_2', 'par_strict_not_col_1', 'par_strict_not_col_4', 'par_strict_not_col_3', 'par_id_1', 'par_id_3', 'par_id_2', 'par_id_5', 'par_id_4', 'par_right_comm', 'par_comm', 'par_strict_comm', 'par_strict_neq1', 'par_symmetry', 'par_strict_neq2', 'par_neq1', 'par_neq2', 'Par_cases', 'Par_perm', 'Par_strict_cases', 'Par_strict_perm', 'pars__os3412', 'Perp_dec', 'l12_6', 'parallel_existence1', 'par_not_col', 'l12_9', 'not_strict_par2', 'not_strict_par', 'not_par_not_col', 'not_strict_par1', 'perp_perp_col_col', 'par_distincts', 'not_par_inter_uniqueness', 'col_not_col_not_par', 'all_one_side_par_strict', 'line_dec', 'par_strict_one_side', 'par_strict_all_one_side', 'par_strict_col4__par_strict', 'inter_trivial', 'inter_right_comm', 'inter_left_comm', 'inter_comm', 'par_strict_par', 'col_par', 'par_strict_distinct', 'par_strict_col2_par_strict', 'par_col2_par', 'perp_inter_perp_in', 'l12_18_d', 'par_two_sides_two_sides', 'inter_sym', 'par_col4__par', 'l12_18_b', 'par_not_col_strict', 'par_one_or_two_sides', 'tarski_s_euclid', 'not_par_inter_exists', 'Par_dec', 'par_not_par', 'l12_20', 'l12_21', 'l12_22', 'not_par_strict_inter_exists', 'not_par_one_not_par', 'not_par_inter', 'inter_dec', 'per_distinct', 'per2_preserves_diff', 'per_lt', 'per2_col_eq', 'perp_per_bet', 'perp2_refl', 'perp2_sym', 'perp2_right_comm', 'perp2_left_comm', 'perp2_comm', 'perp2_par', 'is_image_perp_in', 'gta_to_lta', 'lta_to_gta', 'perp_inter_perp_in_n', 'flat_all_lea', 'perp_in_rewrite', 'perp_bet_obtuse', 'per3_preserves_bet2_aux', 'lg_exists', 'lg_cong', 'lg_cong_lg', 'ex_points_lg', 'lg_sym', 'is_len_cong', 'not_cong_is_len1', 'not_cong_is_len', 'is_len_cong_is_len', 'lg_null_instance', 'lg_null_trivial', 'lg_null_dec', 'ex_point_lg', 'ex_point_lg_bet', 'ex_point_lg_out', 'all_eql', 'ex_eql', 'ex_lg', 'null_len', 'lg_eql_lg', 'ang_exists', 'ex_points_ang', 'is_ang_conga', 'ang_conga', 'not_conga_not_ang', 'is_ang_conga_is_ang', 'not_conga_is_ang', 'not_cong_is_ang1', 'all_eqa', 'is_ang_distinct', 'null_ang', 'flat_ang', 'ex_ang', 'anga_is_ang', 'ex_points_anga', 'anga_conga', 'is_anga_conga', 'is_anga_to_is_ang', 'is_anga_conga_is_anga', 'not_conga_is_anga', 'ex_eqaa', 'ex_eqa', 'all_eqaa', 'is_anga_distinct', 'null_anga', 'out_is_len_eq', 'ex_anga', 'not_null_ang_ang', 'ang_sym', 'ang_const', 'ang_not_null_lg', 'anga_sym', 'not_null_ang_def_equiv', 'anga_not_null_lg', 'not_flat_ang_def_equiv', 'anga_const', 'is_null_anga_out', 'ang_const_o', 'ang_cong_ang', 'anga_acute', 'anga_distincts', 'ang_distincts', 'is_null_ang_out', 'not_null_not_col', 'out_null_ang', 'out_null_anga', 'bet_flat_ang', 'anga_conga_anga', 'anga_const_o', 'is_null_all', 'out_out_anga', 'anga_col_out', 'anga_not_lg_null', 'eqA_preserves_ang', 'ang_not_lg_null', 'not_cong_is_anga1', 'acute_not_bet', 'anga_not_flat', 'eqA_preserves_anga', 'perp_out__acute', 'lcos_lg_not_null', 'acute_not_obtuse', 'lcos_const0', 'lcos_const', 'lcos_lg_distincts', 'lcos_lg_anga', 'lcos_eql_lcos', 'lcos_not_lg_null', 'is_null_anga_dec', 'lcos_eq_refl', 'lcos_eq_sym', 'lcos2_comm', 'lcos2_exists', 'lcos_eqa_lcos', 'lcos2_eq_refl', 'lcos2_eq_sym', 'lcos2_lg_anga', 'lcos2_uniqueness', 'lcos_eq_lcos2_eq', 'lcos2_lg_not_null', 'lcos3_lcos_1_2', 'flat_not_acute', 'lcos3_lcos_2_1', 'lcos3_permut2', 'lcos3_exists', 'lcos3_eq_refl', 'lcos3_eq_sym', 'lcos3_lg_anga', 'lcos3_lg_not_null', 'lcos_eq_lcos3_eq', 'lcos2_eq_lcos3_eq', 'lcos3_uniqueness', 'lcos2_lcos', 'l13_11', 'l13_15', 'project_trivial', 'pj_col_project', 'pj_trivial', 'sum_O_B_eq', 'sum_A_B_A', 'sum_A_O_eq', 'sum_A_B_B', 'sum_B_null', 'sum_A_null', 'opp_comm', 'pj_right_comm', 'pj_comm', 'pj_left_comm', 'opp_uniqueness', 'sum_assoc', 'not_null_double_not_null', 'diff_ar2', 'sum_ar2', 'diff_null_eq', 'sum3_col', 'sum3_comm_2_3', 'sum22_col', 'sum4_col', 'sum3_to_sum4', 'sum_to_sum3', 'sum_A_exists', 'sum22_permut', 'sum_opp', 'diff_stable', 'sum_diff', 'project_pj', 'prod_assoc', 'prod_uniquenessB', 'prod_sym', 'diff_2_prod', 'O_not_positive', 'sum_pos_pos', 'pos_not_neg', 'neg_not_pos', 'opp_neg_pos', 'ltP_ar2', 'leP_refl', 'ltP_sum_pos', 'ltP_neq', 'diff_pos_diff_neg', 'opp_pos_neg', 'not_pos_and_neg', 'leP_asym', 'col_pos_or_neg', 'pos_opp_neg', 'pos_inv_pos', 'length_pos', 'length_id_1', 'length_id_2', 'length_eq_cong_1', 'length_eq_cong_2', 'length_id', 'length_Ar2', 'length_cong', 'leP_bet', 'length_not_col_null', 'length_O', 'not_triangular_equality1', 'conga_bet_conga', 'image_preserves_bet1', 'image_preserves_out', 'length_sym', 'Cs_not_Col', 'Cd_Col']
th_valid=['cong_symmetry', 'cong_transitivity', 'cong_left_commutativity', 'cong_right_commutativity', 'cong_reflexivity', 'cong_3421', 'cong_4312', 'cong_4321', 'cong_commutativity', 'cong_trivial_identity', 'cong_reverse_identity', 'not_cong_1243', 'not_cong_2134', 'not_cong_2143', 'not_cong_3412', 'not_cong_3421', 'not_cong_4312', 'five_segment_with_def', 'not_cong_4321', 'cong_diff', 'cong_diff_2', 'cong_diff_3', 'cong_diff_4', 'cong_3_swap', 'cong_3_sym', 'cong_3_swap_2', 'l2_11', 'eq_dec_points', 'Cong_cases', 'construction_uniqueness', 'Cong_perm', 'bet_cong3', 'cong3_transitivity', 'bet_col', 'between_trivial', 'Bet_perm', 'between_symmetry', 'Bet_cases', 'between_trivial2', 'between_equality', 'between_equality_2', 'bet_neq12__neq', 'bet_neq21__neq', 'bet_neq32__neq', 'bet_neq23__neq', 'between_exchange3', 'between_inner_transitivity', 'outer_transitivity_between2', 'not_bet_distincts', 'outer_transitivity_between', 'between_exchange4', 'between_exchange2', 'two_distinct_points', 'point_construction_different', 'l3_17', 'l2_11_b', 'lower_dim_ex', 'another_point', 'cong_dec_eq_dec_b', 'bet_dec_eq_dec_b', 'BetSEq', 'l_3_9_4', 'col_permutation_1', 'col_permutation_3', 'col_permutation_4', 'col_permutation_2', 'col_permutation_5', 'not_col_permutation_1', 'not_col_permutation_2', 'not_col_permutation_4', 'not_col_permutation_3', 'not_col_permutation_5', 'Col_cases', 'col_trivial_1', 'col_trivial_2', 'col_trivial_3', 'Col_perm', 'l4_13', 'l4_18', 'l4_17', 'l4_19', 'not_col_distincts', 'NCol_cases', 'NCol_perm', 'col_cong_3_cong_3_eq', 'l4_16', 'l4_3', 'cong3_bet_eq', 'l4_3_1', 'segment_construction_2', 'l5_5_1', 'le_bet', 'le_reflexivity', 'le_transitivity', 'cong3_symmetry', 'between_cong_2', 'Cong_dec', 'bet_dec', 'Col_dec', 'le_trivial', 'le_zero', 'le_diff', 'cong__le', 'bet_cong_eq', 'cong__le3412', 'le1221', 'le_left_comm', 'le_right_comm', 'ge_left_comm', 'le_comm', 'ge_right_comm', 'ge_comm', 'lt_left_comm', 'lt_right_comm', 'gt_left_comm', 'lt_comm', 'gt_right_comm', 'l5_6', 'lt_diff', 'gt_comm', 'third_point', 'bet__le1213', 'l5_12_a', 'bet__le2313', 'or_lt_cong_gt', 'lt__le', 'lt_transitivity', 'nlt', 'le__nlt', 'cong__nlt', 'lt__nle', 'le_cases', 'bet2_le2__le', 'bet_out', 'out_dec', 'out_diff1', 'out_diff2', 'out_distinct', 'out_col', 'l6_2', 'l6_3_2', 'l6_3_1', 'l6_4_1', 'bet_out__bet', 'l6_4_2', 'out_trivial', 'l6_6', 'l6_7', 'bet_out_out_bet', 'l6_11_existence', 'segment_construction_3', 'l6_13_2', 'l6_13_1', 'l6_11_uniqueness', 'not_col_exists', 'out2__bet', 'col3', 'cong_preserves_bet', 'bet2_le2__le1245', 'or_bet_out', 'not_out_bet', 'not_bet_out', 'l6_21', 'not_bet_and_out', 'out_to_bet', 'out2_out_2', 'out2_out_1', 'out_bet_out_1', 'out_bet_out_2', 'out_bet__out', 'col_transitivity_1', 'l6_16_1', 'col_transitivity_2', 'is_midpoint_dec', 'is_midpoint_id', 'l7_2', 'is_midpoint_id_2', 'l7_3', 'symmetric_point_uniqueness', 'symmetric_point_construction', 'l7_3_2', 'l7_9_bis', 'l7_15', 'l7_16', 'Mid_perm', 'Mid_cases', 'l7_17_bis', 'symmetry_preserves_midpoint', 'l7_20_bis', 'cong_col_mid', 'l7_20', 'midpoint_distinct_1', 'midpoint_distinct_3', 'l7_25', 'midpoint_distinct_2', 'bet_col1', 'midpoint_bet', 'midpoint_def', 'midpoint_cong', 'midpoint_col', 'swap_diff', 'cong_cong_half_2', 'le_mid2__le12', 'midpoint_preserves_out', 'col_cong2_bet1', 'col_cong2_bet2', 'col_bet2_cong1', 'col_bet2_cong2', 'col_cong2_bet3', 'col_cong_bet', 'cong_mid2__cong', 'Per_dec', 'Per_cases', 'l8_2', 'Per_perm', 'l8_4', 'l8_3', 'l8_5', 'l8_6', 'l8_8', 'l8_9', 'col_col_per_per', 'perp_distinct', 'Perp_in_dec', 'l8_14_1', 'l8_14_2_1b', 'perp_in_distinct', 'l8_14_2_1a', 'l8_14_2_1b_bis', 'l8_14_2_2', 'l8_15_1', 'l8_14_3', 'per_perp', 'perp_left_comm', 'perp_in_right_comm', 'perp_right_comm', 'perp_in_left_comm', 'perp_comm', 'perp_sym', 'perp_in_comm', 'Perp_cases', 'Perp_perm', 'l8_16_2', 'l8_20_2', 'midpoint_distinct', 'l8_21', 'perp_in_col', 'perp_per_1', 'perp_per_2', 'l8_18_uniqueness', 'perp_not_eq_1', 'perp_not_eq_2', 'diff_per_diff', 'perp_cong', 'per_not_col', 'midpoint_existence_aux', 'perp_in_perp', 'l8_22', 'perp_proj', 'l8_22_bis', 'perp_not_col', 'l8_24', 'cong_perp_or_mid', 'per_double_cong', 'per_not_colp', 'perp_not_col2', 'perp_col', 'Perp_in_cases', 'l9_2', 'invert_two_sides', 'ts_distincts', 'sym_sym', 'distinct', 'diff_col_ex', 'diff_bet_ex3', 'mid_preserves_col', 'sym_preserve_diff', 'os_distincts', 'invert_one_side', 'diff_col_ex3', 'l9_8_1', 'not_two_sides_id', 'l9_9_bis', 'one_side_symmetry', 'one_side_transitivity', 'col_eq', 'mid_two_sides', 'one_side_not_col123', 'one_side_not_col124', 'out_one_side', 'l9_18', 'col123__nos', 'col124__nos', 'two_sides_not_col', 'l9_10', 'col_two_sides_bet', 'cong_on_bissect', 'cong_mid_perp__col', 'image_gen_preserves_bet', 'image_gen_preserves_col', 'image_gen_preserves_ncol', 'image_preserves_bet', 'image_preserves_midpoint', 'per_per_cong_1', 'image_preserves_col', 'per_per_cong_gen', 'two_sides_dec', 'one_side_dec', 'per_per_cong', 'is_image_is_image_spec', 'l10_4_spec', 'l10_2_existence', 'l10_5', 'l10_4', 'l10_6_uniqueness', 'l10_8', 'col__refl', 'osym_not_col', 'l10_2_uniqueness_spec', 'image_in_is_image_spec', 'is_image_spec_rev', 'image_in_col0', 'midpoint_preserves_per', 'is_image_rev', 'is_image_spec_triv', 'image_col', 'is_image_spec_dec', 'l10_6_uniqueness_spec', 'image_image_in', 'perp_exists', 'perp_vector', 'exists_cong_per', 'conga_sym', 'cong3_diff', 'cong3_diff2', 'conga_refl', 'conga_diff1', 'conga_diff2', 'conga_diff45', 'conga_diff56', 'conga_trivial_1', 'out2__conga', 'conga_comm', 'l11_10', 'l11_14', 'l11_18_1', 'cong3_preserves_out', 'angle_construction_1', 'l11_24', 'col_in_angle', 'l11_22b', 'out_in_angle', 'inangle1123', 'out321__inangle', 'inangle3123', 'out341__inangle', 'l11_22a', 'in_angle_two_sides', 'segment_construction_0', 'col_in_angle_out', 'inangle_distincts', 'angle_construction_3', 'l11_aux', 'inangle_one_side2', 'in_angle_trivial_2', 'in_angle_trivial_1', 'ncol_conga_ncol', 'in_angle_line', 'lea_line', 'conga_ex_cong3', 'l11_31_1', 'lea_refl', 'conga__lea', 'conga__lea456123', 'bet_in_angle_bet', 'two_sides_in_angle', 'not_conga', 'not_conga_sym', 'not_and_lta', 'gta_trans', 'lea_left_comm', 'lea_right_comm', 'lea_comm', 'l11_36', 'lta_left_comm', 'lta_right_comm', 'lta_comm', 'acute_sym', 'obtuse_sym', 'not_lta_and_conga', 'not_gta_and_conga', 'not_lta_and_gta', 'conga_dec', 'lta_not_conga', 'l11_44_1_b', 'l11_44_1', 'l11_44_2', 'lta_diff', 'conga_distinct', 'conga_sym_equiv', 'per2_cong2__cong_3', 'per2_cong2__cong_conga2', 'l11_51', 'os2__inangle', 'lea_distincts', 'gea_distincts', 'gta_distincts', 'lta_distincts', 'acute_conga__acute', 'l11_50_2', 'lta__lea', 'acute_distincts', 'bet2_lta__lta', 'inangle_dec', 'lea_dec', 'lta_dec', 'gea_dec', 'gta_dec', 'cong__acute', 'nlta', 'acute_trivial', 'acute_not_per', 'triangle_strict_inequality_2', 'conga_os__out', 'acute_one_side', 'par_strict_irreflexivity', 'par_id', 'not_par_strict_id', 'par_strict_not_col_1', 'par_strict_not_col_3', 'par_strict_not_col_2', 'par_reflexivity', 'par_strict_not_col_4', 'par_id_2', 'par_id_1', 'par_id_3', 'par_id_4', 'par_id_5', 'par_strict_symmetry', 'par_strict_left_comm', 'par_comm', 'par_strict_right_comm', 'par_strict_comm', 'par_strict_neq1', 'par_strict_neq2', 'par_neq1', 'Par_cases', 'par_neq2', 'Par_perm', 'Par_strict_cases', 'Par_strict_perm', 'pars__os3412', 'Perp_dec', 'l12_6', 'perp_perp_col_col', 'par_not_col', 'parallel_existence1', 'not_strict_par1', 'not_strict_par2', 'not_par_not_col', 'not_strict_par', 'not_par_inter_uniqueness', 'par_distincts', 'col_not_col_not_par', 'par_left_comm', 'all_one_side_par_strict', 'line_dec', 'par_strict_all_one_side', 'par_strict_col4__par_strict', 'inter_left_comm', 'inter_trivial', 'par_strict_col2_par_strict', 'inter_right_comm', 'inter_comm', 'par_right_comm', 'par_col2_par', 'par_not_col_strict', 'l12_18_d', 'par_strict_par', 'par_strict_distinct', 'col_par', 'acute_col_perp__out', 'acute_col_perp__out_1', 'perp_inter_exists', 'par_two_sides_two_sides', 'par_col4__par', 'perp_inter_perp_in', 'par_one_or_two_sides', 'tarski_s_euclid', 'not_par_inter_exists', 'inter_dec', 'Par_dec', 'par_not_par', 'l12_20', 'l12_22', 'not_par_strict_inter_exists', 'not_par_one_not_par', 'per2_preserves_diff', 'per_distinct', 'per2_col_eq', 'per_lt', 'perp_per_bet', 'perp2_sym', 'perp2_refl', 'perp2_left_comm', 'perp2_comm', 'perp2_right_comm', 'per3_preserves_bet2_aux', 'is_image_perp_in', 'perp_inter_perp_in_n', 'per13_preserves_bet_inv', 'gta_to_lta', 'lta_to_gta', 'perp_in_rewrite', 'perp2_perp_in', 'flat_all_lea', 'per3_preserves_bet2', 'perp_bet_obtuse', 'perp_out_acute', 'lg_cong', 'lg_cong_lg', 'ex_points_lg', 'lg_sym', 'lg_exists', 'is_len_cong', 'not_cong_is_len', 'is_len_cong_is_len', 'not_cong_is_len1', 'lg_null_instance', 'lg_null_trivial', 'lg_null_dec', 'ex_point_lg', 'ex_point_lg_out', 'ex_point_lg_bet', 'null_len', 'all_eql', 'ex_lg', 'lg_eql_lg', 'ang_exists', 'ang_conga', 'ex_points_ang', 'is_ang_conga', 'not_conga_not_ang', 'is_ang_conga_is_ang', 'not_conga_is_ang', 'not_cong_is_ang1', 'all_eqa', 'null_ang', 'is_ang_distinct', 'ex_eqa', 'ex_ang', 'anga_is_ang', 'anga_conga', 'ex_points_anga', 'is_anga_conga', 'is_anga_to_is_ang', 'is_anga_conga_is_anga', 'not_conga_is_anga', 'is_anga_distinct', 'ex_eqaa', 'null_anga', 'out_is_len_eq', 'not_null_ang_ang', 'ang_sym', 'ang_const', 'not_null_ang_def_equiv', 'ang_not_null_lg', 'anga_sym', 'anga_not_null_lg', 'anga_const', 'is_null_anga_out', 'ang_distincts', 'anga_distinct', 'ang_cong_ang', 'is_null_ang_out', 'out_null_ang', 'not_null_not_col', 'bet_flat_ang', 'ang_const_o', 'out_null_anga', 'anga_conga_anga', 'anga_const_o', 'anga_distincts', 'out_out_anga', 'anga_not_flat', 'ang_not_lg_null', 'anga_acute', 'eqA_preserves_ang', 'anga_not_lg_null', 'eqA_preserves_anga', 'not_cong_is_anga1', 'ang_distinct', 'anga_col_out', 'anga_col_null', 'lcos_lg_not_null', 'acute_not_obtuse', 'perp_acute_out', 'lcos_const0', 'lcos_lg_distincts', 'lcos_const', 'lcos_lg_anga', 'lcos_eql_lcos', 'lcos_not_lg_null', 'is_null_anga_dec', 'perp_obtuse_bet', 'lcos_uniqueness', 'lcos2_comm', 'lcos_eqa_lcos', 'lcos2_exists', 'lcos2_eq_refl', 'lcos2_eq_sym', 'lcos2_uniqueness', 'lcos2_lg_anga', 'lcos_eq_lcos2_eq', 'lcos2_lg_not_null', 'lcos3_lcos_1_2', 'lcos3_lcos_2_1', 'lcos3_eq_refl', 'lcos3_exists', 'lcos3_eq_sym', 'lcos3_lg_not_null', 'lcos3_lg_anga', 'lcos_eq_lcos3_eq', 'lcos2_eq_lcos3_eq', 'lcos3_uniqueness', 'lcos2_lcos', 'l13_10_aux1', 'pj_col_project', 'opp0', 'sum_O_O', 'pj_trivial', 'sum_A_O_eq', 'sum_O_B_eq', 'sum_A_B_A', 'sum_A_B_B', 'opp0_uniqueness', 'sum_B_null', 'sum_A_null', 'opp_comm', 'pj_right_comm', 'pj_left_comm', 'pj_comm', 'not_null_double_not_null', 'diff_ar2', 'sum_ar2', 'sum3_col', 'sum3_comm_2_3', 'sum4_col', 'sum22_col', 'sum3_to_sum4', 'sum_to_sum3', 'sum_A_exists', 'sum22_permut', 'sum_opp', 'diff_stable', 'opp_uniqueness', 'sum22_comm', 'sum4_comm', 'project_pj', 'prod_uniqueness', 'prod_sym', 'eq_squares_eq_or_opp', 'O_not_positive', 'neg_not_pos', 'pos_not_neg', 'opp_pos_neg', 'opp_neg_pos', 'ltP_ar2', 'ltP_neq', 'leP_refl', 'ltP_sum_pos', 'diff_pos_diff_neg', 'not_pos_and_neg', 'leP_asym', 'pos_opp_neg', 'pos_inv_pos', 'col_pos_or_neg', 'length_pos', 'length_id_1', 'length_id_2', 'length_id', 'length_eq_cong_1', 'length_eq_cong_2', 'length_Ar2', 'leP_bet', 'length_cong', 'length_not_col_null', 'not_triangular_equality1', 'length_O', 'image_preserves_bet1', 'image_preserves_out', 'conga_bet_conga', 'length_sym', 'Cs_not_Col', 'Cd_Col']
th_valid_with_pyth_rel_grid_ok=['cong_reflexivity', 'cong_symmetry', 'cong_left_commutativity', 'cong_right_commutativity', 'cong_transitivity', 'cong_4312', 'cong_3421', 'cong_reverse_identity', 'cong_trivial_identity', 'cong_commutativity', 'cong_4321', 'not_cong_2134', 'not_cong_3412', 'not_cong_4321', 'not_cong_4312', 'not_cong_1243', 'not_cong_2143', 'five_segment_with_def', 'not_cong_3421', 'cong_diff_4', 'cong_diff', 'cong_diff_3', 'cong_diff_2', 'cong_3_swap', 'cong_3_sym', 'cong3_transitivity', 'bet_cong3', 'cong_3_swap_2', 'l2_11', 'Cong_cases', 'eq_dec_points', 'Cong_perm', 'construction_uniqueness', 'bet_col', 'between_trivial', 'Bet_perm', 'Bet_cases', 'between_symmetry', 'between_equality', 'between_trivial2', 'between_exchange3', 'bet_neq23__neq', 'bet_neq12__neq', 'bet_neq21__neq', 'bet_neq32__neq', 'not_bet_distincts', 'between_equality_2', 'outer_transitivity_between2', 'outer_transitivity_between', 'between_exchange2', 'between_inner_transitivity', 'l_3_9_4', 'between_exchange4', 'two_distinct_points', 'point_construction_different', 'lower_dim_ex', 'l3_17', 'another_point', 'cong_dec_eq_dec_b', 'l2_11_b', 'bet_dec_eq_dec_b', 'BetSEq', 'col_permutation_1', 'col_permutation_2', 'col_permutation_3', 'col_permutation_4', 'col_permutation_5', 'not_col_permutation_1', 'not_col_permutation_2', 'not_col_permutation_3', 'not_col_permutation_4', 'col_trivial_1', 'not_col_permutation_5', 'col_trivial_2', 'Col_cases', 'col_trivial_3', 'l4_14', 'Col_perm', 'l4_17', 'l4_13', 'not_col_distincts', 'l4_19', 'NCol_cases', 'l4_18', 'NCol_perm', 'col_cong_3_cong_3_eq', 'l4_3', 'l4_3_1', 'cong3_bet_eq', 'le_bet', 'l5_5_2', 'l5_5_1', 'le_reflexivity', 'le_transitivity', 'cong3_symmetry', 'Cong_dec', 'bet_dec', 'Col_dec', 'le_trivial', 'le_zero', 'le_diff', 'bet_cong_eq', 'cong__le3412', 'le1221', 'le_left_comm', 'le_right_comm', 'ge_left_comm', 'le_comm', 'ge_right_comm', 'ge_comm', 'lt_right_comm', 'lt_left_comm', 'lt_comm', 'l5_6', 'gt_right_comm', 'gt_left_comm', 'gt_comm', 'bet__le1213', 'l5_12_a', 'bet__le2313', 'bet_le_eq', 'or_lt_cong_gt', 'l5_12_b', 'lt__le', 'lt_transitivity', 'nlt', 'cong__nlt', 'le__nlt', 'lt__nle', 'le_cases', 'bet_out', 'out_dec', 'out_diff1', 'out_distinct', 'out_diff2', 'out_col', 'l6_3_1', 'l6_2', 'l6_3_2', 'l6_4_2', 'out_trivial', 'l6_4_1', 'l6_6', 'l6_7', 'segment_construction_3', 'l6_11_existence', 'l6_13_1', 'bet_out_out_bet', 'l6_13_2', 'l6_11_uniqueness', 'col_transitivity_2', 'out2_bet_out', 'col3', 'bet2_le2__le1245', 'cong_preserves_bet', 'not_out_bet', 'not_bet_out', 'or_bet_out', 'out_cong_cong', 'not_bet_and_out', 'out_to_bet', 'out2_out_1', 'out2_out_2', 'bet2_out_out', 'out_bet_out_1', 'out_bet_out_2', 'l6_21', 'col_transitivity_1', 'is_midpoint_dec', 'is_midpoint_id', 'is_midpoint_id_2', 'l7_2', 'l7_3', 'l7_3_2', 'symmetric_point_construction', 'symmetric_point_uniqueness', 'l7_9_bis', 'l7_9', 'l7_15', 'l7_16', 'Mid_cases', 'symmetry_preserves_midpoint', 'Mid_perm', 'l7_17_bis', 'l7_20_bis', 'cong_col_mid', 'l7_20', 'bet_col1', 'l7_22', 'midpoint_distinct_1', 'midpoint_distinct_2', 'midpoint_distinct_3', 'l7_17', 'midpoint_def', 'midpoint_bet', 'midpoint_col', 'midpoint_cong', 'midpoint_not_midpoint', 'swap_diff', 'cong_cong_half_2', 'le_mid2__le12', 'midpoint_preserves_out', 'col_cong2_bet1', 'col_cong2_bet2', 'col_bet2_cong1', 'col_bet2_cong2', 'cong_cong_half_1', 'Per_dec', 'Per_perm', 'Per_cases', 'l8_2', 'l8_4', 'l8_3', 'l8_5', 'l8_6', 'l8_8', 'l8_9', 'col_col_per_per', 'perp_distinct', 'Perp_in_dec', 'l8_12', 'l8_14_1', 'l8_14_2_1a', 'perp_in_distinct', 'l8_14_2_1b', 'l8_14_2_1b_bis', 'l8_14_2_2', 'l8_15_1', 'l8_15_2', 'perp_in_per', 'perp_sym', 'perp_left_comm', 'per_perp', 'perp_right_comm', 'perp_comm', 'perp_in_left_comm', 'perp_in_sym', 'perp_in_right_comm', 'perp_in_comm', 'Perp_perm', 'Perp_cases', 'Perp_in_cases', 'Perp_in_perm', 'midpoint_distinct', 'l8_16_2', 'l8_20_2', 'l8_21', 'perp_in_col', 'perp_per_1', 'perp_col', 'perp_per_2', 'perp_not_eq_1', 'perp_not_eq_2', 'diff_per_diff', 'per_not_colp', 'l8_18_uniqueness', 'perp_cong', 'l8_22_bis', 'l8_22', 'perp_in_perp', 'perp_not_col', 'perp_not_col2', 'per_double_cong', 'col_per_perp', 'cong_perp_or_mid', 'perp_perp_in', 'l9_2', 'invert_two_sides', 'sym_sym', 'distinct', 'diff_col_ex', 'sym_preserve_diff', 'diff_bet_ex3', 'l9_4_1', 'l9_4_2', 'invert_one_side', 'l9_8_1', 'not_two_sides_id', 'l9_9', 'l9_9_bis', 'one_side_chara', 'one_side_symmetry', 'col_eq', 'one_side_transitivity', 'one_side_not_col123', 'one_side_not_col124', 'col_one_side', 'col_two_sides', 'out_one_side', 'l9_10', 'col123__nos', 'col124__nos', 'two_sides_not_col', 'cong_on_bissect', 'l10_10', 'image_gen_preserves_bet', 'image_gen_preserves_col', 'cong_mid_perp__col', 'image_gen_preserves_ncol', 'image_preserves_bet', 'image_preserves_midpoint', 'per_per_cong_1', 'per_per_cong_gen', 'two_sides_dec', 'per_per_cong', 'image_in_col', 'is_image_is_image_spec', 'l10_4', 'l10_4_spec', 'l10_5', 'l10_6_uniqueness', 'l10_6_existence_spec', 'l10_7', 'l10_8', 'image_in_is_image_spec', 'osym_not_col', 'image_in_col0', 'is_image_spec_rev', 'is_image_rev', 'image_col', 'is_image_spec_triv', 'is_image_spec_dec', 'midpoint_preserves_per', 'perp_vector', 'perp_exists', 'exists_cong_per', 'conga_sym', 'cong3_diff2', 'cong3_diff', 'cong3_conga', 'conga_diff2', 'conga_diff1', 'conga_diff45', 'conga_diff56', 'conga_trivial_1', 'conga_pseudo_refl', 'conga_comm', 'l11_10', 'l11_14', 'l11_18_1', 'cong3_preserves_out', 'out2__conga', 'angle_construction_2', 'l11_15', 'l11_22', 'l11_24', 'inangle1123', 'inangle3123', 'in_angle_two_sides', 'inangle_distincts', 'segment_construction_0', 'angle_construction_3', 'inangle_one_side2', 'in_angle_trivial_2', 'ncol_conga_ncol', 'lea_line', 'bet_in_angle_bet', 'out_in_angle', 'l11_31_1', 'lea_refl', 'conga__lea', 'conga__lea456123', 'lea121345', 'two_sides_in_angle', 'not_conga', 'not_conga_sym', 'not_and_lta', 'gta_trans', 'l11_36', 'lea_right_comm', 'lea_left_comm', 'lea_comm', 'lta_left_comm', 'lta_right_comm', 'lta_comm', 'obtuse_sym', 'acute_sym', 'l11_43', 'not_lta_and_conga', 'not_gta_and_conga', 'conga_sym_equiv', 'not_lta_and_gta', 'lta_not_conga', 'conga_dec', 'l11_44_1_b', 'l11_44_1', 'l11_44_2', 'lta_diff', 'conga_distinct', 'per2_cong2__cong_3', 'os2__inangle', 'acute_conga__acute', 'bet_lea__bet', 'out_lea__out', 'lta__lea', 'bet2_lta__lta', 'inangle_dec', 'lea_dec', 'gea_dec', 'lta_dec', 'gta_dec', 'or_lta_conga_gta', 'cong__acute', 'nlta', 'acute_trivial', 'acute_not_per', 'col_conga__conga', 'conga_os__out', 'triangle_inequality_2', 'par_reflexivity', 'par_strict_irreflexivity', 'not_par_strict_id', 'par_id', 'par_strict_not_col_1', 'par_strict_not_col_2', 'par_strict_not_col_3', 'par_strict_not_col_4', 'par_id_1', 'par_id_2', 'par_id_4', 'par_id_3', 'par_id_5', 'par_right_comm', 'par_symmetry', 'par_comm', 'par_strict_comm', 'par_strict_neq1', 'par_strict_neq2', 'par_neq1', 'Par_cases', 'par_neq2', 'Par_perm', 'Par_strict_cases', 'Par_strict_perm', 'pars__os3412', 'l12_6', 'Perp_dec', 'l12_9', 'parallel_existence1', 'par_not_col', 'perp_perp_col_col', 'not_strict_par1', 'not_strict_par', 'not_strict_par2', 'not_par_not_col', 'not_par_inter_uniqueness', 'col_not_col_not_par', 'par_distincts', 'all_one_side_par_strict', 'line_dec', 'par_strict_col4__par_strict', 'par_strict_one_side', 'par_strict_all_one_side', 'inter_trivial', 'par_col2_par', 'par_strict_col2_par_strict', 'inter_left_comm', 'inter_right_comm', 'inter_comm', 'par_not_col_strict', 'inter_sym', 'l12_18_d', 'l12_18_b', 'par_strict_distinct', 'par_strict_par', 'par_two_sides_two_sides', 'col_par', 'perp_inter_perp_in', 'par_col4__par', 'par_one_or_two_sides', 'tarski_s_euclid', 'not_par_inter_exists', 'Par_dec', 'par_not_par', 'l12_20', 'l12_21', 'l12_22', 'not_par_strict_inter_exists', 'not_par_inter', 'not_par_one_not_par', 'inter_dec', 'per_distinct', 'per2_preserves_diff', 'per2_col_eq', 'per_lt', 'perp_per_bet', 'perp2_refl', 'perp2_sym', 'perp2_left_comm', 'perp2_comm', 'perp2_right_comm', 'per3_preserves_bet2_aux', 'perp2_par', 'is_image_perp_in', 'perp_inter_perp_in_n', 'gta_to_lta', 'lta_to_gta', 'flat_all_lea', 'perp_in_rewrite', 'perp_bet_obtuse', 'lg_exists', 'lg_cong_lg', 'lg_sym', 'lg_cong', 'ex_points_lg', 'is_len_cong', 'not_cong_is_len', 'is_len_cong_is_len', 'not_cong_is_len1', 'lg_null_instance', 'lg_null_trivial', 'lg_null_dec', 'ex_point_lg', 'ex_point_lg_out', 'ex_point_lg_bet', 'null_len', 'ex_eql', 'all_eql', 'ex_lg', 'lg_eql_lg', 'ang_exists', 'ex_points_ang', 'is_ang_conga', 'ang_conga', 'is_ang_conga_is_ang', 'not_conga_not_ang', 'not_conga_is_ang', 'not_cong_is_ang1', 'all_eqa', 'is_ang_distinct', 'null_ang', 'ex_eqa', 'ex_ang', 'flat_ang', 'anga_is_ang', 'ex_points_anga', 'anga_conga', 'is_anga_to_is_ang', 'is_anga_conga', 'not_conga_is_anga', 'is_anga_conga_is_anga', 'ex_eqaa', 'all_eqaa', 'is_anga_distinct', 'null_anga', 'out_is_len_eq', 'ex_anga', 'not_null_ang_ang', 'ang_const', 'ang_sym', 'not_null_ang_def_equiv', 'not_flat_ang_def_equiv', 'ang_not_null_lg', 'anga_sym', 'anga_not_null_lg', 'ang_distincts', 'anga_distincts', 'ang_const_o', 'anga_const', 'is_null_anga_out', 'anga_acute', 'not_null_not_col', 'is_null_ang_out', 'ang_cong_ang', 'acute_not_bet', 'out_null_ang', 'bet_flat_ang', 'out_null_anga', 'anga_const_o', 'is_null_all', 'out_out_anga', 'anga_conga_anga', 'anga_col_out', 'anga_not_flat', 'ang_not_lg_null', 'eqA_preserves_ang', 'anga_not_lg_null', 'not_cong_is_anga1', 'eqA_preserves_anga', 'lcos_lg_not_null', 'perp_out__acute', 'acute_not_obtuse', 'lcos_const0', 'lcos_const', 'lcos_lg_distincts', 'lcos_lg_anga', 'lcos_eql_lcos', 'lcos_not_lg_null', 'is_null_anga_dec', 'flat_not_acute', 'lcos_eq_sym', 'lcos_eq_refl', 'lcos_eqa_lcos', 'lcos2_exists', 'lcos2_comm', 'lcos2_eq_refl', 'lcos2_eq_sym', 'lcos2_uniqueness', 'lcos2_lg_anga', 'lcos_eq_lcos2_eq', 'lcos3_lcos_2_1', 'lcos2_lg_not_null', 'lcos3_lcos_1_2', 'lcos3_permut2', 'lcos3_exists', 'lcos3_eq_refl', 'lcos3_eq_sym', 'lcos3_lg_anga', 'lcos3_lg_not_null', 'lcos2_eq_lcos3_eq', 'lcos_eq_lcos3_eq', 'lcos3_uniqueness', 'perp_acute', 'lcos2_lcos', 'l13_11', 'per_per_perp', 'l13_15', 'project_trivial', 'pj_col_project', 'pj_trivial', 'sum_O_O', 'sum_O_B_eq', 'sum_A_O_eq', 'sum_A_B_A', 'sum_A_B_B', 'sum_A_null', 'sum_B_null', 'opp_comm', 'pj_right_comm', 'opp_uniqueness', 'pj_left_comm', 'pj_comm', 'sum_assoc', 'not_null_double_not_null', 'diff_ar2', 'sum_ar2', 'diff_null_eq', 'sum3_col', 'sum3_comm_2_3', 'sum4_col', 'sum_diff', 'sum22_col', 'sum_to_sum3', 'sum3_to_sum4', 'sum_A_exists', 'sum22_permut', 'sum_opp', 'diff_stable', 'project_pj', 'prod_assoc', 'prod_uniquenessB', 'prod_sym', 'diff_2_prod', 'O_not_positive', 'sum_pos_pos', 'neg_not_pos', 'pos_not_neg', 'opp_pos_neg', 'opp_neg_pos', 'ltP_ar2', 'leP_refl', 'ltP_neq', 'ltP_sum_pos', 'diff_pos_diff_neg', 'not_pos_and_neg', 'leP_asym', 'pos_opp_neg', 'col_pos_or_neg', 'pos_inv_pos', 'length_id_2', 'length_pos', 'length_id_1', 'length_id', 'length_eq_cong_1', 'length_eq_cong_2', 'length_Ar2', 'leP_bet', 'length_cong', 'length_not_col_null', 'not_triangular_equality1', 'length_O', 'image_preserves_bet1', 'conga_bet_conga', 'image_preserves_out', 'length_sym', 'Ps_Col', 'Cs_not_Col', 'Cd_Col']

# %%
data_dir = "../datas/"

types=json_to_list_or_dict(data_dir+"rew_type.json")

rewrite_declaration = get_rewrites_definitions(data_dir+"rew_def.zf")
ax_th_declaration = get_ax_th_definitions(data_dir+"ax_th_def.zf")

all_th=list(ax_th_declaration.keys())

geocoq = json_to_list_or_dict(data_dir+"config_struct.json")

# %%
def dep_to_list(dep_file_path) :
    res=[]
    dep_file=open(dep_file_path,"r")
    for line in dep_file.readlines() :
        line=line.replace("\n","")
        line=line.replace("\r","")
        if line.startswith("lemme :") :
            for w in line.split(" ") :
                if w in all_th :
                    res.append(w)
        if line.startswith("rewrite :") :
            for w in line.split(" ") :
                if w in types :
                    res.append(w)
    dep_file.close()
    return res

def th_declaration_to_text(th_declaration) :
    index = th_declaration.find("]")
    if index >= 0 :
        return th_declaration[index+2:].replace("\n","")
    else :
        return th_declaration.replace("assert ","").replace("\n","")
    
def create_data() :
    x,labeled_y=[],[]
    for chapter in geocoq :
        for lemme in geocoq[chapter] :
            if lemme in th_valid :
                index = ax_th_declaration[lemme].find("]")
                x.append(th_declaration_to_text(ax_th_declaration[lemme]))
                labeled_y.append(dep_to_list(dep_dir_path+"/"+chapter+"/"+lemme+".dep"))
    return x,labeled_y

x,labeled_y=create_data()

# %%
multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(labeled_y)
index=multilabel_binarizer.classes_
y = multilabel_binarizer.transform(labeled_y)

# %%
def occurence_of_classes(y) :
    res=[0 for i in range(len(y[0]))]
    for vect in y :
        for i in range(len(vect)) :
            if vect[i]==1 :
                res[i]+=1
    return res

print(stats.describe(occurence_of_classes(y)))

oc = occurence_of_classes(y)
oc=[value for value in oc]
plt.plot(range(len(y[0])), sorted(oc,reverse=True))
plt.show()
# Out:
# DescribeResult(nobs=713, minmax=(1, 112), mean=5.448807854137447, variance=105.4892998408371, skewness=5.812952588157711, kurtosis=45.911914600920234)

# %%
def pretraitement(x,length=None) :
    global t,max_length
    
    def parse_special_characters(text) :
        text_cpy=text[:]
        for i in range(len(text_cpy)) :
            text_cpy[i]=re.sub(r'([-<=>!]+)', r' \1 ', text_cpy[i])
            text_cpy[i]=re.sub(r'([&|]+)', r' \1 ', text_cpy[i])
            text_cpy[i]=re.sub(r'([~]+)', r' \1 ', text_cpy[i])
            text_cpy[i]=re.sub(r'([()])', r' \1 ', text_cpy[i])
        return text_cpy

    t=prepro.text.Tokenizer(filters='"#$%*+,./:;?@[\\]^{}\t\n',split=" ",char_level=False)
    text=parse_special_characters(x)

    t.fit_on_texts(text)
    
    encoded_docs = t.texts_to_sequences(text)

    if length is None :
        max_length = len(max(encoded_docs,key=len))
    else :
        max_length = length
    
    padded_docs = prepro.sequence.pad_sequences(encoded_docs, maxlen=max_length, padding='post')
    return padded_docs

# %%
padded_docs=pretraitement(x)

# %%
t.sequences_to_texts([padded_docs[0]])
# Out:
# ['forall ( a b point ) cong a b a b']

# %%
weight=100000
x_train, x_test, y_train, y_test = train_test_split(np.array(padded_docs), np.array(y)*weight, test_size=0.20, random_state=10)

# %%
def get_x_test_name(x_test):
    x_train_name=[]
    seqs=t.sequences_to_texts(x_test)
    for th in ax_th_declaration :
        seq_th=pretraitement([th_declaration_to_text(ax_th_declaration[th])])
        for seq in seqs :
            if seq_th[0] == seq :
                x_train_name.append(th)
                break
    return x_train_name
label_x_test=get_x_test_name(x_test)
# Out:
# /home/baptman86/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   import sys

# %%
print(np.array(x_train).shape,np.array(y_train).shape)
# Out:
# (556, 95) (556, 713)

# %%
EMBEDDING_DIM=50
MAX_NUM_WORDS=1000
sequence_length = x_train.shape[1]
output_length = y_train.shape[1]
print(sequence_length,output_length)
# Out:
# 95 713

# %%
from keras.layers import Embedding
vocabulary_size=min(len(t.word_index)+1,MAX_NUM_WORDS)

embedding_layer = Embedding(vocabulary_size,
                            EMBEDDING_DIM)

# %%
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
from keras.layers import Input, Dense, Embedding, Conv2D, MaxPooling2D, Dropout,concatenate, LSTM
from keras.layers.core import Reshape, Flatten
from keras.optimizers import Adam
from keras.models import Model
from keras import regularizers
sequence_length = x_train.shape[1]
filter_sizes = [3,4,5]
num_filters = 50
drop = 0.2



inputs = Input(shape=(sequence_length,))
embedding = embedding_layer(inputs)

conv_0 = Conv1D(num_filters, (filter_sizes[0]),activation='relu',kernel_regularizer=regularizers.l2(0.01))(embedding)
conv_1 = Conv1D(num_filters, (filter_sizes[1]),activation='relu',kernel_regularizer=regularizers.l2(0.01))(embedding)
conv_2 = Conv1D(num_filters, (filter_sizes[2]),activation='relu',kernel_regularizer=regularizers.l2(0.01))(embedding)

merged_tensor = concatenate([conv_0, conv_1, conv_2], axis=1)

flatten = Flatten()(merged_tensor)
dropout = Dropout(drop)(flatten)


lstm=LSTM(1024, dropout=0.2, recurrent_dropout=0.2)(embedding)


output = Dense(units=output_length, activation='softmax',kernel_regularizer=regularizers.l2(0.01))(dropout)

model = Model(inputs, output)
# Out:
# WARNING:tensorflow:From /home/baptman86/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/baptman86/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 95)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 95, 50)       8000        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 93, 50)       7550        embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 92, 50)       10050       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 91, 50)       12550       embedding_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 276, 50)      0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 13800)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 13800)        0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 713)          9840113     dropout_1[0][0]
# ==================================================================================================
# Total params: 9,878,263
# Trainable params: 9,878,263
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=1e-3)

model.compile(loss='binary_crossentropy',optimizer=adam,metrics=['top_k_categorical_accuracy'])

# %%
epochs=10
history=model.fit(x_train, y_train, batch_size=32, epochs=epochs, verbose=1, validation_data=(x_test, y_test),shuffle=False)
#model.save("model_epure_Epochs"+str(epochs)+"_Weight"+str(weight)+".h5")
# Out:
# WARNING:tensorflow:From /home/baptman86/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 556 samples, validate on 139 samples
# Epoch 1/10
# 556/556 [==============================] - 8s 13ms/step - loss: 4368.5619 - top_k_categorical_accuracy: 0.0396 - val_loss: 6576.9910 - val_top_k_categorical_accuracy: 0.0432
# Epoch 2/10
# 556/556 [==============================] - 5s 9ms/step - loss: 3879.0721 - top_k_categorical_accuracy: 0.0791 - val_loss: 6895.2070 - val_top_k_categorical_accuracy: 0.0576
# Epoch 3/10
# 556/556 [==============================] - 6s 11ms/step - loss: 3554.2936 - top_k_categorical_accuracy: 0.1475 - val_loss: 7062.2797 - val_top_k_categorical_accuracy: 0.1295
# Epoch 4/10
# 556/556 [==============================] - 7s 12ms/step - loss: 3026.3363 - top_k_categorical_accuracy: 0.4047 - val_loss: 7497.8079 - val_top_k_categorical_accuracy: 0.2374
# Epoch 5/10
# 556/556 [==============================] - 6s 11ms/step - loss: 2548.3595 - top_k_categorical_accuracy: 0.5791 - val_loss: 8342.9911 - val_top_k_categorical_accuracy: 0.2734
# Epoch 6/10
# 556/556 [==============================] - 7s 13ms/step - loss: 2303.8422 - top_k_categorical_accuracy: 0.6871 - val_loss: 8783.6733 - val_top_k_categorical_accuracy: 0.2878
# Epoch 7/10
# 556/556 [==============================] - 9s 15ms/step - loss: 2207.3675 - top_k_categorical_accuracy: 0.7122 - val_loss: 8757.2467 - val_top_k_categorical_accuracy: 0.2878
# Epoch 8/10
# 556/556 [==============================] - 9s 17ms/step - loss: 2110.0586 - top_k_categorical_accuracy: 0.7662 - val_loss: 8571.7960 - val_top_k_categorical_accuracy: 0.2734
# Epoch 9/10
# 556/556 [==============================] - 9s 17ms/step - loss: 2024.8020 - top_k_categorical_accuracy: 0.7968 - val_loss: 8915.6934 - val_top_k_categorical_accuracy: 0.3022
# Epoch 10/10
# 556/556 [==============================] - 9s 17ms/step - loss: 1972.6071 - top_k_categorical_accuracy: 0.8363 - val_loss: 8821.4121 - val_top_k_categorical_accuracy: 0.3165

# %%
model=load_model("model_geocoq_extract.h5")
# Out:
# WARNING:tensorflow:From /home/baptman86/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/baptman86/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/baptman86/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
y_test_pred=model.predict(x_test)
y_train_pred=model.predict(x_train)
th_test=t.sequences_to_texts(x_test)
th_train=t.sequences_to_texts(x_train)

# %%
y_train_pred.shape
# Out:
# (556, 713)

# %%
def get_chapter(lemme_to_find) :
    for chapter in geocoq :
        for lemme in geocoq[chapter] :
            if lemme==lemme_to_find :
                return chapter
            
def th_string_to_pred(th_string,seuil=0.05,model=model,tokenizer=t,max_length=max_length) :
    x = th_declaration_to_text(th_string)
    padded_docs = pretraitement(np.array([x]),model.input_shape[1])
    
    y_pred = model.predict(padded_docs)[0]
    
    max_pred_value = np.max(y_pred)
    y_pred = np.array([0 if val < max_pred_value*seuil else 1 for val in y_pred])
    
    return y_pred
        
def lemme_pred(lemme,seuil=0.05,model=model,tokenizer=t,max_length=max_length) :
    x = th_declaration_to_text(ax_th_declaration[lemme])
    padded_docs = pretraitement(np.array([x]),model.input_shape[1])
    
    y_pred = model.predict(padded_docs)[0]
    max_pred_value = np.max(y_pred)
    y_pred = np.array([0 if val < max_pred_value*seuil else 1 for val in y_pred])
    
    return y_pred

def th_string_to_pred_top_k(th_string,k=5,model=model,tokenizer=t,max_length=max_length) :
    x = th_declaration_to_text(th_string)
    padded_docs = pretraitement(np.array([x]),model.input_shape[1])
    
    y_pred = model.predict(padded_docs)[0]
    pred_sort = sorted(y_pred)[::-1]
    index_top_k=[list(y_pred).index(pred_sort[i]) for i in range(k)]
    new_y_pred = np.zeros(len(y_pred))
    for i in range(k) :
        new_y_pred[index_top_k[i]]=1
        
    return new_y_pred

def lemme_pred_top_k(lemme,k=5,model=model,tokenizer=t,max_length=max_length) :
    x = th_declaration_to_text(ax_th_declaration[lemme])
    padded_docs = pretraitement(np.array([x]),model.input_shape[1])
    print(model.input_shape[1])
    
    y_pred = model.predict(padded_docs)[0]
    pred_sort = sorted(y_pred)[::-1]
    index_top_k=[list(y_pred).index(pred_sort[i]) for i in range(k)]
    new_y_pred = np.zeros(len(y_pred))
    for i in range(k) :
        new_y_pred[index_top_k[i]]=1
        
    return new_y_pred

def is_good_pred(lemme,seuil=0.05,model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
    pred_y = lemme_pred(lemme,seuil,model,tokenizer)
    
    pred_y_ones = np.where(pred_y==1)[0]
    
    
    labeled_y = dep_to_list(dep_dir_path+"/"+get_chapter(lemme)+"/"+lemme+".dep")
    y = multilabel_binarizer.transform(np.array([labeled_y]))
    
    y_ones = np.where(y[0]==1)[0]
    
    compare = [1 if val in pred_y_ones else 0 for val in y_ones]
    
    if len(compare)==0 :
        compare=[0]
    
    return (np.average(compare),len(pred_y_ones)/len(pred_y))

def is_good_pred_top_k(lemme,k=5,model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
    pred_y = lemme_pred_top_k(lemme,k,model,tokenizer)
    
    pred_y_ones = np.where(pred_y==1)[0]
    
    
    labeled_y = dep_to_list(dep_dir_path+"/"+get_chapter(lemme)+"/"+lemme+".dep")
    y = multilabel_binarizer.transform(np.array([labeled_y]))
    
    y_ones = np.where(y[0]==1)[0]
    
    compare = [1 if val in pred_y_ones else 0 for val in y_ones]
    
    if len(compare)==0 :
        compare=[0]
    
    return (np.average(compare),len(pred_y_ones)/len(pred_y))


print(is_good_pred_top_k('cong3_bet_eq',k=25))
print(is_good_pred('cong3_bet_eq',seuil=0.2))
# Out:
# 95
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-e40108bbb51d> in <module>
#      90
#      91
# ---> 92 print(is_good_pred_top_k('cong3_bet_eq',k=25))
#      93 print(is_good_pred('cong3_bet_eq',seuil=0.2))
#
# <ipython-input-42-e40108bbb51d> in is_good_pred_top_k(lemme, k, model, tokenizer, multilabel_binarizer)
#      72
#      73 def is_good_pred_top_k(lemme,k=5,model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
# ---> 74     pred_y = lemme_pred_top_k(lemme,k,model,tokenizer)
#      75
#      76     pred_y_ones = np.where(pred_y==1)[0]
#
# <ipython-input-42-e40108bbb51d> in lemme_pred_top_k(lemme, k, model, tokenizer, max_length)
#      44     print(model.input_shape[1])
#      45
# ---> 46     y_pred = model.predict(padded_docs)[0]
#      47     pred_sort = sorted(y_pred)[::-1]
#      48     index_top_k=[list(y_pred).index(pred_sort[i]) for i in range(k)]
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected input_1 to have shape (95,) but got array with shape (20,)

# %%
def test_pred(seuil=0.05,model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
    sum_res=0
    size=0
    fail_size=0
    total_precision=None
    total_prop_classe=None
    for chapter in geocoq :
        for lemme in geocoq[chapter] :
            if lemme in th_valid :
                (res,prop_classe) = is_good_pred(lemme,seuil,model,tokenizer,multilabel_binarizer)
                if res==1 :
                    sum_res+=1
                else :
                    if total_precision is None :
                        total_precision=res
                    else :
                        total_precision+=res
                    fail_size+=1
                if total_prop_classe is None :
                    total_prop_classe=prop_classe
                else :
                    total_prop_classe+=prop_classe
                size+=1
    if total_precision is None :
        total_precision=0
    if total_prop_classe is None :
        total_prop_classe=0
    return (sum_res/size,total_prop_classe/size,total_precision/fail_size)

def test_pred_top_k(k=5,model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
    sum_res=0
    size=0
    fail_size=0
    total_precision=None
    total_prop_classe=None
    for chapter in geocoq :
        for lemme in geocoq[chapter] :
            if lemme in th_valid :
                (res,prop_classe) = is_good_pred_top_k(lemme,k,model,tokenizer,multilabel_binarizer)
                if res==1 :
                    sum_res+=1
                else :
                    if total_precision is None :
                        total_precision=res
                    else :
                        total_precision+=res
                    fail_size+=1
                if total_prop_classe is None :
                    total_prop_classe=prop_classe
                else :
                    total_prop_classe+=prop_classe
                size+=1
    if total_precision is None :
        total_precision=0
    if total_prop_classe is None :
        total_prop_classe=0
    return (sum_res/size,total_prop_classe/size,total_precision/fail_size)

# %%
def find_seuil(model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
    seuil_table=[]
    acc_table=[]
    prop_table=[]
    prev_seuil=0
    seuil=0.5
    accuracy=0
    prop_classe=0.5
    while(accuracy < 1 and prop_classe < 1 and abs(seuil-prev_seuil) > 1e-6) :
        (accuracy,prop_classe,precision) = test_pred(seuil,model,tokenizer,multilabel_binarizer)
        new_seuil=abs(seuil-prev_seuil)/2
        prev_seuil=seuil
        seuil=new_seuil
        seuil_table.append(seuil)
        acc_table.append(accuracy)
        prop_table.append(prop_classe)
        print(seuil,accuracy,prop_classe)
    return seuil_table,acc_table,prop_table

def find_seuil_top_k(model=model,tokenizer=t,multilabel_binarizer=multilabel_binarizer) :
    seuil_table=[]
    acc_table=[]
    prop_table=[]
    prev_seuil=0
    k=0
    accuracy=0
    prop_classe=0.5
    while(accuracy < 1 and prop_classe < 1 and k < len(multilabel_binarizer.classes_)) :
        (accuracy,prop_classe,precision) = test_pred_top_k(k,model,tokenizer,multilabel_binarizer)
        seuil_table.append(k)
        acc_table.append(accuracy)
        prop_table.append(prop_classe)
        print(k,accuracy,prop_classe)
        k=k+k//10+1
    return seuil_table,acc_table,prop_table

# %%
seuil_table,acc_table,prop_table=find_seuil_top_k()
x=seuil_table
y1=acc_table
y2=prop_table
plt.plot(x,y1,linewidth=2.0,label = "théorèmes dont toutes les prémisses sont prédites/ensemble des théorèmes")
plt.plot(x,y2,linewidth=2.0,label = "premisses selectionnées/prémisses total")
plt.legend()
# Out:
# 0 0.0 0.0
# 1 0.07050359712230216 0.0014025245441795437
# 2 0.17266187050359713 0.0028050490883590874
# 3 0.25755395683453236 0.004207573632538547
# 4 0.3366906474820144 0.005610098176718175
# 5 0.41294964028776976 0.007012622720897554
# 6 0.4805755395683453 0.008415147265077094
# 7 0.5251798561151079 0.009817671809256818
# 8 0.5669064748201439 0.01122019635343635
# 9 0.5928057553956835 0.012622720897615734
# 10 0.6115107913669064 0.014025245441795108
# 12 0.6589928057553956 0.016830294530154187
# 14 0.6964028776978417 0.019635343618513636
# 16 0.7251798561151079 0.0224403927068727
# 18 0.7352517985611511 0.025245441795231468
# 20 0.7410071942446043 0.028050490883590216
# 23 0.7654676258992805 0.032258064516129066
# 26 0.7798561151079136 0.03646563814866717
# 29 0.7899280575539568 0.04067321178120668
# 32 0.7985611510791367 0.0448807854137454
# 36 0.8115107913669065 0.050490883590462936
# 40 0.814388489208633 0.05610098176718043
# 45 0.8287769784172662 0.0631136044880785
# 50 0.837410071942446 0.07012622720897543
# 56 0.8474820143884892 0.07854137447405454
# 62 0.8532374100719424 0.08695652173913115
# 69 0.8546762589928057 0.09677419354838594
# 76 0.860431654676259 0.10659186535764328
# 84 0.8633093525179856 0.1178120617110789
# 93 0.8705035971223022 0.13043478260869745
# 103 0.8733812949640288 0.14446002805048952
# 114 0.879136690647482 0.15988779803646488
# 126 0.8820143884892087 0.17671809256661766
# 139 0.8848920863309353 0.19495091164095518
# 153 0.8877697841726618 0.21458625525946462
# 169 0.8964028776978418 0.2370266479663398
# 186 0.9007194244604316 0.2608695652173949
# 205 0.9035971223021583 0.28751753155680154
# 226 0.9079136690647482 0.3169705469845761
# 249 0.9093525179856116 0.3492265934797778
# 274 0.9122302158273381 0.3842856710424057
# 302 0.9122302158273381 0.42355434025851246
# 333 0.9122302158273381 0.4670305831071493
# 367 0.9179856115107914 0.514708345525537
# 404 0.9194244604316547 0.566591663555557
# 445 0.9309352517985612 0.6240770076785642
# 490 0.9410071942446043 0.68716639591552
# 540 0.9525179856115108 0.7572643708315354
# 595 0.9669064748201439 0.8343830405521221
# 655 0.9856115107913669 0.918528459140115

# %%
def write_dep(th,rew,dep_file):
    with open(dep_file,"w+") as dep_f :
        dep_f.write("lemme :")
        for th in list(set(th_dep)) :
            dep_f.write(" "+th)
            
        dep_f.write("\nrewrite :")
        for rew in list(set(rew_dep)) :
            dep_f.write(" "+rew)

def dot_to_dep(dot_file,dep_file) :
    th_dep=[]
    rew_dep=[]
    ensure_dir(dep_file)
    with open(dot_file,"r") as dot_f :
        lines = dot_f.readlines()
        for line in lines :
            for word in types :
                if "\\\"Label"+word+"\\\"" in line :
                    rew_dep.append(word)
            for word in all_th :
                if "\\\"Label"+word+"\\\"" in line :
                    th_dep.append(word)
    write_dep(th,rew,dep_file)


            
def copy_dep(dep_file_from,dep_file_to) :
    ensure_dir(dep_file_to)
    copyfile(dep_file_from, dep_file_to)
    
    
def init_dep(dep_file) :
    ensure_dir(dep_file)
    with open(dep_file,"w+") as dep_f :
        dep_f.write("lemme :")
        dep_f.write("\nrewrite :")

# %%
def dep_to_zf(lemme,dep_file_name,zf_file_name) :
    
    dep_list=dep_to_list(dep_file_name)
    
    ensure_dir(zf_file_name)
    f=open(zf_file_name,"w+")
    f.write("include \"../tarski_term_def.zf\".\n")
    for dep in dep_list :
        if dep in all_th :
            if dep==lemme :
                f.write("#include itself\n")
            else :
                f.write("#"+dep+"\n")
                f.write(ax_th_declaration[dep])
        if dep in types :
            f.write(rewrite_declaration[dep])
            
    f.write("goal "+th_declaration_to_text(ax_th_declaration[lemme]))
    f.close()

# %%
def lemme_pred_to_dep(lemme,dep_file_name,seuil=0.05,model=model,tokenizer=t,max_length=max_length,multilabel_binarizer=multilabel_binarizer) :
    pred=lemme_pred(lemme,seuil,model=model,tokenizer=t,max_length=max_length)
    deps = multilabel_binarizer.inverse_transform(np.array([pred]))[0]
    th,rew=[]
    for dep in deps :
        if dep in all_th :
            th.append(dep)
        if dep in types :
            rew.append(dep)
    write_dep(th,rew,dep_file_name)
    
def th_string_pred_to_zf(th_string,zf_file_name,seuil=0.05,model=model,tokenizer=t,max_length=max_length,multilabel_binarizer=multilabel_binarizer) :
    pred=th_string_to_pred(th_string,seuil,model=model,tokenizer=t,max_length=max_length)
    deps = multilabel_binarizer.inverse_transform(np.array([pred]))[0]
    ensure_dir(zf_file_name)
    f=open(zf_file_name,"w+")
    f.write("include \"../tarski_term_def.zf\".\n")
    if (set(deps) & set(grid_ok)) :
        f.write("val O : point.\nval E : point.\nval E1 : point.\nassert ~Col O E E1.\n")
    for dep in deps :
        if dep in all_th :
            f.write("#"+dep+"\n")
            f.write(ax_th_declaration[dep])
        if dep in types :
            f.write(rewrite_declaration[dep])
            
    f.write("goal "+th_declaration_to_text(th_string))
    f.close()
    
def lemme_pred_to_zf(lemme,zf_file_name=None,seuil=0.05,model=model,tokenizer=t,max_length=max_length,multilabel_binarizer=multilabel_binarizer) :
    pred=lemme_pred(lemme,seuil,model=model,tokenizer=t,max_length=max_length)
    deps = multilabel_binarizer.inverse_transform(np.array([pred]))[0]
    if zf_file_name is None :
        zf_file_name=zf_dir_path+get_chapter(lemme)+"/"+lemme+".zf"
    ensure_dir(zf_file_name)
    f=open(zf_file_name,"w+")
    f.write("include \"../tarski_term_def.zf\".\n")
    if (set(deps) & set(grid_ok)) :
        f.write("val O : point.\nval E : point.\nval E1 : point.\nassert ~Col O E E1.\n")
    for dep in deps :
        if dep in all_th :
            if dep==lemme :
                f.write("#include itself\n")
            else :
                f.write("#"+dep+"\n")
                f.write(ax_th_declaration[dep])
        if dep in types :
            f.write(rewrite_declaration[dep])
            
    f.write("goal "+th_declaration_to_text(ax_th_declaration[lemme]))
    f.close()
    
def th_string_to_zf_top_k(th_string,zf_file_name,k=5,model=model,tokenizer=t,max_length=max_length,multilabel_binarizer=multilabel_binarizer) :
    pred=th_string_to_pred_top_k(th_string,k,model=model,tokenizer=t,max_length=max_length)
    deps = multilabel_binarizer.inverse_transform(np.array([pred]))[0]
    ensure_dir(zf_file_name)
    f=open(zf_file_name,"w+")
    f.write("include \"../tarski_term_def.zf\".\n")
    if (set(deps) & set(grid_ok)) :
        f.write("val O : point.\nval E : point.\nval E1 : point.\nassert ~Col O E E1.\n")
    for dep in deps :
        if dep in all_th :
            f.write("#"+dep+"\n")
            f.write(ax_th_declaration[dep])
        if dep in types :
            f.write(rewrite_declaration[dep])
            
    f.write("goal "+th_declaration_to_text(th_string))
    f.close()
    
def lemme_pred_to_zf_top_k(lemme,zf_file_name=None,k=5,model=model,tokenizer=t,max_length=max_length,multilabel_binarizer=multilabel_binarizer) :
    pred=lemme_pred_top_k(lemme,k,model=model,tokenizer=t,max_length=max_length)
    deps = multilabel_binarizer.inverse_transform(np.array([pred]))[0]
    if zf_file_name is None :
        zf_file_name=zf_dir_path+get_chapter(lemme)+"/"+lemme+".zf"
    ensure_dir(zf_file_name)
    f=open(zf_file_name,"w+")
    f.write("include \"../tarski_term_def.zf\".\n")
    if (set(deps) & set(grid_ok)) :
        f.write("val O : point.\nval E : point.\nval E1 : point.\nassert ~Col O E E1.\n")
    for dep in deps :
        if dep in all_th :
            if dep==lemme :
                f.write("#include itself\n")
            else :
                f.write("#"+dep+"\n")
                f.write(ax_th_declaration[dep])
        if dep in types :
            f.write(rewrite_declaration[dep])
            
    f.write("goal "+th_declaration_to_text(ax_th_declaration[lemme]))
    f.close()

# %%
def all_dep_to_zf(dep_dir,zf_dir) :
    no_dep=[]
    nb_convert=0
    if os.path.exists(dep_dir) :
        for chapter in geocoq :
            ensure_dir(zf_dir+chapter)
            for lemme in geocoq[chapter] :
                if os.path.exists(dep_dir+chapter+"/"+lemme+".dep") :
                    nb_convert+=1
                    dep_to_zf(lemme,dep_dir+chapter+"/"+lemme+".dep",zf_dir+chapter+"/"+lemme+".zf")
        print("nb_file_converted = "+str(nb_convert))
    else :
        print("no such directory : "+dep_dir)

# %% [raw]
# all_dep_to_zf("./dependencies_geocoq/","./zf_geocoq/")

# %% [raw]
# lemme_pred_to_zf('cong_reflexivity',seuil=0.6)

# %% [raw]
# zf_dir_path="./unbalanced_v2_zf/"
#
# for chapter in geocoq :
#     for lemme in geocoq[chapter] :
#         if lemme in th_valid :
#             lemme_pred_to_zf(lemme,seuil=0.01)

# %%
n_jobsZ=6

semZ = Semaphore(n_jobsZ)
lockZ = RLock()

zipper_exec_time=dict()

class Zipperposition(Thread):

    def __init__(self, zf_dir,chapter,lemme):
        Thread.__init__(self)
        self.zf_dir=zf_dir
        self.chapter=chapter
        self.lemme=lemme

    def run(self):
        global zipper_exec_time
        t=time.time()
        lemme_file=self.zf_dir+self.chapter+"/"+self.lemme
        if os.path.isfile(lemme_file+".zf") :
            res=os.popen("zipperposition -o none --mem-limit 4000 --timeout 30 --dot "+lemme_file+".dot "+lemme_file+".zf").read()
            with lockZ :
                if res.endswith("output end Refutation\n") :
                    print(self.lemme+" : Valid")
                    zipper_exec_time[self.chapter][self.lemme]=(time.time()-t)
                else:
                    print(self.lemme+" : Error")
                    zipper_exec_time[self.chapter][self.lemme]=res
        else :
            with lockZ :
                print("FileNotFoundError : "+lemme_file+".zf")

# %%
#zf_dir_path="./unbalanced_v2_zf/"

threads=[]

for chapter in geocoq :
    
    zipper_exec_time[chapter]=dict()
    
    for lemme in geocoq[chapter] :
        #if lemme in th_valid :
            threads.append(Zipperposition(zf_dir_path,chapter,lemme))

for i in range(len(threads)):
    with semZ :
        threads[i].start()

for i in range(len(threads)):
    threads[i].join()
print("done")
# Out:
# cong_transitivity : Valid
# cong_symmetry : Valid
# cong_3421 : Valid
# cong_right_commutativity : Valid
# cong_reflexivity : Valid
# cong_left_commutativity : Valid
# cong_4312 : Valid
# cong_4321 : Valid
# cong_commutativity : Valid
# cong_reverse_identity : Valid
# cong_trivial_identity : Valid
# not_cong_2134 : Valid
# not_cong_1243 : Valid
# not_cong_3412 : Valid
# not_cong_2143 : Valid
# not_cong_4312 : Valid
# not_cong_4321 : Valid
# not_cong_3421 : Valid
# five_segment_with_def : Valid
# cong_diff : Valid
# cong_diff_2 : Valid
# cong_diff_4 : Valid
# cong_3_sym : Valid
# cong_diff_3 : Valid
# cong_3_swap : Valid
# cong3_transitivity : Valid
# eq_dec_points : Valid
# cong_3_swap_2 : Valid
# l2_11 : Valid
# bet_cong3 : Valid
# between_trivial : Valid
# construction_uniqueness : Valid
# Cong_perm : Valid
# Cong_cases : Valid
# Bet_perm : Valid
# bet_col : Valid
# between_symmetry : Valid
# between_trivial2 : Valid
# Bet_cases : Valid
# between_equality_2 : Valid
# between_equality : Valid
# bet_neq21__neq : Valid
# bet_neq32__neq : Valid
# bet_neq12__neq : Valid
# between_exchange3 : Valid
# between_inner_transitivity : Valid
# bet_neq23__neq : Valid
# outer_transitivity_between2 : Valid
# between_exchange4 : Valid
# between_exchange2 : Valid
# not_bet_distincts : Valid
# outer_transitivity_between : Valid
# l_3_9_4 : Valid
# point_construction_different : Valid
# l3_17 : Valid
# lower_dim_ex : Valid
# two_distinct_points : Valid
# cong_dec_eq_dec_b : Valid
# l2_11_b : Valid
# another_point : Valid
# BetSEq : Valid
# bet_dec_eq_dec_b : Valid
# col_permutation_2 : Valid
# col_permutation_4 : Valid
# col_permutation_1 : Valid
# col_permutation_5 : Valid
# col_permutation_3 : Valid
# not_col_permutation_1 : Valid
# not_col_permutation_2 : Valid
# not_col_permutation_3 : Valid
# not_col_permutation_4 : Valid
# not_col_permutation_5 : Valid
# Col_cases : Valid
# col_trivial_1 : Valid
# Col_perm : Valid
# col_trivial_3 : Valid
# col_trivial_2 : Valid
# l4_13 : Valid
# l4_14 : Valid
# l4_19 : Valid
# not_col_distincts : Valid
# l4_17 : Valid
# l4_18 : Valid
# NCol_cases : Valid
# NCol_perm : Valid
# col_cong_3_cong_3_eq : Valid
# l4_3 : Valid
# l4_3_1 : Valid
# cong3_bet_eq : Valid
# le_bet : Valid
# l5_5_1 : Valid
# l5_5_2 : Valid
# le_reflexivity : Valid
# le_transitivity : Valid
# cong3_symmetry : Valid
# between_cong_2 : Error
# Cong_dec : Valid
# Col_dec : Valid
# bet_dec : Valid
# le_trivial : Valid
# le_zero : Valid
# lt_diff : Error
# le_diff : Valid
# bet_cong_eq : Valid
# cong__le : Error
# cong__le3412 : Valid
# le_left_comm : Valid
# le1221 : Valid
# le_right_comm : Valid
# ge_left_comm : Valid
# le_comm : Valid
# ge_right_comm : Valid
# lt_right_comm : Valid
# ge_comm : Valid
# l5_6 : Valid
# lt_left_comm : Valid
# gt_left_comm : Valid
# lt_comm : Valid
# gt_right_comm : Valid
# gt_comm : Valid
# cong2_lt__lt : Error
# third_point : Error
# l5_12_a : Valid
# bet__le1213 : Valid
# bet__le2313 : Valid
# bet__lt1213 : Error
# l5_12_b : Valid
# bet__lt2313 : Error
# bet_le_eq : Valid
# or_lt_cong_gt : Valid
# lt__le : Valid
# le3456_lt__lt : Error
# lt_transitivity : Valid
# le1234_lt__lt : Error
# not_and_lt : Error
# nlt : Valid
# le__nlt : Valid
# cong__nlt : Valid
# l4_6 : Error
# le_anti_symmetry : Error
# l5_3 : Error
# l5_2 : Error
# between_cong : Error
# between_cong_3 : Error
# l4_5 : Error
# l4_2 : Error
# segment_construction_2 : Error
# l5_1 : Error
# fourth_point : Error
# l4_16 : Error
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-254-ed48b9f335b7> in <module>
#      13 for i in range(len(threads)):
#      14     with semZ :
# ---> 15         threads[i].start()
#      16
#      17 for i in range(len(threads)):
#
# ~/anaconda3/lib/python3.7/threading.py in start(self)
#     850                 del _limbo[self]
#     851             raise
# --> 852         self._started.wait()
#     853
#     854     def run(self):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# nlt__le : Error
# lt__nle : Error

# %%
def get_zipper_stat(zipper_exec_time):
    done=[]
    notdone=[]
    gaveup=[]
    ressourceout=[]
    timeout=[]
    for chapter in zipper_exec_time :
        for lemme in zipper_exec_time[chapter] :
            if isinstance(zipper_exec_time[chapter][lemme],float) :
                done.append(lemme)
            else :
                if "GaveUp" in zipper_exec_time[chapter][lemme] :
                    gaveup.append(lemme)
                else :
                    if "for" in zipper_exec_time[chapter][lemme] :
                        timeout.append(lemme)
                    else :
                        ressourceout.append(lemme)
                notdone.append(lemme)
    return (done,notdone,gaveup,ressourceout,timeout)

# %%
def zipper_stat(done,notdone,gaveup,ressourceout,timeout):
    res = str(len(done)/(len(done)+len(notdone))*100)+"% good to go = "+str(len(notdone))
    if len(notdone) > 0 :
        res+=" GaveUp = "+str(len(gaveup)/len(notdone)*100)+" TimeOut = "+str(len(timeout)/len(notdone)*100)+" RessourceOut = "+str(len(ressourceout)/len(notdone)*100)+" size = "+str(len(done)+len(notdone))
    return res

# %% [raw]
# zf_dir_new="./dependencies_geocoq_grid_ok/"
# for chapter in geocoq :
#     for lemme in geocoq[chapter] :
#         if lemme in done :
#             dot_file=zf_dir_path+chapter+"/"+lemme+".dot"
#             lemme_file=zf_dir_new+chapter+"/"+lemme+".dep"
#             dot_to_dep(dot_file,lemme_file)

# %%
avg_val=0
nb=0
for lemme in gaveup+ressourceout+timeout :
    (val,res)=is_good_pred(lemme,0.01)
    if val != 1 :
        avg_val+=val
        nb+=1
        print(lemme,val)
print(avg_val/nb)
# Out:
# not_cong_2134 0.5
# not_cong_1243 0.5
# not_cong_4321 0.5
# not_cong_4312 0.5
# not_cong_2143 0.5
# not_cong_3421 0.5
# cong_diff_4 0.5
# cong_diff_3 0.5
# cong_3_swap 0.6666666666666666
# col_permutation_3 0.5
# col_permutation_5 0.5
# not_col_permutation_1 0.5
# not_col_permutation_2 0.5
# col_permutation_4 0.5
# not_col_permutation_4 0.5
# not_col_permutation_3 0.5
# not_col_distincts 0.0
# le_diff 0.0
# bet_le_eq 0.0
# bet_out 0.5
# out_cong_cong 0.5714285714285714
# not_bet_and_out 0.3333333333333333
# midpoint_distinct_1 0.6666666666666666
# midpoint_distinct_2 0.6666666666666666
# midpoint_def 0.0
# midpoint_distinct_3 0.6666666666666666
# midpoint_not_midpoint 0.0
# l8_9 0.42857142857142855
# perp_in_distinct 0.0
# l8_15_2 0.0
# l8_22_bis 0.25
# col_per_perp 0.42857142857142855
# perp_not_col 0.125
# l9_9 0.0
# l9_9_bis 0.3333333333333333
# one_side_chara 0.0
# l9_10 0.7
# cong3_diff 0.5
# cong3_diff2 0.5
# conga__lea456123 0.5
# obtuse_sym 0.0
# l11_44_2 0.3333333333333333
# lta_diff 0.25
# par_strict_irreflexivity 0.5
# Par_perm 0.5
# par_strict_one_side 0.0
# l12_18_b 0.09090909090909091
# l12_18_d 0.1
# par_col_par 0.5714285714285714
# perp_per_bet 0.0
# perp2_left_comm 0.3333333333333333
# perp2_right_comm 0.6666666666666666
# perp2_comm 0.3333333333333333
# not_cong_is_len 0.0
# null_ang 0.0
# out_is_len_eq 0.6
# anga_distincts 0.25
# anga_sym 0.0
# anga_acute 0.0
# out_null_ang 0.6666666666666666
# bet_flat_ang 0.0
# anga_col_out 0.0
# lcos_const 0.5
# flat_not_acute 0.08333333333333333
# lcos2_lg_not_null 0.5
# lcos3_uniqueness 0.75
# lcos3_lg_not_null 0.5
# lcos2_lg_anga 0.0
# prod_uniquenessB 0.0
# diff_2_prod 0.0
# ltP_sum_pos 0.5
# bet2_out_out 0.3333333333333333
# l8_12 0.5
# perp_in_per 0.6666666666666666
# perp_in_sym 0.5
# l10_7 0.0
# conga_trivial_1 0.0
# col_conga__conga 0.375
# not_null_ang_def_equiv 0.8
# l4_14 0.6666666666666666
# l5_5_2 0.0
# l5_12_b 0.7777777777777778
# l7_22 0.3333333333333333
# perp_sym 0.5
# perp_not_col2 0.8571428571428571
# l9_18 0.9
# is_image_is_image_spec 0.0
# exists_cong_per 0.9166666666666666
# cong3_preserves_out 0.6
# angle_construction_2 0.8666666666666667
# lea_line 0.25
# out_lea__out 0.5
# cong__acute 0.5
# parallel_existence1 0.5
# col_not_col_not_par 0.8333333333333334
# par_col2_par 0.16666666666666666
# par_two_sides_two_sides 0.125
# l12_20 0.3333333333333333
# null_anga 0.2
# ang_distincts 0.75
# acute_not_bet 0.6923076923076923
# out_out_anga 0.0
# acute_not_obtuse 0.0
# lcos_lg_distincts 0.6666666666666666
# l13_10_aux1 0.34285714285714286
# lcos2_lcos 0.5
# diff_null_eq 0.75
# length_id_1 0.6666666666666666
# length_id 0.3333333333333333
# 0.37678282471860464

# %%
def tactics(list_of_lemme=th_valid,seuil=0.9, nb_iter=100) :
    
    if not(list_of_lemme and nb_iter > 0 and seuil > 0.00001) : #possède au moins un élément
        return []
    
    global zipper_exec_time
    print("size_of_echantillon =",len(list_of_lemme))
    print("starting")
    
    zipper_exec_time=dict()
    
    print("create files")
    
    for chapter in geocoq :
        for lemme in geocoq[chapter] :
            if lemme in list_of_lemme :
                lemme_pred_to_zf(lemme,seuil=seuil)
                
    print("file created")
                
    threads=[]

    for chapter in geocoq :

        zipper_exec_time[chapter]=dict()

        for lemme in geocoq[chapter] :
            if lemme in list_of_lemme :
                threads.append(Zipperposition(zf_dir_path,chapter,lemme))

    for i in range(len(threads)):
        with semZ :
            threads[i].start()

    for i in range(len(threads)):
        threads[i].join()
    
    done,notdone,gaveup,ressourceout,timeout = get_zipper_stat(zipper_exec_time)
    
    print("iter remaining : "+str(nb_iter))
    print(zipper_stat(done,notdone,gaveup,ressourceout,timeout))

    data_list = tactics(list_of_lemme=notdone,seuil=seuil/1.2,nb_iter=nb_iter-1)
    return [[seuil,done,notdone,gaveup,ressourceout,timeout]]+data_list

# %%
def tactics_top_k(list_of_lemme=th_valid,k=0, nb_iter=100) :
    
    if not(list_of_lemme and nb_iter > 0 and k < 180) : #possède au moins un élément
        return []
    
    global zipper_exec_time
    print("size_of_echantillon =",len(list_of_lemme))
    print("starting")
    
    zipper_exec_time=dict()
    
    print("create files")
    
    for chapter in geocoq :
        for lemme in geocoq[chapter] :
            if lemme in list_of_lemme :
                lemme_pred_to_zf_top_k(lemme,k=k)
                
    print("file created")
                
    threads=[]

    for chapter in geocoq :

        zipper_exec_time[chapter]=dict()

        for lemme in geocoq[chapter] :
            if lemme in list_of_lemme :
                threads.append(Zipperposition(zf_dir_path,chapter,lemme))

    for i in range(len(threads)):
        with semZ :
            threads[i].start()

    for i in range(len(threads)):
        threads[i].join()
    
    done,notdone,gaveup,ressourceout,timeout = get_zipper_stat(zipper_exec_time)
    
    print("k="+str(k))
    print(zipper_stat(done,notdone,gaveup,ressourceout,timeout))

    data_list = tactics_top_k(list_of_lemme=notdone,k=k+k//10+1,nb_iter=nb_iter-1)
    return [[k,done,notdone,gaveup,ressourceout,timeout]]+data_list

# %%
first_iter=0
last_iter=3
zf_dir_path="./zf_geocoq_pred_grid_ok/"
data=tactics(set(all_th)-set(tarski))
# Out:
# size_of_echantillon = 1242
# starting
# create files
# file created
# cong_right_commutativity : Error
# cong_transitivity : Error
# cong_left_commutativity : Error
# cong_reflexivity : Error
# cong_symmetry : Error
# cong_3421 : Error
# cong_4312 : Error
# cong_trivial_identity : Error
# cong_reverse_identity : Error
# cong_4321 : Error
# cong_commutativity : Error
# not_cong_2134 : Error
# not_cong_3412 : Valid
# not_cong_1243 : Error
# not_cong_2143 : Error
# not_cong_4312 : Error
# not_cong_3421 : Error
# five_segment_with_def : Error
# cong_diff : Valid
# not_cong_4321 : Error
# cong_diff_3 : Error
# cong_diff_4 : Error
# cong_diff_2 : Valid
# cong_3_swap : Error
# cong_3_sym : Valid
# cong3_transitivity : Error
# cong_3_swap_2 : Error
# eq_dec_points : Valid
# bet_cong3 : Error
# construction_uniqueness : Error
# l2_11 : Error
# bet_col : Valid
# Cong_cases : Error
# Cong_perm : Error
# between_trivial : Error
# Bet_cases : Valid
# Bet_perm : Valid
# between_symmetry : Error
# between_trivial2 : Error
# between_equality_2 : Error
# between_equality : Error
# between_exchange3 : Error
# bet_neq21__neq : Error
# bet_neq12__neq : Error
# bet_neq23__neq : Error
# bet_neq32__neq : Error
# not_bet_distincts : Error
# between_exchange2 : Error
# between_inner_transitivity : Error
# outer_transitivity_between2 : Error
# outer_transitivity_between : Error
# between_exchange4 : Error
# lower_dim_ex : Valid
# l_3_9_4 : Error
# l3_17 : Error
# two_distinct_points : Error
# point_construction_different : Error
# l2_11_b : Error
# another_point : Error
# cong_dec_eq_dec_b : Valid
# bet_dec_eq_dec_b : Valid
# BetSEq : Error
# not_col_permutation_2 : Error
# col_permutation_1 : Valid
# col_permutation_4 : Error
# col_permutation_3 : Error
# not_col_permutation_3 : Error
# col_permutation_2 : Valid
# col_permutation_5 : Error
# not_col_permutation_1 : Error
# not_col_permutation_4 : Error
# not_col_permutation_5 : Error
# Col_cases : Valid
# Col_perm : Error
# col_trivial_2 : Error
# col_trivial_1 : Error
# l4_13 : Error
# l4_14 : Error
# col_trivial_3 : Error
# l4_17 : Error
# l4_18 : Error
# l4_16 : Error
# l4_19 : Error
# NCol_cases : Valid
# not_col_distincts : Error
# NCol_perm : Error
# l4_3 : Error
# col_cong_3_cong_3_eq : Error
# l4_3_1 : Error
# l4_2 : Error
# l4_5 : Error
# l4_6 : Error
# l5_2 : Error
# cong3_bet_eq : Error
# l5_5_1 : Error
# le_bet : Error
# l5_3 : Error
# segment_construction_2 : Error
# l5_1 : Error
# l5_5_2 : Error
# l5_6 : Error
# between_cong : Error
# cong3_symmetry : Valid
# between_cong_3 : Error
# le_transitivity : Error
# le_reflexivity : Error
# Cong_dec : Valid
# le_anti_symmetry : Error
# bet_dec : Valid
# between_cong_2 : Error
# Col_dec : Valid
# le_trivial : Error
# le_zero : Error
# le_diff : Valid
# bet_cong_eq : Error
# lt_diff : Error
# cong__le : Error
# cong__le3412 : Error
# le1221 : Error
# le_left_comm : Error
# le_right_comm : Error
# le_comm : Error
# ge_left_comm : Error
# ge_right_comm : Error
# ge_comm : Error
# lt_right_comm : Error
# lt_left_comm : Error
# lt_comm : Error
# gt_left_comm : Error
# gt_right_comm : Error
# gt_comm : Error
# cong2_lt__lt : Error
# bet__le1213 : Valid
# third_point : Error
# fourth_point : Error
# l5_12_a : Error
# bet__le2313 : Valid
# bet__lt1213 : Error
# bet__lt2313 : Error
# bet_le_eq : Error
# or_lt_cong_gt : Error
# le3456_lt__lt : Error
# le1234_lt__lt : Error
# l5_12_b : Error
# lt__le : Valid
# not_and_lt : Error
# nlt : Valid
# le__nlt : Error
# lt_transitivity : Valid
# cong__nlt : Error
# nlt__le : Error
# nle__lt : Error
# lt__nle : Error
# lt1123 : Error
# bet2_le2__le : Error
# le_cases : Error
# bet_out : Error
# out_dec : Valid
# out_diff1 : Error
# out_diff2 : Error
# out_distinct : Error
# l6_2 : Error
# bet_out__bet : Error
# out_col : Error
# l6_3_1 : Error
# l6_3_2 : Error
# l6_6 : Error
# out_trivial : Error
# l6_4_2 : Error
# bet_out_out_bet : Error
# l6_7 : Error
# out2_bet_out : Error
# l6_4_1 : Error
# l6_11_uniqueness : Error
# l6_11_existence : Error
# l6_13_1 : Error
# segment_construction_3 : Error
# col_transitivity_1 : Error
# l6_13_2 : Error
# l6_16_1 : Error
# col_transitivity_2 : Error
# out2__bet : Error
# not_col_exists : Error
# bet2_le2__le1346 : Error
# bet2_le2__le2356 : Error
# out_cong_cong : Error
# bet2_le2__le1245 : Error
# cong_preserves_bet : Error
# not_bet_out : Error
# or_bet_out : Error
# not_out_bet : Error
# not_bet_and_out : Error
# out_to_bet : Error
# col_out2_col : Error
# bet2_out_out : Error
# col3 : Error
# out2_out_1 : Error
# out2_out_2 : Error
# out_bet_out_1 : Error
# out_bet__out : Error
# out_bet_out_2 : Error
# is_midpoint_id : Error
# is_midpoint_dec : Valid
# l7_2 : Error
# l7_3 : Error
# is_midpoint_id_2 : Error
# symmetric_point_construction : Error
# l7_9 : Error
# l7_9_bis : Error
# symmetric_point_uniqueness : Error
# l7_3_2 : Error
# l7_13 : Error
# l7_15 : Error
# l7_16 : Error
# symmetry_preserves_midpoint : Error
# Mid_cases : Error
# Mid_perm : Error
# l7_17_bis : Error
# l7_17 : Error
# l7_20_bis : Valid
# l7_20 : Error
# cong_col_mid : Error
# l7_22_aux : Error
# l7_21 : Error
# l7_22 : Error
# bet_col1 : Error
# midpoint_distinct_1 : Error
# l7_25 : Error
# midpoint_distinct_3 : Error
# midpoint_distinct_2 : Error
# midpoint_def : Error
# midpoint_bet : Error
# midpoint_cong : Error
# midpoint_col : Error
# swap_diff : Valid
# cong_cong_half_1 : Error
# cong_cong_half_2 : Error
# midpoint_not_midpoint : Error
# cong_mid2__cong : Error
# mid__lt : Error
# le_mid2__le12 : Error
# le_mid2__le13 : Error
# lt_mid2__lt12 : Error
# lt_mid2__lt13 : Error
# midpoint_preserves_out : Error
# col_cong2_bet1 : Error
# col_cong2_bet2 : Error
# col_cong_bet : Error
# col_bet2_cong1 : Error
# col_bet2_cong2 : Error
# col_cong2_bet3 : Error
# col_cong2_bet4 : Error
# bet2_lt_le__lt : Error
# bet2_lt2__lt : Error
# l8_2 : Error
# Per_dec : Valid
# l8_3 : Error
# Per_perm : Error
# l8_5 : Error
# l8_4 : Error
# Per_cases : Error
# l8_6 : Error
# l8_7 : Error
# l8_8 : Error
# l8_9 : Error
# l8_10 : Error
# col_col_per_per : Error
# perp_distinct : Error
# Perp_in_dec : Valid
# per_col : Error
# l8_12 : Error
# l8_13_2 : Error
# l8_14_1 : Error
# l8_14_2_1a : Valid
# perp_in_distinct : Valid
# l8_14_2_1b : Error
# l8_14_2_1b_bis : Error
# l8_14_2_2 : Error
# l8_14_3 : Error
# l8_15_1 : Error
# perp_col0 : Error
# perp_sym : Error
# per_perp_in : Error
# per_perp : Error
# l8_15_2 : Error
# perp_in_per : Error
# l8_16_1 : Error
# perp_left_comm : Error
# perp_right_comm : Error
# perp_comm : Error
# perp_in_left_comm : Error
# perp_in_right_comm : Error
# perp_in_comm : Error
# perp_in_sym : Error
# Perp_cases : Valid
# Perp_perm : Error
# Perp_in_cases : Valid
# l8_18_uniqueness : Error
# Perp_in_perm : Error
# l8_18_existence : Error
# perp_col1 : Error
# l8_20_2 : Error
# midpoint_distinct : Error
# l8_16_2 : Error
# l8_20_1 : Error
# l8_21_aux : Error
# perp_in_col : Error
# l8_21 : Error
# perp_per_2 : Error
# perp_perp_in : Error
# perp_per_1 : Error
# perp_not_eq_1 : Error
# perp_col : Error
# perp_col2 : Error
# diff_per_diff : Error
# perp_not_eq_2 : Error
# per_not_col : Error
# perp_cong : Error
# per_not_colp : Error
# midpoint_existence_aux : Error
# per_cong : Error
# midpoint_existence : Error
# perp_in_id : Error
# l8_22_bis : Error
# l8_22 : Error
# perp_in_perp : Error
# perp_proj : Error
# perp_not_col : Error
# perp_not_col2 : Error
# l8_24 : Error
# perp_in_col_perp_in : Error
# perp_col2_bis : Error
# perp_in_perp_bis : Error
# col_per_perp : Error
# per_double_cong : Error
# cong_perp_or_mid : Error
# invert_two_sides : Error
# per_cong_mid : Error
# col_per2_cases : Error
# sym_sym : Error
# l9_2 : Error
# distinct : Valid
# l9_3 : Error
# ts_distincts : Error
# diff_col_ex : Error
# diff_bet_ex3 : Error
# diff_col_ex3 : Error
# mid_preserves_col : Error
# sym_preserve_diff : Error
# per_mid_per : Error
# l9_4_1_aux : Error
# per_col_eq : Error
# l9_4_1 : Error
# mid_two_sides : Error
# col_preserves_two_sides : Error
# l9_4_2_aux : Error
# l9_5 : Error
# out_out_two_sides : Error
# l9_4_2 : Error
# os_distincts : Error
# outer_pasch : Error
# invert_one_side : Error
# l9_9 : Valid
# l9_8_1 : Error
# not_two_sides_id : Error
# l9_8_2 : Error
# l9_9_bis : Error
# l9_10 : Error
# col_eq : Error
# one_side_chara : Error
# one_side_reflexivity : Error
# one_side_transitivity : Error
# one_side_symmetry : Valid
# l9_17 : Error
# l9_19 : Error
# one_side_not_col123 : Error
# l9_18 : Error
# col_two_sides : Error
# one_side_not_col124 : Error
# out_one_side : Error
# col_one_side : Error
# out_out_one_side : Error
# bet_ts__ts : Error
# l9_31 : Error
# col123__nos : Valid
# col124__nos : Error
# os_out_os : Error
# col2_os__os : Error
# ts_ts_os : Error
# col_one_side_out : Error
# two_sides_not_col : Error
# os_ts1324__os : Error
# ts2__inangle : Error
# ts2__ex_bet2 : Error
# col_two_sides_bet : Error
# TS__ncol : Error
# out_one_side_1 : Error
# per_per_col : Error
# all_coplanar : Error
# perp_perp_col : Error
# cong_on_bissect : Error
# cong_mid_perp__col : Error
# image_in_col : Error
# l10_10 : Error
# l10_10_spec : Error
# image_gen_preserves_bet : Error
# image_preserves_col : Error
# image_preserves_bet : Error
# image_gen_preserves_col : Error
# image_gen_preserves_inter : Error
# image_gen_preserves_ncol : Error
# image_preserves_per : Error
# image_preserves_midpoint : Error
# intersection_with_image_gen : Error
# l10_16 : Error
# image_cong_col : Error
# per_per_cong : Error
# per_per_cong_gen : Error
# per_per_cong_1 : Error
# one_side_dec : Valid
# two_sides_dec : Valid
# is_image_is_image_spec : Valid
# ex_sym : Error
# l10_2_uniqueness : Error
# ex_sym1 : Error
# l10_2_uniqueness_spec : Error
# l10_2_existence_spec : Error
# l10_4_spec : Error
# l10_2_existence : Error
# l10_4 : Error
# l10_6_uniqueness : Error
# l10_6_uniqueness_spec : Error
# l10_7 : Error
# l10_5 : Error
# l10_6_existence_spec : Error
# l10_8 : Error
# l10_6_existence : Error
# col__refl : Error
# image_id : Error
# is_image_col_cong : Error
# is_image_spec_col_cong : Error
# osym_not_col : Error
# image_in_is_image_spec : Error
# midpoint_preserves_image : Error
# image_in_col0 : Error
# image_image_in : Error
# image_in_gen_is_image : Error
# is_image_rev : Error
# is_image_spec_rev : Error
# midpoint_preserves_per : Error
# image_col : Error
# l10_14 : Error
# is_image_spec_dec : Valid
# perp_exists : Error
# is_image_spec_triv : Error
# l10_15 : Error
# perp_vector : Error
# ex_per_cong : Error
# exists_cong_per : Error
# l11_3 : Error
# l11_aux : Error
# l11_4_1 : Error
# l11_3_bis : Error
# conga_refl : Error
# cong3_diff2 : Error
# l11_4_2 : Error
# out_conga : Error
# conga_sym : Error
# cong3_diff : Error
# cong3_conga : Error
# conga_diff1 : Valid
# cong3_conga2 : Error
# conga_diff2 : Valid
# conga_diff45 : Valid
# conga_diff56 : Valid
# conga_trans : Error
# conga_pseudo_refl : Error
# conga_trivial_1 : Error
# out2__conga : Error
# l11_10 : Error
# l11_13 : Error
# conga_right_comm : Error
# conga_left_comm : Error
# conga_line : Error
# conga_comm : Error
# l11_14 : Error
# l11_18_1 : Error
# l11_17 : Error
# l11_16 : Error
# l11_18_2 : Error
# l11_21_b : Error
# cong3_preserves_out : Error
# angle_construction_2 : Error
# conga__or_out_ts : Error
# l11_21_a : Error
# angle_construction_1 : Error
# ex_conga_ts : Error
# cong2_conga_cong : Error
# l11_15 : Error
# l11_22a : Error
# l11_22b : Error
# l11_19 : Error
# l11_22_bet : Error
# l11_24 : Error
# l11_22 : Error
# out_in_angle : Error
# col_in_angle : Error
# out321__inangle : Error
# inangle1123 : Error
# in_angle_two_sides : Error
# out341__inangle : Error
# l11_25_aux : Error
# in_angle_out : Error
# inangle3123 : Error
# col_in_angle_out : Error
# inangle_distincts : Valid
# angle_construction_3 : Error
# l11_25 : Error
# segment_construction_0 : Error
# l11_28 : Error
# out_in_angle_out : Error
# in_angle_one_side : Error
# bet_conga_bet : Error
# in_angle_trivial_1 : Error
# inangle_one_side2 : Error
# in_angle_trivial_2 : Error
# inangle_one_side : Error
# col_conga_col : Error
# l11_29_a : Error
# ncol_conga_ncol : Error
# l11_29_b : Error
# bet_in_angle_bet : Error
# in_angle_line : Error
# eq_conga_out : Error
# lea_line : Error
# conga_ex_cong3 : Error
# l11_30 : Error
# out_conga_out : Error
# lea_refl : Error
# l11_31_1 : Error
# conga_preserves_in_angle : Error
# l11_31_2 : Error
# lea121345 : Error
# conga__lea456123 : Error
# inangle__lea : Error
# in_angle_trans : Error
# lea_trans : Error
# conga__lea : Error
# in_angle_asym : Error
# two_sides_in_angle : Error
# lea_asym : Error
# not_two_sides_one_side : Error
# col_perp_perp_col : Error
# in_angle_reverse : Error
# in_angle_trans2 : Error
# l11_36 : Error
# l11_41_aux : Error
# not_conga : Valid
# not_conga_sym : Valid
# conga_preserves_lta : Error
# l11_41 : Error
# conga_preserves_gta : Error
# not_and_lta : Error
# lta_trans : Error
# lea_left_comm : Error
# gta_trans : Error
# lea_right_comm : Error
# lea_comm : Error
# lta_left_comm : Error
# lta_right_comm : Error
# acute_sym : Error
# l11_43_aux : Error
# l11_43 : Error
# lta_comm : Error
# acute_lea_acute : Error
# obtuse_gea_obtuse : Error
# obtuse_sym : Error
# lea_acute_obtuse : Error
# l11_44_1_a : Error
# l11_44_2_a : Error
# not_lta_and_conga : Valid
# not_lta_and_gta : Error
# not_gta_and_conga : Error
# conga_dec : Valid
# lta_not_conga : Error
# conga_sym_equiv : Valid
# l11_44_1 : Error
# l11_44_2 : Error
# l11_44_1_b : Error
# l11_44_2_b : Error
# l11_47 : Error
# lta_diff : Error
# l11_46 : Error
# l11_49 : Error
# l11_50_2 : Error
# l11_50_1 : Error
# conga_distinct : Valid
# l11_51 : Error
# l11_53 : Error
# per2_cong2__cong_3 : Error
# per2_cong2__cong_conga2 : Error
# l11_52 : Error
# not_one_side_two_sides : Error
# two_sides_cases : Error
# hilbert_s_version_of_pasch_aux : Error
# one_or_two_sides : Error
# not_par_two_sides : Error
# not_par_other_side : Error
# lea_distincts : Error
# gea_distincts : Error
# not_par_same_side : Error
# os_ts__inangle : Error
# lta_distincts : Error
# os2__inangle : Error
# acute_distincts : Error
# gta_distincts : Error
# obtuse_distincts : Error
# bet_lea__bet : Error
# out_lea__out : Error
# acute_conga__acute : Error
# obtuse_conga__obtuse : Error
# bet2_lta__lta : Error
# lta__lea : Error
# lea123456_lta__lta : Error
# acute_obtuse__lta : Error
# lea456789_lta__lta : Error
# out__acute : Error
# bet__obtuse : Error
# obtuse_per__lta : Error
# acute_per__lta : Error
# lea_in_angle : Error
# bet_acute__obtuse : Error
# bet_obtuse__acute : Error
# lea_dec : Valid
# inangle_dec : Valid
# gea_dec : Valid
# lta_dec : Valid
# or_lta_conga_gta : Error
# gta_dec : Valid
# gea_total : Error
# lea_total : Error
# angle_partition : Error
# acute_chara : Error
# obtuse_chara : Error
# conga__acute : Error
# cong__acute : Error
# lea__nlta : Error
# nlta : Valid
# lta__nlea : Error
# triangle_strict_inequality : Error
# nlta__lea : Error
# nlea__lta : Error
# triangle_inequality : Error
# triangle_strict_inequality_2 : Error
# triangle_inequality_2 : Error
# triangle_strict_reverse_inequality : Error
# bet_le__lt : Error
# triangle_reverse_inequality : Error
# t18_18_aux : Error
# os3__lta : Error
# t18_18 : Error
# acute_trivial : Error
# t18_19 : Error
# acute_not_per : Error
# reflectl__conga : Error
# angle_bisector : Error
# out_conga_reflect__out : Error
# col_conga_reflectl__col : Error
# inangle__ex_col_inangle : Error
# col_conga__conga : Error
# inangle2__lea : Error
# conga2__col : Error
# conga_inangle_per__acute : Error
# col_inangle2__out : Error
# conga_inangle2_per__acute : Error
# conga_os__out : Error
# lta_os__ts : Error
# acute_one_side_aux : Error
# acute_one_side_aux0 : Error
# acute_one_side : Error
# par_reflexivity : Error
# not_par_strict_id : Error
# par_strict_irreflexivity : Error
# par_id : Error
# par_strict_not_col_1 : Error
# par_strict_not_col_2 : Error
# par_strict_not_col_3 : Error
# par_strict_not_col_4 : Error
# par_id_1 : Error
# par_id_2 : Error
# par_id_4 : Error
# par_symmetry : Error
# par_strict_symmetry : Error
# par_id_3 : Error
# par_left_comm : Error
# par_id_5 : Error
# par_comm : Error
# par_right_comm : Error
# par_strict_left_comm : Error
# par_strict_neq1 : Valid
# par_strict_comm : Error
# par_strict_neq2 : Valid
# par_strict_right_comm : Error
# par_neq2 : Error
# par_neq1 : Error
# Par_cases : Valid
# Par_perm : Error
# Par_strict_perm : Error
# Par_strict_cases : Valid
# l12_6 : Error
# pars__os3412 : Error
# Perp_dec : Valid
# l12_9 : Error
# perp_perp_col_col : Error
# parallel_existence : Error
# par_col_par : Error
# par_not_col : Error
# parallel_existence1 : Error
# not_strict_par1 : Error
# not_strict_par2 : Error
# not_strict_par : Error
# not_par_not_col : Error
# not_par_inter_uniqueness : Error
# col_not_col_not_par : Error
# inter_uniqueness_not_par : Error
# par_distincts : Error
# par_not_col_strict : Error
# par_col_par_2 : Error
# par_col2_par : Error
# all_one_side_par_strict : Error
# par_col2_par_bis : Error
# par_strict_col_par_strict : Error
# line_dec : Valid
# par_strict_col2_par_strict : Error
# par_distinct : Error
# par_strict_col4__par_strict : Error
# inter_sym : Error
# par_strict_all_one_side : Valid
# par_strict_one_side : Error
# inter_trivial : Error
# inter_left_comm : Error
# inter_comm : Error
# l12_17 : Error
# inter_right_comm : Error
# l12_18_a : Error
# l12_18_b : Error
# l12_18_d : Error
# l12_18_c : Error
# par_one_or_two_sides : Error
# l12_18 : Error
# l12_22_aux : Error
# par_two_sides_two_sides : Error
# l12_22_b : Error
# l12_21_b : Error
# par_strict_par : Error
# acute_col_perp__out : Error
# par_strict_distinct : Valid
# col_par : Error
# perp_not_par : Error
# acute_col_perp__out_1 : Error
# cong_conga_perp : Error
# conga_inangle_per2__inangle : Error
# perp_inter_exists : Error
# perp_inter_perp_in : Error
# par_col4__par : Error
# bet__trisuma : Error
# tarski_s_euclid : Valid
# inter_dec : Valid
# l6_21 : Error
# not_par_inter_exists : Error
# par_trans : Error
# l12_16 : Error
# parallel_uniqueness : Error
# par_not_par : Valid
# Par_dec : Valid
# l12_19 : Error
# l12_20 : Error
# l12_20_bis : Error
# l12_22 : Error
# l12_21 : Error
# l12_21_a : Error
# l12_22_a : Error
# l12_23 : Error
# col_par_par_col : Error
# not_par_one_not_par : Error
# not_obtuse : Error
# not_par_inter : Error
# not_par_strict_inter_exists : Error
# trisuma__bet : Error
# suma__sams : Error
# per_distinct : Valid
# per2_col_eq : Error
# per2_preserves_diff : Error
# per23_preserves_bet_inv : Error
# per23_preserves_bet : Error
# per13_preserves_bet_inv : Error
# per13_preserves_bet : Error
# per3_preserves_bet2 : Error
# per3_preserves_bet2_aux : Error
# per3_preserves_bet1 : Error
# symmetry_preserves_per : Error
# l13_1 : Error
# per_lt : Error
# cong_perp_conga : Error
# perp_per_bet : Error
# ts_per_per_ts : Error
# triangle_mid_par : Error
# perp_in_perp_in_col : Error
# l13_2_1 : Error
# l13_2 : Error
# perp2_refl : Error
# perp2_sym : Valid
# perp2_comm : Error
# perp2_left_comm : Error
# perp2_right_comm : Error
# perp2_trans : Error
# perp2_par : Error
# perp2_preserves_bet23 : Error
# perp2_preserves_bet13 : Error
# is_image_perp_in : Error
# perp2_perp_in : Error
# l13_8 : Error
# gta_to_lta : Error
# perp_inter_perp_in_n : Error
# lta_to_gta : Error
# perp_in_rewrite : Error
# conga_preserves_obtuse : Error
# flat_all_lea : Error
# perp_out_acute : Error
# acute_bet_obtuse : Error
# lg_cong : Error
# perp_bet_obtuse : Error
# lg_exists : Error
# ex_points_lg : Error
# lg_sym : Error
# lg_cong_lg : Error
# is_len_cong_is_len : Error
# not_cong_is_len : Error
# is_len_cong : Error
# not_cong_is_len1 : Valid
# lg_null_instance : Error
# lg_null_trivial : Valid
# ex_point_lg_out : Error
# lg_null_dec : Valid
# ex_point_lg : Error
# ex_point_lg_bet : Error
# ex_points_lg_not_col : Error
# ex_eql : Error
# null_len : Error
# all_eql : Valid
# ang_exists : Error
# lg_eql_lg : Error
# ex_lg : Error
# ex_points_ang : Error
# ang_conga : Error
# is_ang_conga : Error
# is_ang_conga_is_ang : Error
# not_cong_is_ang1 : Error
# not_conga_not_ang : Valid
# ex_eqa : Error
# all_eqa : Valid
# not_conga_is_ang : Error
# is_ang_distinct : Error
# flat_ang : Error
# ex_ang : Error
# null_ang : Error
# anga_is_ang : Error
# anga_conga : Error
# anga_exists : Error
# ex_points_anga : Error
# not_conga_is_anga : Error
# is_anga_conga_is_anga : Error
# is_anga_to_is_ang : Error
# all_eqaa : Valid
# is_anga_conga : Error
# ex_eqaa : Valid
# null_anga : Error
# is_anga_distinct : Error
# out_is_len_eq : Error
# out_len_eq : Error
# not_null_ang_def_equiv : Error
# not_flat_ang_def_equiv : Error
# not_null_ang_ang : Error
# anga_distinct : Error
# ex_anga : Error
# ang_const : Error
# ang_sym : Error
# ang_not_null_lg : Error
# ang_distincts : Error
# anga_sym : Error
# anga_distincts : Error
# anga_not_null_lg : Error
# ang_const_o : Error
# anga_const : Error
# null_anga_null_anga' : Error
# is_null_anga_out : Valid
# acute_not_bet : Error
# acute_col_out : Error
# ang_cong_ang : Error
# anga_acute : Error
# is_null_ang_out : Error
# not_null_not_col : Error
# out_null_ang : Error
# bet_flat_ang : Error
# anga_not_flat : Error
# anga_const_o : Error
# anga_out_anga : Error
# anga_conga_anga : Error
# anga_not_lg_null : Valid
# is_null_all : Error
# out_out_anga : Error
# anga_col_out : Error
# anga_col_null : Error
# eqA_preserves_ang : Error
# eqA_preserves_anga : Error
# not_cong_is_anga1 : Error
# l13_6 : Error
# ang_distinct : Error
# eql_lcos_null : Error
# null_lcos_eql : Error
# lcos_lg_not_null : Error
# perp_acute_out : Error
# l10_12 : Error
# perp_out__acute : Valid
# acute_not_obtuse : Error
# obtuse_not_acute : Error
# lcos_const1 : Error
# lcos_lg_distincts : Error
# perp_obtuse_bet : Error
# lcos_const0 : Error
# lcos_const_ab : Error
# lcos_const : Error
# lcos_lg_anga : Valid
# lcos_eql_lcos : Error
# lcos_const_cb : Error
# acute_comp_not_acute : Error
# lcos_not_lg_null : Error
# lcos_const_a : Error
# lcos_const_o : Error
# is_null_anga_dec : Valid
# flat_not_acute : Error
# lcos_per : Error
# l13_7 : Error
# perp_acute : Error
# lcos_lg : Error
# null_lcos : Error
# lcos_exists : Error
# out_acute : Error
# lcos_uniqueness : Error
# lcos_eqa_lcos : Error
# lcos_eq_refl : Error
# lcos_eq_sym : Valid
# lcos2_comm : Valid
# lcos_eq_trans : Error
# lcos2_exists' : Error
# lcos2_exists : Error
# lcos2_eq_sym : Valid
# lcos2_eq_refl : Error
# lcos2_lg_anga : Error
# lcos2_uniqueness : Error
# lcos2_eq_trans : Error
# lcos2_eql_lcos2 : Error
# lcos3_lcos_1_2 : Error
# lcos_eq_lcos2_eq : Error
# lcos2_lg_not_null : Error
# lcos3_lcos_2_1 : Error
# lcos3_permut3 : Error
# lcos3_eql_lcos3 : Error
# lcos3_permut1 : Error
# lcos3_exists : Error
# lcos3_eq_refl : Error
# lcos3_eq_sym : Valid
# lcos3_permut2 : Error
# lcos3_lg_not_null : Error
# lcos3_eq_trans : Error
# lcos3_lg_anga : Error
# l13_10_aux2 : Error
# lcos3_uniqueness : Error
# l13_10_aux1 : Error
# lcos2_eq_lcos3_eq : Error
# lcos_eq_lcos3_eq : Error
# lcos3_lcos2 : Error
# lcos_per_anga : Error
# l13_6_bis : Error
# lcos_lcos_col : Error
# lcos2_lcos : Error
# l13_10_aux3 : Error
# per_per_perp : Error
# l13_10_aux5 : Error
# l13_10_aux4 : Error
# par_perp2 : Error
# l13_11 : Error
# l13_10 : Error
# l13_15_1 : Error
# l13_14 : Error
# l13_15_2 : Error
# l13_15_2_aux : Error
# l13_15 : Error
# l13_15_par : Error
# l13_18_2 : Error
# l13_19_aux : Error
# l13_18_3 : Error
# l13_19 : Error
# sum_to_sump : Error
# sump_to_sum : Error
# l13_19_par_aux : Error
# l13_19_par : Error
# l13_18 : Error
# project_trivial : Error
# project_col_project : Error
# pj_col_project : Error
# opp_exists : Error
# sum_exists : Error
# sum_uniqueness : Error
# opp0 : Error
# sum_O_O : Error
# pj_trivial : Error
# sum_A_O : Error
# sum_O_B : Error
# proj_pars : Error
# opp0_uniqueness : Error
# grid_not_par : Error
# proj_id : Error
# sum_O_B_eq : Error
# proj_col : Error
# sum_A_O_eq : Error
# sum_par_strict : Error
# sum_A_B_B : Error
# sum_A_B_A : Error
# sum_uniquenessB : Error
# sum_uniquenessA : Error
# sum_B_null : Error
# sum_cong : Error
# sum_cong2 : Error
# sum_comm : Error
# sum_A_null : Error
# opp_uniqueness : Error
# cong_sum : Error
# opp_comm : Error
# sum_iff_cong : Error
# pj_left_comm : Error
# pj_uniqueness : Error
# pj_right_comm : Error
# pj_comm : Error
# sum_assoc : Error
# proj_preserves_sum : Error
# sum_assoc_1 : Error
# sum_y_axis_change : Error
# sum_assoc_2 : Error
# sum_x_axis_unit_change : Error
# double_null_null : Error
# change_grid_sum : Error
# diff_ar2 : Error
# not_null_double_not_null : Valid
# change_grid_sum_0 : Error
# double_not_null_not_null : Error
# diff_null : Error
# diff_exists : Error
# diff_A_O : Error
# sum_ar2 : Error
# diff_uniqueness : Error
# diff_O_A : Error
# diff_O_A_opp : Error
# diff_uniquenessA : Error
# diff_uniquenessB : Error
# diff_null_eq : Error
# midpoint_opp : Error
# diff_sum : Error
# sum_diff : Error
# diff_opp : Error
# plg_to_sum : Error
# sum_stable : Error
# opp_midpoint : Error
# diff_to_plg : Error
# sum3_col : Error
# sum3_permut : Error
# sum3_comm_1_2 : Error
# sum3_uniqueness : Error
# sum4_col : Error
# sum3_comm_2_3 : Valid
# sum3_exists : Error
# sum22_col : Error
# sum3_to_sum4 : Valid
# sum_to_sum3 : Valid
# sum_B_exists : Error
# sum4_equiv : Error
# sum_A_exists : Error
# sum4_permut : Error
# sum22_permut : Valid
# sum22_comm : Error
# sum_diff2_diff_sum2_a : Error
# sum_abcd : Error
# sum4_comm : Error
# sum_diff_diff_b : Error
# sum_diff_diff_a : Error
# sum_diff2_diff_sum2_b : Error
# sum_plg : Error
# sum_diff_diff : Error
# sum_opp : Valid
# diff_stable : Valid
# prod_to_prodp : Error
# prod_exists : Error
# prodp_to_prod : Error
# project_pj : Error
# prod_0_l : Error
# prod_0_r : Error
# prod_uniqueness : Error
# prod_1_l : Error
# prod_1_r : Error
# inv_exists : Error
# prod_null : Error
# prod_y_axis_change : Error
# proj_preserves_prod : Error
# prod_assoc1 : Error
# prod_assoc2 : Error
# prod_O_r_eq : Error
# prod_assoc : Valid
# prod_uniquenessA : Error
# prod_comm : Error
# prod_uniquenessB : Error
# distr_r : Error
# prod_O_l_eq : Error
# distr_l : Error
# change_grid_prod : Error
# prod_1_r_eq : Error
# prod_1_l_eq : Error
# change_grid_prod1 : Error
# change_grid_prod_l_O : Error
# l14_31_1 : Error
# prod_sym : Error
# opp_prod : Error
# l14_31_2 : Error
# prod_x_axis_unit_change : Error
# distr_l_diff : Error
# eq_squares_eq_or_opp : Error
# diff_of_squares : Error
# O_not_positive : Error
# l14_36_a : Error
# l14_36_b : Error
# sum_pos_pos : Error
# prod_pos_pos : Error
# diff_2_prod : Error
# pos_null_neg : Error
# opp_neg_pos : Error
# pos_not_neg : Error
# ltP_ar2 : Error
# opp_pos_neg : Error
# neg_not_pos : Error
# ltP_neq : Error
# ltP_sum_pos : Error
# leP_refl : Valid
# diff_pos_diff_neg : Error
# pos_opp_neg : Error
# not_pos_and_neg : Error
# square_pos : Error
# leP_asym : Error
# leP_sum_leP : Error
# leP_trans : Error
# col_pos_or_neg : Error
# ltP_neg : Error
# lt_diff_ps : Error
# compatibility_of_prod_with_order : Error
# ps_le : Error
# col_2_le_or_ge : Error
# pos_inv_pos : Error
# le_pos_prod_le : Error
# compatibility_of_sum_with_order : Error
# bet_lt12_le23 : Error
# bet_lt12_le13 : Error
# diff_2_le_le : Error
# bet_lt21_le32 : Error
# bet_lt21_le31 : Error
# length_pos : Valid
# opp_2_le_le : Error
# length_id_2 : Error
# length_id_1 : Error
# length_id : Error
# ltP_pos : Error
# length_eq_cong_1 : Error
# bet_leP : Error
# length_eq_cong_2 : Error
# length_leP_le_1 : Error
# length_Ar2 : Error
# length_cong : Error
# length_uniqueness : Error
# length_leP_le_2 : Error
# leP_bet : Error
# l15_3 : Error
# length_not_col_null : Error
# length_Ps : Error
# triangular_equality_equiv : Error
# triangular_equality : Error
# not_triangular_equality1 : Error
# triangular_equality_bis : Error
# length_out : Error
# length_O : Error
# image_preserves_bet1 : Error
# thales : Error
# project_preserves_out : Error
# length_existence : Error
# image_preserves_out : Error
# conga_bet_conga : Error
# l15_7 : Error
# l15_7_1 : Error
# l15_7_2 : Error
# pythagoras : Error
# is_length_exists : Error
# length_sym : Error
# Ps_Col : Error
# PythRel_exists : Error
# PythOK : Error
# Cs_not_Col : Error
# opp_same_square : Error
# grid_exchange_axes : Error
# PythRel_uniqueness : Error
# exists_grid : Error
# Cd_Col : Error
# exists_grid_spec : Error
# coord_exchange_axes : Error
# exists_projp : Error
# coordinates_of_point : Error
# exists_coord : Error
# point_of_coordinates_on_an_axis : Error
# point_of_coordinates_origin : Error
# eq_points_coordinates : Error
# point_of_coordinates : Error
# l16_9_1 : Error
# length_eq_or_opp : Error
# l16_9_2 : Error
# cong_3_2_cong_4 : Error
# square_distance_formula_aux : Error
# cong_3_3_cong_5 : Error
# square_distance_formula : Error
# bet_betCood_aux : Error
# bet_betCood : Error
# characterization_of_congruence : Error
# same_abscissa_col : Error
# characterization_of_betweenness_aux : Error
# characterization_of_betweenness : Error
# characterization_of_collinearity : Error
# out_null_anga : Error
# ang_not_lg_null : Error
# iter remaining : 100
# 8.132045088566828% good to go = 1141 GaveUp = 99.47414548641542 TimeOut = 0.5258545135845749 RessourceOut = 0.0 size = 1242
# size_of_echantillon = 1141
# starting
# create files
# file created
# cong_symmetry : Error
# cong_transitivity : Error
# cong_left_commutativity : Valid
# cong_reflexivity : Error
# cong_right_commutativity : Error
# cong_3421 : Error
# cong_4312 : Error
# cong_4321 : Error
# cong_trivial_identity : Error
# cong_reverse_identity : Error
# not_cong_2134 : Error
# cong_commutativity : Valid
# not_cong_2143 : Error
# not_cong_4312 : Error
# not_cong_4321 : Error
# not_cong_1243 : Error
# not_cong_3421 : Error
# cong_diff_3 : Error
# five_segment_with_def : Error
# cong_3_swap_2 : Error
# cong_3_swap : Error
# bet_cong3 : Error
# l2_11 : Error
# cong_diff_4 : Error
# construction_uniqueness : Error
# cong3_transitivity : Valid
# Cong_cases : Error
# between_trivial : Error
# Cong_perm : Error
# between_symmetry : Error
# between_equality : Error
# between_equality_2 : Error
# between_trivial2 : Error
# between_exchange3 : Error
# bet_neq12__neq : Error
# bet_neq21__neq : Error
# bet_neq32__neq : Error
# bet_neq23__neq : Error
# not_bet_distincts : Error
# between_inner_transitivity : Error
# outer_transitivity_between2 : Error
# between_exchange2 : Error
# outer_transitivity_between : Error
# l_3_9_4 : Error
# between_exchange4 : Error
# l3_17 : Error
# two_distinct_points : Valid
# another_point : Error
# l2_11_b : Error
# point_construction_different : Error
# col_permutation_3 : Error
# BetSEq : Error
# col_permutation_4 : Error
# col_permutation_5 : Error
# not_col_permutation_2 : Error
# not_col_permutation_1 : Error
# not_col_permutation_3 : Error
# not_col_permutation_5 : Error
# not_col_permutation_4 : Error
# Col_perm : Valid
# col_trivial_2 : Error
# l4_13 : Error
# col_trivial_1 : Error
# l4_14 : Error
# col_trivial_3 : Error
# l4_16 : Error
# l4_17 : Error
# not_col_distincts : Error
# l4_18 : Error
# NCol_perm : Error
# l4_19 : Error
# l4_2 : Error
# col_cong_3_cong_3_eq : Error
# l4_5 : Error
# l4_6 : Error
# l4_3 : Error
# cong3_bet_eq : Error
# l5_2 : Error
# l5_3 : Error
# l5_1 : Error
# le_bet : Error
# segment_construction_2 : Error
# l5_6 : Error
# l5_5_1 : Error
# l5_5_2 : Error
# le_reflexivity : Error
# between_cong : Error
# le_transitivity : Error
# between_cong_2 : Error
# between_cong_3 : Error
# le_anti_symmetry : Error
# le_trivial : Error
# le_zero : Error
# bet_cong_eq : Error
# lt_diff : Error
# cong__le3412 : Error
# cong__le : Error
# le_left_comm : Error
# le1221 : Error
# ge_left_comm : Error
# le_right_comm : Error
# ge_right_comm : Error
# lt_right_comm : Error
# le_comm : Error
# lt_left_comm : Error
# l4_3_1 : Error
# lt_comm : Error
# gt_right_comm : Error
# gt_left_comm : Error
# gt_comm : Error
# ge_comm : Error
# cong2_lt__lt : Error
# fourth_point : Error
# l5_12_a : Error
# third_point : Error
# bet__lt2313 : Error
# l5_12_b : Error
# bet_le_eq : Error
# bet__lt1213 : Error
# le1234_lt__lt : Error
# or_lt_cong_gt : Error
# le__nlt : Error
# le3456_lt__lt : Error
# lt__nle : Error
# not_and_lt : Error
# cong__nlt : Error
# nle__lt : Error
# nlt__le : Error
# bet2_le2__le : Error
# le_cases : Error
# lt1123 : Error
# bet_out : Error
# out_diff1 : Error
# out_distinct : Error
# out_diff2 : Error
# l6_2 : Error
# out_col : Error
# bet_out__bet : Error
# l6_3_1 : Error
# l6_3_2 : Valid
# l6_4_2 : Error
# l6_4_1 : Error
# l6_7 : Error
# l6_6 : Error
# out_trivial : Error
# l6_11_uniqueness : Error
# l6_11_existence : Error
# l6_13_1 : Error
# l6_13_2 : Valid
# segment_construction_3 : Error
# l6_16_1 : Error
# col_transitivity_1 : Error
# not_col_exists : Error
# out2__bet : Error
# col_transitivity_2 : Error
# bet2_le2__le1346 : Error
# bet2_le2__le2356 : Error
# cong_preserves_bet : Error
# bet2_le2__le1245 : Error
# out_cong_cong : Error
# not_out_bet : Error
# or_bet_out : Valid
# col3 : Error
# not_bet_and_out : Error
# not_bet_out : Error
# out_to_bet : Error
# col_out2_col : Error
# bet2_out_out : Error
# out2_out_1 : Error
# out2_out_2 : Error
# out_bet_out_1 : Error
# out_bet__out : Error
# out_bet_out_2 : Error
# is_midpoint_id : Error
# l7_2 : Error
# is_midpoint_id_2 : Error
# l7_3 : Error
# l7_3_2 : Error
# symmetric_point_construction : Error
# l7_9 : Error
# l7_13 : Error
# symmetric_point_uniqueness : Error
# l7_9_bis : Error
# l7_16 : Error
# l7_15 : Error
# Mid_cases : Error
# symmetry_preserves_midpoint : Error
# Mid_perm : Error
# l7_17 : Error
# l7_17_bis : Error
# l7_20 : Error
# cong_col_mid : Error
# l7_21 : Error
# l7_22_aux : Error
# l7_22 : Error
# bet_col1 : Error
# midpoint_distinct_1 : Error
# midpoint_distinct_2 : Error
# l7_25 : Error
# midpoint_bet : Error
# midpoint_def : Error
# midpoint_col : Valid
# midpoint_distinct_3 : Error
# midpoint_not_midpoint : Error
# cong_cong_half_1 : Error
# midpoint_cong : Error
# cong_cong_half_2 : Error
# cong_mid2__cong : Error
# mid__lt : Error
# le_mid2__le13 : Error
# le_mid2__le12 : Error
# midpoint_preserves_out : Error
# lt_mid2__lt12 : Error
# lt_mid2__lt13 : Error
# col_cong_bet : Error
# col_cong2_bet1 : Error
# col_cong2_bet2 : Error
# col_cong2_bet3 : Error
# col_cong2_bet4 : Error
# col_bet2_cong1 : Error
# bet2_lt2__lt : Error
# col_bet2_cong2 : Error
# bet2_lt_le__lt : Error
# Per_cases : Error
# Per_perm : Error
# l8_2 : Error
# l8_4 : Error
# l8_7 : Error
# l8_5 : Error
# l8_3 : Error
# l8_6 : Error
# l8_9 : Error
# l8_8 : Error
# col_col_per_per : Error
# l8_10 : Error
# l8_12 : Error
# perp_distinct : Error
# per_col : Error
# l8_13_2 : Error
# l8_14_1 : Error
# l8_14_2_1b : Error
# l8_15_1 : Error
# l8_15_2 : Error
# perp_in_per : Error
# l8_14_2_1b_bis : Error
# l8_14_2_2 : Error
# l8_14_3 : Error
# perp_sym : Error
# l8_16_1 : Error
# perp_col0 : Error
# per_perp_in : Error
# per_perp : Error
# perp_right_comm : Error
# perp_left_comm : Error
# perp_comm : Error
# perp_in_sym : Error
# perp_in_right_comm : Error
# perp_in_comm : Error
# perp_in_left_comm : Error
# Perp_perm : Error
# l8_16_2 : Error
# l8_18_uniqueness : Error
# l8_20_1 : Error
# l8_20_2 : Valid
# Perp_in_perm : Error
# midpoint_distinct : Error
# l8_18_existence : Error
# l8_21_aux : Error
# perp_col1 : Error
# l8_21 : Error
# perp_in_col : Error
# perp_per_1 : Error
# perp_per_2 : Error
# perp_perp_in : Error
# perp_col : Error
# perp_not_eq_1 : Error
# perp_col2 : Error
# perp_not_eq_2 : Error
# diff_per_diff : Error
# per_not_colp : Error
# per_not_col : Error
# per_cong : Error
# midpoint_existence_aux : Error
# perp_cong : Error
# midpoint_existence : Error
# perp_in_id : Error
# l8_22 : Error
# l8_22_bis : Error
# perp_proj : Error
# perp_in_perp : Valid
# l8_24 : Error
# perp_not_col2 : Error
# perp_not_col : Error
# perp_in_perp_bis : Error
# perp_col2_bis : Error
# col_per_perp : Error
# perp_in_col_perp_in : Error
# per_double_cong : Error
# per_cong_mid : Error
# cong_perp_or_mid : Error
# l9_2 : Error
# col_per2_cases : Error
# ts_distincts : Error
# invert_two_sides : Error
# l9_3 : Error
# diff_col_ex : Error
# sym_sym : Error
# diff_bet_ex3 : Error
# per_mid_per : Error
# diff_col_ex3 : Error
# sym_preserve_diff : Error
# per_col_eq : Error
# l9_4_1_aux : Error
# l9_4_1 : Error
# mid_two_sides : Error
# col_preserves_two_sides : Error
# out_out_two_sides : Error
# l9_4_2_aux : Error
# l9_4_2 : Error
# outer_pasch : Error
# l9_5 : Error
# os_distincts : Error
# invert_one_side : Error
# l9_8_1 : Error
# not_two_sides_id : Error
# l9_8_2 : Error
# l9_9_bis : Error
# one_side_chara : Error
# l9_10 : Error
# one_side_reflexivity : Error
# one_side_transitivity : Error
# col_eq : Error
# l9_17 : Error
# l9_18 : Error
# l9_19 : Error
# one_side_not_col124 : Error
# one_side_not_col123 : Error
# col_one_side : Valid
# col_two_sides : Error
# out_one_side : Error
# out_out_one_side : Error
# bet_ts__ts : Error
# l9_31 : Error
# col124__nos : Error
# col2_os__os : Error
# os_out_os : Error
# ts_ts_os : Error
# two_sides_not_col : Error
# col_one_side_out : Error
# col_two_sides_bet : Error
# ts2__ex_bet2 : Error
# ts2__inangle : Error
# os_ts1324__os : Error
# per_per_col : Error
# out_one_side_1 : Error
# TS__ncol : Error
# perp_perp_col : Error
# cong_on_bissect : Error
# image_in_col : Error
# all_coplanar : Error
# cong_mid_perp__col : Error
# l10_10_spec : Error
# image_gen_preserves_bet : Error
# image_preserves_bet : Error
# l10_10 : Error
# image_gen_preserves_col : Error
# image_gen_preserves_ncol : Valid
# image_preserves_col : Error
# image_gen_preserves_inter : Error
# image_preserves_midpoint : Error
# intersection_with_image_gen : Error
# image_cong_col : Error
# image_preserves_per : Error
# l10_16 : Error
# per_per_cong : Error
# per_per_cong_1 : Error
# ex_sym : Error
# per_per_cong_gen : Error
# ex_sym1 : Error
# l10_2_uniqueness : Error
# l10_2_uniqueness_spec : Error
# l10_2_existence_spec : Error
# l10_2_existence : Error
# l10_4_spec : Error
# l10_6_uniqueness : Error
# l10_5 : Error
# l10_6_existence_spec : Error
# l10_4 : Error
# l10_6_existence : Error
# l10_7 : Valid
# l10_6_uniqueness_spec : Error
# col__refl : Error
# l10_8 : Error
# is_image_col_cong : Error
# image_id : Error
# bet_out_out_bet : Valid
# is_image_spec_col_cong : Error
# osym_not_col : Error
# image_in_is_image_spec : Error
# image_in_gen_is_image : Error
# midpoint_preserves_image : Error
# image_image_in : Error
# is_image_spec_rev : Error
# is_image_rev : Error
# image_in_col0 : Error
# midpoint_preserves_per : Error
# image_col : Error
# l10_15 : Error
# is_image_spec_triv : Error
# l10_14 : Error
# perp_exists : Error
# perp_vector : Error
# ex_per_cong : Error
# exists_cong_per : Error
# l11_aux : Error
# l11_3 : Error
# l11_3_bis : Error
# l11_4_1 : Error
# out_conga : Error
# l11_4_2 : Error
# conga_sym : Error
# conga_refl : Error
# cong3_diff2 : Error
# cong3_diff : Error
# cong3_conga : Error
# cong3_conga2 : Error
# conga_trans : Error
# l11_10 : Error
# conga_pseudo_refl : Error
# conga_trivial_1 : Error
# l11_13 : Error
# out2__conga : Error
# conga_right_comm : Error
# conga_left_comm : Error
# l11_14 : Error
# l11_16 : Error
# conga_line : Error
# l11_17 : Error
# conga_comm : Error
# l11_18_1 : Error
# l11_18_2 : Error
# cong3_preserves_out : Error
# l11_21_a : Error
# conga__or_out_ts : Error
# l11_21_b : Error
# angle_construction_1 : Error
# cong2_conga_cong : Error
# ex_conga_ts : Error
# angle_construction_2 : Error
# l11_15 : Error
# l11_19 : Error
# l11_22_bet : Error
# l11_22a : Error
# l11_22b : Error
# l11_22 : Error
# out_in_angle : Error
# l11_24 : Valid
# inangle1123 : Valid
# col_in_angle : Error
# out321__inangle : Error
# in_angle_two_sides : Error
# out341__inangle : Error
# inangle3123 : Valid
# in_angle_out : Error
# col_in_angle_out : Error
# l11_25_aux : Error
# l11_25 : Error
# angle_construction_3 : Error
# out_in_angle_out : Error
# l11_28 : Error
# bet_conga_bet : Error
# segment_construction_0 : Error
# in_angle_one_side : Error
# inangle_one_side : Error
# in_angle_trivial_1 : Valid
# col_conga_col : Error
# inangle_one_side2 : Error
# in_angle_trivial_2 : Valid
# ncol_conga_ncol : Error
# l11_29_a : Error
# eq_conga_out : Error
# l11_29_b : Error
# in_angle_line : Error
# bet_in_angle_bet : Error
# out_conga_out : Error
# lea_line : Error
# conga_ex_cong3 : Error
# conga_preserves_in_angle : Error
# l11_30 : Error
# l11_31_1 : Error
# l11_31_2 : Error
# lea_refl : Error
# conga__lea456123 : Valid
# lea121345 : Error
# inangle__lea : Error
# in_angle_trans : Error
# conga__lea : Error
# lea_trans : Error
# lea_asym : Error
# in_angle_asym : Error
# col_perp_perp_col : Error
# two_sides_in_angle : Error
# in_angle_reverse : Error
# in_angle_trans2 : Error
# l11_36 : Error
# not_two_sides_one_side : Error
# l11_41 : Error
# l11_41_aux : Error
# conga_preserves_lta : Error
# not_and_lta : Valid
# conga_preserves_gta : Error
# gta_trans : Error
# lea_left_comm : Error
# lta_trans : Error
# lea_comm : Error
# lea_right_comm : Error
# lta_left_comm : Error
# lta_right_comm : Error
# acute_sym : Error
# l11_43_aux : Error
# obtuse_sym : Error
# lta_comm : Error
# l11_43 : Error
# obtuse_gea_obtuse : Error
# acute_lea_acute : Error
# lea_acute_obtuse : Error
# l11_44_1_a : Error
# l11_44_2_a : Error
# not_lta_and_gta : Error
# not_gta_and_conga : Error
# out2_bet_out : Error
# lta_not_conga : Error
# l11_44_1_b : Error
# l11_44_2_b : Error
# l11_44_1 : Valid
# lta_diff : Error
# l11_44_2 : Error
# l6_21 : Error
# l11_47 : Error
# l11_46 : Error
# l11_49 : Error
# l11_50_1 : Error
# l11_52 : Error
# l11_50_2 : Error
# l11_51 : Error
# l11_53 : Error
# per2_cong2__cong_3 : Error
# per2_cong2__cong_conga2 : Error
# hilbert_s_version_of_pasch_aux : Error
# not_par_two_sides : Error
# not_one_side_two_sides : Error
# two_sides_cases : Error
# one_or_two_sides : Error
# not_par_other_side : Error
# not_par_same_side : Error
# os_ts__inangle : Error
# os2__inangle : Error
# lea_distincts : Error
# acute_distincts : Error
# gea_distincts : Error
# lta_distincts : Error
# gta_distincts : Error
# obtuse_distincts : Error
# acute_conga__acute : Error
# obtuse_conga__obtuse : Error
# bet_lea__bet : Error
# lta__lea : Valid
# lea123456_lta__lta : Error
# bet2_lta__lta : Error
# out_lea__out : Error
# lea456789_lta__lta : Error
# acute_per__lta : Error
# obtuse_per__lta : Error
# bet__obtuse : Error
# acute_obtuse__lta : Error
# out__acute : Error
# bet_acute__obtuse : Error
# lea_in_angle : Error
# bet_obtuse__acute : Error
# acute_chara : Error
# or_lta_conga_gta : Error
# lea_total : Error
# conga__acute : Error
# gea_total : Error
# angle_partition : Error
# obtuse_chara : Error
# cong__acute : Error
# lea__nlta : Error
# triangle_strict_inequality : Error
# lta__nlea : Error
# nlta__lea : Error
# triangle_strict_inequality_2 : Error
# nlea__lta : Error
# triangle_inequality : Error
# triangle_strict_reverse_inequality : Error
# triangle_inequality_2 : Error
# triangle_reverse_inequality : Error
# bet_le__lt : Error
# t18_18_aux : Error
# os3__lta : Error
# t18_19 : Error
# acute_trivial : Error
# t18_18 : Error
# reflectl__conga : Error
# angle_bisector : Error
# acute_not_per : Error
# out_conga_reflect__out : Error
# col_conga_reflectl__col : Error
# col_conga__conga : Error
# conga2__col : Error
# inangle__ex_col_inangle : Error
# col_inangle2__out : Error
# conga_inangle_per__acute : Error
# inangle2__lea : Error
# conga_inangle2_per__acute : Error
# lta_os__ts : Error
# acute_one_side_aux : Error
# acute_one_side_aux0 : Error
# conga_os__out : Error
# par_reflexivity : Error
# acute_one_side : Error
# par_strict_irreflexivity : Error
# not_par_strict_id : Error
# par_id : Error
# par_strict_not_col_1 : Error
# par_strict_not_col_3 : Error
# par_id_2 : Error
# par_strict_not_col_2 : Error
# par_strict_not_col_4 : Error
# par_id_3 : Valid
# par_id_1 : Error
# par_id_4 : Error
# par_id_5 : Error
# par_symmetry : Error
# par_strict_symmetry : Error
# par_left_comm : Error
# par_right_comm : Error
# par_strict_left_comm : Error
# par_strict_right_comm : Error
# par_comm : Error
# par_strict_comm : Error
# par_neq1 : Error
# Par_perm : Error
# Par_strict_perm : Error
# l12_6 : Error
# par_neq2 : Error
# pars__os3412 : Error
# perp_perp_col_col : Error
# l12_9 : Error
# parallel_existence : Error
# par_col_par : Error
# not_strict_par1 : Error
# par_not_col : Error
# parallel_existence1 : Error
# not_strict_par : Error
# not_strict_par2 : Error
# not_par_inter_uniqueness : Error
# not_par_not_col : Error
# col_not_col_not_par : Error
# inter_uniqueness_not_par : Error
# all_one_side_par_strict : Error
# par_distincts : Error
# par_strict_col_par_strict : Error
# par_not_col_strict : Error
# par_col2_par : Error
# par_col_par_2 : Error
# par_strict_col2_par_strict : Error
# par_distinct : Error
# par_col2_par_bis : Error
# par_strict_col4__par_strict : Error
# par_strict_one_side : Error
# inter_sym : Error
# inter_trivial : Error
# inter_left_comm : Error
# inter_right_comm : Error
# l12_17 : Error
# inter_comm : Error
# l12_18_a : Error
# l12_18_c : Error
# l12_18_b : Error
# par_two_sides_two_sides : Error
# l12_18 : Error
# l12_18_d : Error
# par_one_or_two_sides : Error
# l12_22_b : Error
# l12_22_aux : Error
# l12_21_b : Error
# col_par : Error
# par_strict_par : Error
# acute_col_perp__out : Error
# acute_col_perp__out_1 : Error
# conga_inangle_per2__inangle : Error
# perp_not_par : Error
# perp_inter_exists : Error
# cong_conga_perp : Error
# not_par_inter_exists : Error
# perp_inter_perp_in : Error
# par_col4__par : Error
# bet__trisuma : Error
# par_trans : Error
# parallel_uniqueness : Error
# l12_19 : Error
# l12_16 : Error
# l12_21_a : Error
# l12_20_bis : Error
# l12_20 : Error
# l12_21 : Valid
# l12_22_a : Error
# l12_22 : Valid
# not_par_strict_inter_exists : Error
# not_par_inter : Error
# not_par_one_not_par : Valid
# l12_23 : Error
# col_par_par_col : Error
# trisuma__bet : Error
# not_obtuse : Error
# per2_col_eq : Error
# suma__sams : Error
# per2_preserves_diff : Error
# per23_preserves_bet : Error
# per23_preserves_bet_inv : Error
# per13_preserves_bet : Error
# per13_preserves_bet_inv : Error
# per3_preserves_bet2_aux : Error
# per3_preserves_bet1 : Error
# l13_1 : Error
# per_lt : Error
# symmetry_preserves_per : Error
# cong_perp_conga : Error
# per3_preserves_bet2 : Error
# perp_per_bet : Error
# ts_per_per_ts : Error
# l13_2_1 : Error
# perp_in_perp_in_col : Error
# perp2_refl : Error
# perp2_right_comm : Error
# perp2_left_comm : Error
# l13_2 : Error
# triangle_mid_par : Error
# perp2_trans : Error
# perp2_comm : Error
# perp2_preserves_bet23 : Error
# perp2_preserves_bet13 : Error
# perp2_par : Error
# is_image_perp_in : Error
# perp_inter_perp_in_n : Error
# l13_8 : Error
# perp_in_rewrite : Error
# gta_to_lta : Error
# conga_preserves_obtuse : Error
# perp2_perp_in : Error
# lta_to_gta : Error
# flat_all_lea : Error
# perp_out_acute : Error
# perp_bet_obtuse : Error
# acute_bet_obtuse : Error
# lg_cong : Error
# lg_cong_lg : Error
# lg_exists : Error
# not_cong_is_len : Error
# lg_sym : Error
# ex_point_lg_out : Error
# lg_null_instance : Error
# mid_preserves_col : Error
# is_len_cong_is_len : Error
# ex_points_lg : Error
# is_len_cong : Valid
# ex_point_lg : Error
# ex_eql : Error
# null_len : Error
# ex_point_lg_bet : Error
# ex_points_lg_not_col : Error
# ex_lg : Error
# lg_eql_lg : Error
# ex_points_ang : Valid
# ang_conga : Error
# ang_exists : Error
# is_ang_conga_is_ang : Error
# is_ang_conga : Error
# not_conga_is_ang : Error
# ex_eqa : Error
# not_cong_is_ang1 : Error
# is_ang_distinct : Error
# null_ang : Error
# ex_ang : Error
# anga_exists : Error
# flat_ang : Error
# anga_is_ang : Error
# ex_points_anga : Error
# is_anga_to_is_ang : Error
# anga_conga : Error
# is_anga_conga : Error
# not_conga_is_anga : Error
# is_anga_conga_is_anga : Error
# is_anga_distinct : Error
# null_anga : Error
# anga_distinct : Error
# out_is_len_eq : Error
# out_len_eq : Error
# ex_anga : Error
# not_null_ang_def_equiv : Error
# not_null_ang_ang : Error
# not_flat_ang_def_equiv : Error
# ang_sym : Error
# ang_distincts : Error
# anga_sym : Error
# ang_not_null_lg : Error
# ang_const : Error
# anga_distincts : Error
# acute_not_bet : Error
# anga_not_null_lg : Error
# ang_const_o : Error
# null_anga_null_anga' : Error
# anga_const : Error
# ang_cong_ang : Error
# anga_acute : Error
# acute_col_out : Error
# not_null_not_col : Error
# bet_flat_ang : Error
# is_null_ang_out : Error
# out_null_ang : Error
# anga_not_flat : Error
# anga_const_o : Error
# anga_conga_anga : Error
# anga_out_anga : Error
# is_null_all : Error
# out_out_anga : Error
# anga_col_out : Error
# eqA_preserves_ang : Error
# anga_col_null : Error
# ang_distinct : Error
# l13_6 : Error
# eqA_preserves_anga : Error
# not_cong_is_anga1 : Valid
# null_lcos_eql : Error
# eql_lcos_null : Error
# perp_acute_out : Error
# lcos_lg_not_null : Error
# obtuse_not_acute : Error
# acute_not_obtuse : Error
# lcos_const0 : Error
# perp_obtuse_bet : Error
# lcos_const : Error
# lcos_const1 : Error
# lcos_const_a : Error
# lcos_lg_distincts : Error
# lcos_eql_lcos : Error
# lcos_const_ab : Error
# lcos_const_cb : Error
# lcos_not_lg_null : Error
# lcos_const_o : Error
# lcos_lg : Error
# flat_not_acute : Error
# acute_comp_not_acute : Error
# lcos_per : Error
# out_acute : Error
# l13_7 : Error
# perp_acute : Error
# lcos_exists : Error
# null_lcos : Error
# lcos_uniqueness : Error
# lcos_eq_trans : Error
# lcos_eq_refl : Error
# lcos_eqa_lcos : Error
# lcos2_exists : Error
# lcos2_eql_lcos2 : Error
# lcos2_exists' : Error
# lcos2_eq_refl : Error
# lcos2_eq_trans : Error
# lcos2_lg_anga : Error
# lcos2_uniqueness : Error
# lcos_eq_lcos2_eq : Error
# l10_12 : Error
# lcos3_permut3 : Error
# lcos3_lcos_1_2 : Error
# lcos3_lcos_2_1 : Error
# lcos2_lg_not_null : Error
# lcos3_permut1 : Error
# lcos3_eq_refl : Error
# lcos3_permut2 : Error
# lcos3_uniqueness : Error
# lcos3_exists : Error
# lcos3_eql_lcos3 : Error
# lcos3_lg_anga : Error
# lcos3_eq_trans : Error
# lcos3_lg_not_null : Error
# lcos2_eq_lcos3_eq : Error
# l13_10_aux1 : Error
# lcos_eq_lcos3_eq : Error
# l13_10_aux2 : Error
# lcos3_lcos2 : Error
# l13_6_bis : Error
# lcos2_lcos : Error
# lcos_per_anga : Error
# lcos_lcos_col : Error
# l13_10_aux3 : Error
# l13_10_aux4 : Error
# l13_10 : Error
# l13_10_aux5 : Error
# per_per_perp : Error
# l13_11 : Error
# par_perp2 : Error
# l13_15 : Error
# l13_14 : Error
# l13_15_2_aux : Error
# l13_15_1 : Error
# l13_15_par : Error
# l13_15_2 : Error
# l13_18 : Error
# l13_18_2 : Error
# l13_18_3 : Error
# l13_19_aux : Error
# l13_19 : Error
# l13_19_par_aux : Error
# sump_to_sum : Error
# l13_19_par : Error
# project_col_project : Error
# sum_to_sump : Error
# project_trivial : Error
# sum_exists : Error
# pj_col_project : Error
# sum_uniqueness : Error
# opp_exists : Error
# opp0 : Error
# pj_trivial : Error
# sum_O_O : Error
# sum_A_O : Error
# opp0_uniqueness : Error
# sum_O_B : Error
# proj_pars : Error
# grid_not_par : Error
# proj_col : Error
# proj_id : Error
# sum_O_B_eq : Error
# sum_A_B_A : Error
# sum_A_B_B : Error
# sum_par_strict : Error
# sum_A_O_eq : Error
# sum_uniquenessB : Error
# sum_uniquenessA : Error
# sum_B_null : Error
# sum_cong2 : Error
# sum_A_null : Error
# sum_cong : Error
# sum_comm : Error
# sum_iff_cong : Error
# opp_comm : Error
# opp_uniqueness : Error
# cong_sum : Error
# pj_left_comm : Error
# pj_uniqueness : Error
# pj_comm : Error
# pj_right_comm : Error
# sum_assoc_1 : Error
# proj_preserves_sum : Error
# sum_y_axis_change : Error
# sum_assoc : Valid
# sum_x_axis_unit_change : Error
# sum_assoc_2 : Error
# change_grid_sum_0 : Error
# double_not_null_not_null : Error
# double_null_null : Error
# change_grid_sum : Error
# sum_ar2 : Error
# diff_ar2 : Error
# diff_uniqueness : Error
# diff_A_O : Error
# diff_exists : Error
# diff_null : Error
# diff_O_A : Error
# diff_uniquenessA : Error
# diff_O_A_opp : Error
# diff_uniquenessB : Error
# diff_null_eq : Error
# sum_stable : Error
# sum_diff : Error
# diff_to_plg : Error
# diff_sum : Error
# diff_opp : Error
# opp_midpoint : Error
# ...
# sum3_uniqueness : Error
# sum3_comm_1_2 : Error
# sum3_exists : Error
# sum4_permut : Error
# sum22_comm : Error
# sum4_equiv : Error
# sum_B_exists : Error
# sum4_comm : Error
# sum_abcd : Error
# sum_diff_diff_a : Error
# sum_diff_diff_b : Error
# sum_diff2_diff_sum2_a : Error
# sum_diff2_diff_sum2_b : Error
# sum_diff_diff : Error
# sum_plg : Error
# prod_to_prodp : Error
# prodp_to_prod : Error
# prod_exists : Error
# prod_0_l : Error
# prod_uniqueness : Error
# prod_0_r : Error
# prod_1_l : Error
# prod_1_r : Error
# inv_exists : Error
# prod_y_axis_change : Error
# prod_null : Error
# prod_assoc2 : Error
# prod_assoc1 : Error
# proj_preserves_prod : Error
# prod_comm : Error
# prod_O_l_eq : Error
# prod_uniquenessA : Error
# prod_O_r_eq : Error
# prod_uniquenessB : Error
# distr_l : Error
# distr_r : Error
# prod_1_l_eq : Error
# prod_1_r_eq : Error
# change_grid_prod_l_O : Error
# l14_31_1 : Error
# change_grid_prod1 : Error
# change_grid_prod : Error
# l14_31_2 : Error
# prod_x_axis_unit_change : Error
# opp_prod : Error
# distr_l_diff : Error
# diff_of_squares : Error
# eq_squares_eq_or_opp : Error
# l14_36_a : Error
# sum_pos_pos : Error
# pos_null_neg : Error
# ltP_sum_pos : Error
# prod_pos_pos : Error
# l14_36_b : Error
# leP_sum_leP : Error
# leP_trans : Error
# square_pos : Error
# ltP_neg : Error
# ps_le : Error
# lt_diff_ps : Error
# col_2_le_or_ge : Error
# compatibility_of_sum_with_order : Error
# le_pos_prod_le : Error
# compatibility_of_prod_with_order : Error
# bet_lt12_le23 : Error
# bet_lt12_le13 : Error
# bet_lt21_le32 : Error
# bet_lt21_le31 : Error
# diff_2_le_le : Error
# opp_2_le_le : Error
# ltP_pos : Error
# bet_leP : Error
# length_leP_le_1 : Error
# l15_3 : Error
# length_leP_le_2 : Error
# length_uniqueness : Error
# length_Ps : Error
# triangular_equality_bis : Error
# triangular_equality_equiv : Error
# triangular_equality : Error
# length_out : Error
# project_preserves_out : Error
# thales : Error
# length_existence : Error
# l15_7 : Error
# l15_7_1 : Error
# l15_7_2 : Error
# pythagoras : Error
# PythOK : Error
# is_length_exists : Error
# PythRel_exists : Error
# opp_same_square : Error
# PythRel_uniqueness : Error
# grid_exchange_axes : Error
# exists_grid : Error
# exists_grid_spec : Error
# exists_projp : Error
# coord_exchange_axes : Error
# exists_coord : Error
# coordinates_of_point : Error
# point_of_coordinates_origin : Error
# point_of_coordinates : Error
# point_of_coordinates_on_an_axis : Error
# eq_points_coordinates : Error
# length_eq_or_opp : Error
# l16_9_1 : Error
# l16_9_2 : Error
# cong_3_2_cong_4 : Error
# cong_3_3_cong_5 : Error
# square_distance_formula_aux : Error
# square_distance_formula : Error
# characterization_of_congruence : Error
# bet_betCood_aux : Error
# bet_betCood : Error
# characterization_of_betweenness_aux : Error
# characterization_of_betweenness : Error
# same_abscissa_col : Error
# characterization_of_collinearity : Error
# iter remaining : 39
# 0.0% good to go = 597 GaveUp = 0.16750418760469013 TimeOut = 4.690117252931323 RessourceOut = 95.14237855946399 size = 597
# size_of_echantillon = 597
# starting
# create files
# file created
# l4_16 : Error
# segment_construction_2 : Error
# l4_6 : Error
# l_3_9_4 : Error
# l5_2 : Error
# l4_2 : Error
# l5_1 : Error
# l4_5 : Error
# l4_14 : Error
# bet_cong_eq : Error
# l5_3 : Error
# l5_6 : Error
# between_cong_3 : Error
# le_anti_symmetry : Error
# cong2_lt__lt : Error
# fourth_point : Error
# lt_right_comm : Error
# bet__lt1213 : Error
# bet__lt2313 : Error
# le1234_lt__lt : Error
# le3456_lt__lt : Error
# nlt__le : Error
# l8_22_bis : Error
# not_and_lt : Error
# nle__lt : Error
# lt1123 : Error
# bet2_le2__le : Error
# le_cases : Error
# l6_7 : Error
# bet2_le2__le1346 : Error
# bet2_le2__le2356 : Error
# col_out2_col : Error
# bet2_out_out : Error
# l6_16_1 : Error
# l7_21 : Error
# l7_13 : Error
# l7_22_aux : Error
# l7_22 : Error
# cong_cong_half_1 : Error
# mid__lt : Error
# col_cong2_bet4 : Error
# le_mid2__le13 : Error
# lt_mid2__lt13 : Error
# lt_mid2__lt12 : Error
# l8_3 : Error
# bet2_lt2__lt : Error
# bet2_lt_le__lt : Error
# l8_10 : Error
# l8_7 : Error
# l8_13_2 : Error
# l8_12 : Error
# per_col : Error
# l8_15_2 : Error
# perp_col0 : Error
# l8_16_1 : Error
# perp_sym : Error
# per_perp_in : Error
# perp_in_sym : Error
# l8_20_1 : Error
# l8_18_uniqueness : Error
# perp_col1 : Error
# l8_18_existence : Error
# l8_21_aux : Error
# perp_col2 : Error
# per_cong : Error
# midpoint_existence_aux : Error
# perp_perp_in : Error
# per_not_col : Error
# l8_24 : Error
# midpoint_existence : Error
# perp_in_id : Error
# perp_in_perp_bis : Error
# perp_col2_bis : Error
# perp_in_col_perp_in : Error
# per_cong_mid : Error
# col_per2_cases : Error
# l9_3 : Error
# per_mid_per : Error
# diff_col_ex3 : Error
# diff_bet_ex3 : Error
# mid_preserves_col : Error
# l9_4_1_aux : Error
# per_col_eq : Error
# col_preserves_two_sides : Error
# l9_4_1 : Error
# mid_two_sides : Error
# out_out_two_sides : Error
# l9_4_2_aux : Error
# outer_pasch : Error
# l9_8_2 : Error
# l9_5 : Error
# os_distincts : Error
# one_side_reflexivity : Error
# col_eq : Error
# l9_17 : Error
# l9_19 : Error
# l9_18 : Error
# out_out_one_side : Error
# col2_os__os : Error
# bet_ts__ts : Error
# l9_31 : Error
# os_out_os : Error
# ts_ts_os : Error
# os_ts1324__os : Error
# col_one_side_out : Error
# col_two_sides_bet : Error
# out_one_side_1 : Error
# ts2__ex_bet2 : Error
# all_coplanar : Error
# per_per_col : Error
# TS__ncol : Error
# perp_perp_col : Error
# image_gen_preserves_bet : Error
# image_preserves_col : Error
# image_in_col : Error
# image_gen_preserves_col : Error
# l10_10_spec : Error
# image_preserves_per : Error
# intersection_with_image_gen : Error
# image_gen_preserves_inter : Error
# l10_12 : Error
# l10_16 : Error
# image_cong_col : Error
# ex_sym : Error
# ex_sym1 : Error
# l10_2_uniqueness : Error
# l10_2_uniqueness_spec : Error
# l10_2_existence_spec : Error
# l10_6_uniqueness_spec : Error
# is_image_col_cong : Error
# l10_6_existence : Error
# is_image_spec_col_cong : Error
# image_id : Error
# midpoint_preserves_image : Error
# image_in_gen_is_image : Error
# midpoint_preserves_per : Error
# image_image_in : Error
# l10_15 : Error
# ex_per_cong : Error
# l10_14 : Error
# l11_3 : Error
# l11_aux : Error
# l11_4_1 : Error
# cong3_conga2 : Error
# l11_3_bis : Error
# conga_trans : Error
# out_conga : Error
# l11_4_2 : Error
# conga_refl : Error
# l11_13 : Error
# conga_pseudo_refl : Error
# out2__conga : Error
# conga_right_comm : Error
# conga_line : Error
# l11_10 : Error
# l11_16 : Error
# l11_17 : Error
# cong3_preserves_out : Error
# l11_18_2 : Error
# l11_21_b : Error
# cong2_conga_cong : Error
# angle_construction_1 : Error
# conga__or_out_ts : Error
# ex_conga_ts : Error
# l11_15 : Error
# l11_22_bet : Error
# l11_19 : Error
# l11_22a : Error
# l11_22b : Error
# in_angle_out : Error
# l11_25_aux : Error
# l11_25 : Error
# bet_conga_bet : Error
# l11_28 : Error
# out_in_angle_out : Error
# inangle_one_side2 : Error
# inangle_one_side : Error
# in_angle_one_side : Error
# col_conga_col : Error
# l11_29_a : Error
# l11_29_b : Error
# eq_conga_out : Error
# conga_preserves_in_angle : Error
# out_conga_out : Error
# l11_30 : Error
# l11_31_2 : Error
# inangle__lea : Error
# lea_trans : Error
# in_angle_trans : Error
# in_angle_asym : Error
# lea_asym : Error
# not_two_sides_one_side : Error
# in_angle_trans2 : Error
# col_perp_perp_col : Error
# l11_41_aux : Error
# in_angle_reverse : Error
# l11_41 : Error
# lta_trans : Error
# conga_preserves_lta : Error
# lea_right_comm : Error
# bet_acute__obtuse : Valid
# lta_right_comm : Error
# conga_preserves_gta : Error
# l11_43_aux : Error
# obtuse_sym : Error
# acute_lea_acute : Error
# lea_acute_obtuse : Error
# l11_44_1_a : Error
# l11_44_2_a : Error
# lta_diff : Error
# obtuse_gea_obtuse : Error
# l11_44_2_b : Error
# l11_46 : Error
# l11_49 : Error
# l11_47 : Error
# l11_50_1 : Error
# l11_50_2 : Error
# l11_52 : Error
# l11_51 : Error
# l11_53 : Error
# per2_cong2__cong_conga2 : Error
# hilbert_s_version_of_pasch_aux : Error
# per2_cong2__cong_3 : Error
# not_one_side_two_sides : Error
# two_sides_cases : Error
# one_or_two_sides : Error
# not_par_other_side : Error
# not_par_same_side : Error
# not_par_two_sides : Error
# lea_distincts : Error
# os_ts__inangle : Error
# gea_distincts : Error
# lta_distincts : Error
# gta_distincts : Error
# obtuse_conga__obtuse : Error
# lea123456_lta__lta : Error
# acute_per__lta : Error
# lea456789_lta__lta : Error
# obtuse_per__lta : Error
# acute_obtuse__lta : Error
# out__acute : Error
# bet__obtuse : Error
# lea_in_angle : Error
# lea_total : Error
# bet_obtuse__acute : Error
# angle_partition : Error
# gea_total : Error
# obtuse_chara : Error
# lea__nlta : Error
# conga__acute : Error
# acute_chara : Error
# nlta__lea : Error
# nlea__lta : Error
# lta__nlea : Error
# triangle_strict_inequality : Error
# triangle_strict_inequality_2 : Error
# triangle_inequality_2 : Error
# triangle_inequality : Error
# triangle_strict_reverse_inequality : Error
# bet_le__lt : Error
# os3__lta : Error
# triangle_reverse_inequality : Error
# t18_18_aux : Error
# t18_18 : Error
# t18_19 : Error
# angle_bisector : Error
# acute_trivial : Error
# reflectl__conga : Error
# col_conga_reflectl__col : Error
# out_conga_reflect__out : Error
# conga2__col : Error
# inangle__ex_col_inangle : Error
# col_conga__conga : Error
# col_inangle2__out : Error
# conga_inangle_per__acute : Error
# inangle2__lea : Error
# conga_inangle2_per__acute : Error
# lta_os__ts : Error
# acute_one_side_aux0 : Error
# acute_one_side_aux : Error
# par_right_comm : Error
# acute_one_side : Error
# parallel_existence : Error
# l12_9 : Error
# par_col_par : Error
# inter_uniqueness_not_par : Error
# parallel_existence1 : Error
# par_col_par_2 : Error
# par_col2_par_bis : Error
# par_strict_col_par_strict : Error
# par_strict_one_side : Error
# l12_18_a : Error
# inter_sym : Error
# l12_18_c : Error
# l12_17 : Error
# l12_18 : Error
# l12_22_aux : Error
# l12_21_b : Error
# l12_22_b : Error
# acute_col_perp__out : Error
# acute_col_perp__out_1 : Error
# null_anga_null_anga' : Error
# conga_inangle_per2__inangle : Error
# cong_conga_perp : Error
# par_col4__par : Error
# perp_not_par : Error
# bet__trisuma : Error
# parallel_uniqueness : Error
# l12_19 : Error
# l12_20_bis : Error
# l12_20 : Error
# par_trans : Error
# l12_16 : Error
# l12_22_a : Error
# l12_21_a : Error
# l12_23 : Error
# col_par_par_col : Error
# trisuma__bet : Error
# not_par_inter : Error
# per23_preserves_bet : Error
# not_obtuse : Error
# suma__sams : Error
# per13_preserves_bet : Error
# per23_preserves_bet_inv : Error
# per13_preserves_bet_inv : Error
# per3_preserves_bet2_aux : Error
# per3_preserves_bet1 : Error
# per3_preserves_bet2 : Error
# cong_perp_conga : Error
# l13_1 : Error
# symmetry_preserves_per : Error
# perp_per_bet : Error
# l13_2_1 : Error
# ts_per_per_ts : Error
# lcos2_exists' : Error
# l13_2 : Error
# triangle_mid_par : Error
# perp2_trans : Error
# perp_in_perp_in_col : Error
# perp2_perp_in : Error
# perp2_preserves_bet23 : Error
# perp2_preserves_bet13 : Error
# conga_preserves_obtuse : Error
# l13_8 : Error
# acute_bet_obtuse : Error
# perp_out_acute : Error
# ex_point_lg_out : Error
# ang_conga : Error
# ex_points_lg_not_col : Error
# null_ang : Error
# is_anga_to_is_ang : Error
# out_len_eq : Error
# null_anga : Error
# ex_anga : Error
# ang_sym : Error
# anga_sym : Error
# anga_acute : Error
# acute_not_bet : Error
# acute_col_out : Error
# is_null_ang_out : Error
# out_null_ang : Error
# anga_not_flat : Error
# anga_const_o : Error
# eqA_preserves_ang : Error
# eql_lcos_null : Error
# anga_out_anga : Error
# perp_acute_out : Error
# l13_6 : Error
# null_lcos_eql : Error
# perp_obtuse_bet : Error
# obtuse_not_acute : Error
# lcos_const1 : Error
# acute_not_obtuse : Error
# lcos_const_a : Error
# lcos_const_ab : Error
# acute_comp_not_acute : Error
# lcos_const_cb : Error
# lcos_const_o : Error
# flat_not_acute : Error
# lcos_per : Error
# l13_7 : Error
# lcos_lg : Error
# perp_acute : Error
# out_acute : Error
# null_lcos : Error
# lcos2_exists : Error
# lcos_exists : Error
# lcos2_eq_trans : Error
# lcos_eq_trans : Error
# lcos3_permut3 : Error
# lcos_eq_lcos2_eq : Error
# lcos2_eql_lcos2 : Error
# lcos3_permut1 : Error
# lcos3_permut2 : Error
# lcos3_exists : Error
# lcos3_eql_lcos3 : Error
# lcos3_eq_trans : Error
# lcos3_lcos2 : Error
# l13_10_aux2 : Error
# l13_10_aux1 : Error
# l13_6_bis : Error
# lcos2_lcos : Error
# lcos_per_anga : Error
# lcos_lcos_col : Error
# l13_10_aux3 : Error
# l13_10_aux5 : Error
# l13_10_aux4 : Error
# l13_10 : Error
# par_perp2 : Error
# l13_15_1 : Error
# l13_11 : Error
# l13_14 : Error
# l13_15_2 : Error
# l13_15_par : Error
# l13_18_3 : Error
# l13_18_2 : Error
# l13_19 : Error
# l13_19_aux : Error
# l13_18 : Error
# l13_19_par_aux : Error
# sum_to_sump : Error
# l13_19_par : Error
# project_trivial : Error
# sump_to_sum : Error
# project_col_project : Error
# sum_uniqueness : Error
# sum_exists : Error
# opp0 : Error
# opp_exists : Error
# sum_A_O : Error
# sum_O_B : Error
# proj_pars : Error
# opp0_uniqueness : Error
# grid_not_par : Error
# proj_col : Error
# proj_id : Error
# sum_A_O_eq : Error
# sum_O_B_eq : Error
# sum_A_B_A : Error
# sum_par_strict : Error
# sum_uniquenessA : Error
# sum_A_B_B : Error
# sum_uniquenessB : Error
# sum_A_null : Error
# sum_B_null : Error
# sum_cong2 : Error
# sum_cong : Error
# cong_sum : Error
# sum_comm : Error
# opp_uniqueness : Error
# sum_iff_cong : Error
# pj_uniqueness : Error
# proj_preserves_sum : Error
# sum_assoc_2 : Error
# sum_assoc_1 : Error
# sum_y_axis_change : Error
# sum_x_axis_unit_change : Error
# double_not_null_not_null : Error
# change_grid_sum_0 : Error
# change_grid_sum : Error
# double_null_null : Error
# diff_exists : Error
# diff_null : Error
# diff_uniqueness : Error
# diff_O_A : Error
# diff_A_O : Error
# diff_O_A_opp : Error
# diff_uniquenessA : Error
# diff_uniquenessB : Error
# diff_null_eq : Error
# sum_diff : Error
# diff_opp : Error
# midpoint_opp : Error
# diff_sum : Error
# sum_stable : Error
# plg_to_sum : Error
# opp_midpoint : Error
# sum3_permut : Error
# diff_to_plg : Error
# sum3_comm_1_2 : Error
# sum3_uniqueness : Error
# sum3_exists : Error
# sum4_permut : Error
# sum_B_exists : Error
# sum4_equiv : Error
# sum4_comm : Error
# sum22_comm : Error
# sum_abcd : Error
# sum_diff_diff_a : Error
# sum_diff2_diff_sum2_a : Error
# sum_diff_diff_b : Error
# sum_diff2_diff_sum2_b : Error
# sum_plg : Error
# sum_diff_diff : Error
# prodp_to_prod : Error
# prod_exists : Error
# prod_to_prodp : Error
# prod_uniqueness : Error
# prod_0_l : Error
# prod_0_r : Error
# prod_1_l : Error
# inv_exists : Error
# prod_1_r : Error
# prod_null : Error
# prod_assoc1 : Error
# prod_y_axis_change : Error
# proj_preserves_prod : Error
# prod_assoc2 : Error
# prod_comm : Error
# prod_O_r_eq : Error
# prod_O_l_eq : Error
# prod_uniquenessA : Error
# prod_uniquenessB : Error
# distr_r : Error
# distr_l : Error
# prod_1_l_eq : Error
# prod_1_r_eq : Error
# change_grid_prod_l_O : Error
# change_grid_prod1 : Error
# change_grid_prod : Error
# l14_31_2 : Error
# l14_31_1 : Error
# prod_x_axis_unit_change : Error
# opp_prod : Error
# distr_l_diff : Error
# diff_of_squares : Error
# eq_squares_eq_or_opp : Error
# l14_36_a : Error
# l14_36_b : Error
# pos_null_neg : Error
# ltP_sum_pos : Error
# sum_pos_pos : Error
# prod_pos_pos : Error
# leP_trans : Error
# leP_sum_leP : Error
# square_pos : Error
# ltP_neg : Error
# ps_le : Error
# col_2_le_or_ge : Error
# lt_diff_ps : Error
# compatibility_of_sum_with_order : Error
# le_pos_prod_le : Error
# compatibility_of_prod_with_order : Error
# bet_lt12_le23 : Error
# bet_lt12_le13 : Error
# bet_lt21_le32 : Error
# bet_lt21_le31 : Error
# opp_2_le_le : Error
# ltP_pos : Error
# diff_2_le_le : Error
# bet_leP : Error
# length_leP_le_1 : Error
# length_leP_le_2 : Error
# length_uniqueness : Error
# l15_3 : Error
# triangular_equality_bis : Error
# triangular_equality : Error
# length_Ps : Error
# triangular_equality_equiv : Error
# length_out : Error
# project_preserves_out : Error
# thales : Error
# l15_7 : Error
# l15_7_1 : Error
# length_existence : Error
# l15_7_2 : Error
# pythagoras : Error
# is_length_exists : Error
# PythOK : Error
# PythRel_exists : Error
# opp_same_square : Error
# PythRel_uniqueness : Error
# grid_exchange_axes : Error
# exists_grid : Error
# exists_grid_spec : Error
# coord_exchange_axes : Error
# exists_projp : Error
# coordinates_of_point : Error
# exists_coord : Error
# point_of_coordinates_origin : Error
# point_of_coordinates_on_an_axis : Error
# eq_points_coordinates : Error
# point_of_coordinates : Error
# l16_9_1 : Error
# length_eq_or_opp : Error
# l16_9_2 : Error
# cong_3_3_cong_5 : Error
# cong_3_2_cong_4 : Error
# square_distance_formula_aux : Error
# square_distance_formula : Error
# characterization_of_congruence : Error
# bet_betCood_aux : Error
# bet_betCood : Error
# characterization_of_betweenness_aux : Error
# characterization_of_betweenness : Error
# characterization_of_collinearity : Error
# same_abscissa_col : Error
# iter remaining : 38
# 0.16750418760469013% good to go = 596 GaveUp = 0.16778523489932887 TimeOut = 5.033557046979865 RessourceOut = 94.79865771812081 size = 597

# %%
with open("data_seuil_grid_ok.txt", "wb") as fp:
    pickle.dump(data, fp)
    
with open("data_seuil_grid_ok.txt", "rb") as fp:
    b = pickle.load(fp)

# %%
def get_lemme_by_decl(decl) :
    for lemme in ax_th_declaration :
        if decl in ax_th_declaration[lemme] :
            return lemme
    return "nope"

# %%
lemme='not_col_exists'
print(get_chapter(lemme))
print(ax_th_declaration[lemme])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a17445b53f17> in <module>
#       1 lemme='not_col_exists'
# ----> 2 print(get_chapter(lemme))
#       3 print(ax_th_declaration[lemme])
#
# NameError: name 'get_chapter' is not defined

# %%
done = list(itertools.chain.from_iterable([done[1] for done in b]))

# %% [raw]
# for th in done :
#     lemme_file=zf_dir_path+get_chapter(th)+"/"+th+".zf"
#     dot_file=zf_dir_path+get_chapter(th)+"/"+th+".dot"
#     if os.path.isfile(lemme_file) :
#         res=os.popen("zipperposition -o none --mem-limit 4000 --dot "+dot_file+" "+lemme_file).read()
#     dot_to_dep(dot_file,"./dependencies_v2/"+get_chapter(th)+"/"+th+".dep")
#     os.remove(dot_file)

# %%
for th in list(set(th_valid)-set(tarski)-set(done)) :
    dep_file_from="./dependencies/"+get_chapter(th)+"/"+th+".dep"
    dep_file_to=dep_dir_path+get_chapter(th)+"/"+th+".dep"
    copy_dep(dep_file_from,dep_file_to)

# %%
i=0
for th in done :
    if set(dep_to_list("./dependencies_v2/"+get_chapter(th)+"/"+th+".dep"))!=set(dep_to_list(dep_dir_path+get_chapter(th)+"/"+th+".dep")) :
        i+=1
        print(get_chapter(th)+"/"+th)
        print(set(dep_to_list("./dependencies_v2/"+get_chapter(th)+"/"+th+".dep")))
        print(set(dep_to_list(dep_dir_path+get_chapter(th)+"/"+th+".dep")))
print(i)
# Out:
# Ch02_cong/eq_dec_points
# set()
# {'point_equality_decidability'}
# Ch02_cong/Cong_cases
# {'cong_symmetry'}
# {'cong_right_commutativity', 'cong_symmetry', 'cong_4312', 'cong_3421', 'cong_left_commutativity', 'cong_commutativity', 'cong_4321'}
# Ch03_bet/bet_neq21__neq
# {'between_identity'}
# {'bet_neq12__neq'}
# Ch03_bet/bet_neq32__neq
# {'between_identity'}
# {'bet_neq23__neq'}
# Ch03_bet/two_distinct_points
# {'between_trivial', 'lower_dim_ex'}
# {'between_trivial', 'eq_dec_points', 'lower_dim_ex'}
# Ch03_bet/bet_dec_eq_dec_b
# set()
# {'between_identity', 'between_trivial'}
# Ch03_bet/cong_dec_eq_dec_b
# set()
# {'cong_pseudo_reflexivity', 'cong_identity'}
# Ch04_col/Col_cases
# {'Col'}
# {'col_permutation_5', 'col_permutation_3', 'col_permutation_2', 'col_permutation_1', 'col_permutation_4'}
# Ch04_col/NCol_cases
# {'not_col_permutation_3'}
# {'not_col_permutation_1', 'not_col_permutation_2', 'not_col_permutation_4', 'not_col_permutation_5', 'not_col_permutation_3'}
# Ch05_bet_le/Cong_dec
# set()
# {'Cong_3', 'cong_4312', 'cong_3_swap_2', 'cong_trivial_identity', 'cong_right_commutativity', 'cong_reflexivity', 'five_segment_with_def', 'OFSC', 'cong_symmetry', 'cong_3_swap', 'IFSC', 'between_exchange3', 'between_inner_transitivity', 'between_identity', 'FSC', 'segment_construction', 'between_trivial', 'between_symmetry', 'cong_left_commutativity', 'inner_pasch', 'cong_commutativity', 'between_equality', 'cong_4321', 'five_segment', 'bet_col', 'Col', 'cong_3421', 'lower_dim_ex', 'cong_transitivity', 'cong_identity', 'eq_dec_points'}
# Ch05_bet_le/Col_dec
# {'Col'}
# {'Col', 'bet_dec'}
# Ch05_bet_le/bet_dec
# set()
# {'Cong_3', 'cong_4312', 'cong_3_swap_2', 'cong_trivial_identity', 'cong_right_commutativity', 'cong_reflexivity', 'five_segment_with_def', 'OFSC', 'cong_symmetry', 'cong_3_swap', 'IFSC', 'between_exchange3', 'between_inner_transitivity', 'between_identity', 'FSC', 'segment_construction', 'between_trivial', 'between_symmetry', 'cong_left_commutativity', 'inner_pasch', 'cong_commutativity', 'between_equality', 'cong_4321', 'five_segment', 'between_trivial2', 'bet_col', 'Col', 'cong_3421', 'lower_dim_ex', 'cong_transitivity', 'cong_identity', 'eq_dec_points'}
# Ch06_out_lines/out_dec
# set()
# {'bet_dec', 'eq_dec_points', 'Out'}
# Ch06_out_lines/out_distinct
# {'Out'}
# {'out_diff1', 'out_diff2'}
# Ch06_out_lines/not_bet_out
# {'or_bet_out', 'Col'}
# {'or_bet_out'}
# Ch07_midpoint/is_midpoint_dec
# {'Midpoint'}
# {'Midpoint', 'bet_dec'}
# Ch08_orthogonality/Per_dec
# set()
# {'symmetric_point_uniqueness', 'symmetric_point_construction', 'Per'}
# Ch08_orthogonality/Perp_in_dec
# set()
# {'col_trivial_3', 'col_trivial_1', 'Per_dec', 'Perp_at', 'col_col_per_per', 'eq_dec_points'}
# Ch08_orthogonality/Perp_cases
# {'perp_right_comm'}
# {'perp_comm', 'perp_right_comm', 'perp_left_comm', 'perp_sym'}
# Ch08_orthogonality/perp_not_eq_2
# {'Perp', 'Perp_at'}
# {'perp_not_eq_1', 'perp_sym'}
# Ch09_plane/distinct
# set()
# {'eq_dec_points'}
# Ch10_line_reflexivity_2D/two_sides_dec
# set()
# {'col_permutation_3', 'perp_distinct', 'col_permutation_1', 'col_trivial_2', 'l4_17', 'col_trivial_1', 'not_col_distincts', 'perp_right_comm', 'l7_20', 'construction_uniqueness', 'l5_6', 'OS', 'l9_8_2', 'swap_diff', 'l9_2', 'cong_right_commutativity', 'col_permutation_4', 'l2_11', 'col_permutation_5', 'le_bet', 'invert_two_sides', 'perp_in_left_comm', 'midpoint_col', 'midpoint_distinct_1', 'cong_reflexivity', 'col_trivial_3', 'l9_8_1', 'perp_sym', 'between_cong_2', 'Midpoint', 'l9_9', 'segment_construction_2', 'perp_left_comm', 'l4_3', 'cong_diff', 'cong_symmetry', 'l4_18', 'perp_perp_in', 'TS', 'midpoint_existence', 'cong_diff_2', 'midpoint_distinct_2', 'l6_13_2', 'l8_21', 'between_identity', 'perp_in_right_comm', 'segment_construction', 'l8_18_existence', 'between_symmetry', 'cong_left_commutativity', 'all_coplanar', 'out_one_side', 'l7_3', 'perp_comm', 'cong_4321', 'col_preserves_two_sides', 'cong_commutativity', 'per_not_col', 'not_col_permutation_5', 'five_segment', 'symmetric_point_uniqueness', 'bet_col', 'perp_in_per', 'perp_in_sym', 'eq_dec_points', 'perp_not_col', 'not_col_permutation_4', 'cong_transitivity', 'cong_identity', 'l7_17', 'perp_col'}
# Ch10_line_reflexivity_2D/one_side_dec
# set()
# {'bet_neq23__neq', 'perp_col', 'col_permutation_3', 'perp_distinct', 'col_permutation_1', 'col_trivial_2', 'not_col_distincts', 'l7_20', 'perp_right_comm', 'OS', 'l9_8_2', 'col_permutation_4', 'l9_2', 'col_permutation_5', 'invert_two_sides', 'perp_in_left_comm', 'col_trivial_3', 'l9_8_1', 'perp_sym', 'cong_diff_3', 'Midpoint', 'l9_9', 'perp_left_comm', 'segment_construction_2', 'cong_symmetry', 'perp_perp_in', 'TS', 'l8_21', 'perp_in_right_comm', 'l8_18_existence', 'out_one_side', 'per_not_col', 'not_col_permutation_5', 'perp_comm', 'col_preserves_two_sides', 'per_per_col', 'bet_col', 'perp_in_per', 'perp_in_sym', 'not_col_permutation_4', 'one_side_reflexivity', 'perp_not_col', 'cong_identity', 'eq_dec_points'}
# Ch10_line_reflexivity/is_image_spec_dec
# set()
# {'Reflect', 'perp_distinct', 'eq_dec_points', 'is_image_spec_triv', 'l10_6_uniqueness', 'ReflectL', 'l10_6_existence_spec'}
# Ch11_angles/conga_dec
# set()
# {'CongA', 'construction_uniqueness', 'segment_construction', 'eq_dec_points'}
# Ch11_angles/inangle_dec
# {'InAngle'}
# {'col_trivial_2', 'not_col_distincts', 'col_trivial_1', 'in_angle_two_sides', 'two_sides_in_angle', 'l6_21', 'swap_diff', 'out2_bet_out', 'col_permutation_5', 'invert_two_sides', 'midpoint_col', 'col_trivial_3', 'not_bet_out', 'InAngle', 'out_col', 'midpoint_distinct_2', 'out_distinct', 'l6_7', 'l6_4_1', 'between_trivial', 'between_symmetry', 'not_col_permutation_5', 'symmetric_point_construction', 'bet_dec', 'two_sides_dec', 'between_trivial2', 'out_dec', 'midpoint_bet', 'bet_col', 'l6_6', 'eq_dec_points'}
# Ch11_angles/lea_dec
# set()
# {'bet_dec', 'out_col', 'inangle_dec', 'angle_construction_1', 'bet_lea__bet', 'out_dec', 'lea_distincts', 'one_side_symmetry', 'out_lea__out', 'not_bet_out', 'col_permutation_4', 'lea_in_angle', 'not_out_bet', 'l11_31_1', 'l11_30', 'conga_refl', 'l11_31_2', 'eq_dec_points'}
# Ch11_angles/gea_dec
# {'GeA'}
# {'GeA', 'lea_dec'}
# Ch11_angles/lta_dec
# set()
# {'LtA', 'conga_dec', 'lea_dec'}
# Ch11_angles/gta_dec
# {'GtA'}
# {'lta_dec', 'GtA'}
# Ch12_parallel/Par_strict_cases
# {'par_strict_comm'}
# {'par_strict_symmetry', 'par_strict_left_comm', 'par_strict_comm', 'par_strict_right_comm'}
# Ch12_parallel/Perp_dec
# set()
# {'col_permutation_5', 'perp_perp_col', 'l8_14_2_1a', 'perp_distinct', 'col_permutation_2', 'col_permutation_1', 'perp_in_right_comm', 'perp_sym', 'l8_15_1', 'perp_right_comm', 'l8_18_existence', 'perp_col1', 'Perp_in_dec', 'eq_dec_points'}
# Ch12_parallel/par_strict_distinct
# {'Par_strict'}
# {'par_strict_par', 'par_distincts'}
# Ch12_parallel_inter_dec/inter_dec
# set()
# {'acute_obtuse__lta', 'one_side_symmetry', 'l10_2_existence', 'not_par_same_side', 'hilbert_s_version_of_pasch_aux', 'out_conga', 'col_permutation_2', 'out_conga_out', 'col123__nos', 'l8_7', 'Saccheri', 'l11_41', 'l11_17', 'out_lea__out', 'lta_distincts', 'midpoint_cong', 'all_coplanar', 'conga_sym', 'os_ts1324__os', 'l11_22a', 'l8_13_2', 'l12_9', 'col_permutation_3', 'par_strict_col_par_strict', 'col_permutation_1', 'or_lt_cong_gt', 'l10_15', 'col_trivial_1', 'one_side_not_col123', 'col_transitivity_1', 'le_right_comm', 'l5_1', 'l11_10', 'cong2_lt__lt', 'cong_diff', 'l8_3', 'os_ts__inangle', 'conga_right_comm', 'not_out_bet', 'inner_pasch', 'l6_16_1', 'bet_out_out_bet', 'per_per_col', 'nlta', 'out_dec', 'perp_perp_col_col', 'perp_col1', 'le_cases', 'in_angle_reverse', 'obtuse_chara', 'bet_neq21__neq', 'l11_44_1_a', 'cong_4312', 'is_midpoint_id_2', 'cong_reflexivity', 'l9_9_bis', 'out2__bet', 'lta_comm', 'out_distinct', 'par_id_1', 'perp_per_1', 'perp_not_col2', 'l11_14', 'par_strict_par', 'perp_col', 'perp_perp_in', 'lea123456_lta__lta', 'bet_out', 'lea_refl', 'per_col', 'BetS', 'cong_right_commutativity', 'midpoint_distinct_1', 'conga_preserves_in_angle', 'perp_sym', 'os3__lta', 'col124__nos', 'obtuse_gea_obtuse', 'l12_21_b', 'cong_commutativity', 'l8_14_2_1b_bis', 'l5_5_1', 'lea_trans', 'cong_3421', 'col_transitivity_2', 'thales', 'midpoint_distinct_3', 'image_preserves_per', 'l11_22b', 'two_sides_not_col', 'l11_16', 'lea__nlta', 'os_distincts', 'le_comm', 'ncol_conga_ncol', 'segment_construction_3', 'l11_18_1', 'acute_sym', 'conga_diff1', 'lea_comm', 'per_not_col', 'par_right_comm', 'midpoint_bet', 'l11_50_2', 'col_conga_col', 'l8_14_2_1a', 'conga__or_out_ts', 'par_left_comm', 'OS', 'l9_17', 'Par', 'midpoint_col', 'conga_pseudo_refl', 'lea_right_comm', 'line_dec', 'acute_per__lta', 'acute_lea_acute', 'perp2_par', 'segment_construction_2', 'perp_left_comm', 'bet_conga_bet', 'triangle_mid_par', 'midpoint_distinct_2', 'l8_18_existence', 'l7_3', 'not_col_permutation_5', 'lt_comm', 'not_col_permutation_2', 'outer_pasch', 'Col', 'acute_chara', 'par_strict_neq2', 'Perp_bisect', 'l11_36', 'bet_neq32__neq', 'l11_24', 'par_strict_not_col_3', 'l9_2', 'col_permutation_5', 'par_strict_not_col_4', 'par_id', 'par_col_par', 'perp_col2', 'Lambert', 'Perp_at', 'ReflectL', 'col3', 'l6_6', 'col_one_side', 'l11_30', 'perp_perp_col', 'in_angle_trans', 'not_strict_par', 'l11_49', 'l11_51', 'out_out_one_side', 'lea_total', 'nlea__lta', 'par_symmetry', 'l11_31_1', 'not_par_other_side', 'between_identity', 'angle_partition', 'l5_2', 'out_one_side', 'perp_in_col', 'par_strict_left_comm', 'par_not_col_strict', 'lta_trans', 'col_trivial_2', 'lea_dec', 'l6_21', 'conga__lea', 'cong_diff_4', 'conga_diff56', 'cong_diff_3', 'acute_conga__acute', 'Midpoint', 'l9_9', 'not_lta_and_gta', 'not_strict_par1', 'not_col_permutation_1', 'between_inner_transitivity', 'l6_7', 'not_bet_distincts', 'perp_exists', 'par_strict_comm', 'l7_20_bis', 'perp_comm', 'l9_31', 'par_col_par_2', 'conga_trivial_1', 't18_18', 'l11_18_2', 'lea_left_comm', 'obtuse_sym', 'par_distincts', 'par_strict_col2_par_strict', 'l12_17', 'perp_right_comm', 'obtuse_conga__obtuse', 'bet_lea__bet', 'col_permutation_4', 'bet_obtuse__acute', 'obtuse_per__lta', 'conga_diff2', 'le_diff', 'midpoint_existence', 'not_two_sides_one_side', 'perp_in_right_comm', 'col_two_sides_bet', 'col_preserves_two_sides', 'l8_14_2_1b', 'l10_10_spec', 'perp_not_col', 'cong_transitivity', 'conga_diff45', 'in_angle_one_side', 'not_col_distincts', 'angle_construction_3', 'swap_diff', 'cong_mid2__cong', 'par_id_2', 'os2__inangle', 'l6_4_2', 'par_strict_symmetry', 'TS', 'l6_4_1', 'l9_19', 'par_neq1', 'cong_left_commutativity', 'symmetric_point_construction', 'outer_transitivity_between2', 'col_one_side_out', 'l7_9_bis', 'cong_cong_half_1', 'lea_acute_obtuse', 'per_perp_in', 'par_strict_neq1', 'lea_asym', 'col2_os__os', 't18_19', 'l11_22', 'out_trivial', 'Per', 'l10_4_spec', 'l6_13_1', 'le_zero', 'conga_refl', 'diff_col_ex3', 'par ...
# Ch12_parallel_inter_dec/Par_dec
# set()
# {'col_permutation_5', 'par_id_3', 'parallel_existence1', 'par_neq1', 'par_symmetry', 'par_left_comm', 'par_col_par', 'par_trans', 'par_neq2', 'eq_dec_points'}
# Ch13_2_length/lg_null_dec
# set()
# {'Q_Cong', 'cong_reflexivity', 'Q_Cong_Null', 'cong_identity', 'eq_dec_points'}
# Ch13_4_cos/is_null_anga_dec
# set()
# {'out_dec', 'Q_CongA_Acute', 'acute_distincts', 'out_conga_out', 'conga_refl', 'Q_CongA_Null_Acute'}
# Ch13_4_cos/lcos2_comm
# set()
# {'lcos_lg_not_null', 'l13_7', 'lcos_lg_anga', 'lcos_eql_lcos', 'lcos2', 'lcos_exists'}
# Ch14_sum/sum3_to_sum4
# {'Sum4'}
# {'sum_ar2', 'sum3_col', 'Sum4', 'Ar2'}
# Ch05_bet_le/le_comm
# {'le1221', 'le_transitivity'}
# {'le_left_comm', 'le_right_comm'}
# Ch05_bet_le/ge_comm
# {'ge_right_comm', 'Ge', 'ge_left_comm'}
# {'ge_right_comm', 'ge_left_comm'}
# Ch09_plane/col_eq
# {'l6_21', 'col_trivial_2'}
# {'l6_21', 'col_trivial_2', 'not_col_distincts'}
# Ch10_line_reflexivity/image_col
# {'Col', 'ReflectL', 'l7_3_2'}
# {'ReflectL', 'l7_3_2'}
# Ch11_angles/in_angle_trivial_1
# {'out321__inangle', 'out_trivial'}
# {'not_and_lta', 'out_trivial'}
# Ch13_1/per2_preserves_diff
# {'col_permutation_1', 'per2_col_eq'}
# {'col_permutation_5', 'per2_col_eq', 'col_permutation_1'}
# Ch04_col/col_trivial_2
# {'Col', 'between_trivial'}
# {'Col', 'between_symmetry', 'between_trivial2'}
# Ch04_col/col_trivial_1
# {'Col', 'between_trivial'}
# {'Col', 'between_trivial', 'between_symmetry'}
# Ch04_col/col_trivial_3
# {'Col', 'between_trivial'}
# {'Col', 'between_trivial', 'between_symmetry'}
# Ch04_col/NCol_perm
# {'col_permutation_5', 'not_col_permutation_1'}
# {'not_col_permutation_1', 'not_col_permutation_2', 'not_col_permutation_4', 'not_col_permutation_5', 'not_col_permutation_3'}
# Ch08_orthogonality/Perp_perm
# {'perp_right_comm', 'Perp', 'perp_sym'}
# {'perp_comm', 'perp_right_comm', 'perp_left_comm', 'perp_sym'}
# Ch02_cong/cong_right_commutativity
# {'cong_symmetry', 'cong_pseudo_reflexivity', 'cong_inner_transitivity'}
# {'cong_symmetry', 'cong_left_commutativity'}
# Ch02_cong/cong_4312
# {'cong_symmetry', 'cong_pseudo_reflexivity', 'cong_inner_transitivity'}
# {'cong_right_commutativity', 'cong_symmetry'}
# Ch02_cong/cong_trivial_identity
# {'cong_identity', 'segment_construction'}
# {'cong_identity', 'cong_inner_transitivity', 'segment_construction', 'cong_reflexivity'}
# Ch02_cong/cong_4321
# {'cong_symmetry', 'cong_pseudo_reflexivity', 'cong_inner_transitivity'}
# {'cong_right_commutativity', 'cong_symmetry'}
# Ch06_out_lines/l6_7
# {'l5_1', 'l5_3', 'between_exchange4', 'Out'}
# {'l5_1', 'between_exchange4', 'Out', 'l5_3', 'between_symmetry'}
# Ch11_angles/conga__lea
# {'conga_right_comm', 'LeA', 'conga_diff45', 'in_angle_trivial_2'}
# {'LeA', 'conga_diff56', 'conga_diff45', 'in_angle_trivial_2'}
# Ch12_parallel/Par_cases
# {'Par', 'par_right_comm'}
# {'par_right_comm', 'par_symmetry', 'par_left_comm', 'par_comm'}
# Ch02_cong/cong_commutativity
# {'cong_inner_transitivity', 'cong_pseudo_reflexivity'}
# {'cong_right_commutativity', 'cong_left_commutativity'}
# Ch02_cong/cong_left_commutativity
# {'cong_inner_transitivity', 'cong_pseudo_reflexivity'}
# {'cong_symmetry', 'cong_pseudo_reflexivity', 'cong_inner_transitivity'}
# Ch05_bet_le/le_trivial
# {'Le', 'cong_trivial_identity', 'between_trivial2'}
# {'Le', 'cong_trivial_identity', 'between_symmetry', 'between_trivial2'}
# Ch06_out_lines/bet_out_out_bet
# {'between_symmetry', 'outer_transitivity_between', 'Out', 'between_exchange3'}
# {'outer_transitivity_between2', 'between_exchange3', 'between_inner_transitivity', 'Out', 'outer_transitivity_between', 'between_symmetry'}
# Ch10_line_reflexivity/l10_6_uniqueness
# {'l10_2_uniqueness', 'l10_4'}
# {'symmetric_point_uniqueness', 'Reflect', 'l10_2_uniqueness', 'l7_2', 'l10_4', 'eq_dec_points'}
# Ch12_parallel/par_id_4
# {'col_permutation_1', 'col_permutation_5', 'par_id'}
# {'col_permutation_2', 'col_permutation_5', 'par_id'}
# Ch12_parallel/par_id_2
# {'col_permutation_1', 'par_id'}
# {'col_permutation_5', 'par_id', 'col_permutation_4'}
# Ch12_parallel/par_id_5
# {'col_permutation_1', 'par_id'}
# {'col_permutation_5', 'par_id', 'col_permutation_3'}
# Ch13_3_angles/is_anga_distinct
# {'Ang', 'Ang_Acute', 'is_ang_distinct', 'is_anga_to_is_ang'}
# {'is_ang_distinct', 'is_anga_to_is_ang'}
# Ch13_4_cos/lcos3_lcos_1_2
# {'Lcos3', 'lcos2'}
# {'lcos_lg_anga', 'Lcos3', 'lcos2'}
# Ch14_order/pos_inv_pos
# {'prod_1_l', 'col_trivial_2', 'Ar2', 'Prod'}
# {'prod_0_l', 'opp_comm', 'prod_comm', 'col_trivial_2', 'not_col_distincts', 'col_trivial_1', 'Ar2', 'col_trivial_3', 'opp_prod', 'Opp', 'Prod', 'pos_null_neg', 'prod_pos_pos', 'opp_pos_neg', 'neg_not_pos', 'diff_exists', 'opp_exists', 'prod_1_l', 'diff_A_O', 'between_symmetry', 'between_trivial', 'diff_uniqueness', 'Sum', 'prod_uniqueness', 'prod_assoc1'}
# Ch08_orthogonality/l8_8
# {'l8_2', 'l8_5', 'l8_7', 'Per'}
# {'l8_2', 'l8_5', 'l8_7'}
# Ch10_line_reflexivity/perp_vector
# {'perp_exists', 'perp_sym'}
# {'perp_comm', 'perp_exists', 'perp_sym'}
# Ch11_angles/out2__conga
# {'l11_10', 'out_distinct', 'conga_refl', 'out_trivial'}
# {'out_distinct', 'out_trivial', 'l6_6', 'l11_10', 'conga_refl'}
# Ch12_parallel/Par_perm
# {'par_symmetry', 'par_right_comm', 'par_left_comm'}
# {'par_right_comm', 'par_symmetry', 'par_left_comm', 'par_comm'}
# Ch13_1/perp_in_rewrite
# {'perp_in_col_perp_in', 'perp_in_left_comm', 'perp_in_sym', 'perp_in_right_comm', 'perp_in_col'}
# {'perp_in_col_perp_in', 'perp_in_left_comm', 'perp_in_sym', 'perp_in_right_comm', 'perp_in_col', 'eq_dec_points'}
# Ch13_3_angles/eqA_preserves_anga
# {'EqA', 'Q_CongA_Acute'}
# {'is_ang_distinct', 'eqA_preserves_ang', 'is_ang_conga', 'Q_CongA_Acute', 'LeA', 'ex_points_anga', 'in_angle_trivial_2', 'EqA', 'conga_sym', 'is_ang_conga_is_ang', 'acute_lea_acute', 'Ang'}
# Ch14_order/ltP_sum_pos
# {'LtP', 'Sum', 'sum_diff'}
# {'LtP', 'sum_diff'}
# Ch14_order/opp_pos_neg
# {'between_inner_transitivity', 'Out', 'outer_transitivity_between', 'opp_midpoint', 'Opp', 'between_symmetry', 'Ps', 'Midpoint', 'cong_identity', 'Ng'}
# {'between_inner_transitivity', 'Out', 'outer_transitivity_between', 'opp_midpoint', 'between_symmetry', 'Ps', 'Midpoint', 'cong_identity', 'Ng'}
# Ch14_order/pos_opp_neg
# {'between_inner_transitivity', 'Out', 'outer_transitivity_between', 'opp_midpoint', 'Opp', 'between_symmetry', 'Ps', 'Midpoint', 'cong_identity', 'Ng'}
# {'sum_ar2', 'Ar2', 'between_exchange3', 'Out', 'outer_transitivity_between', 'opp_midpoint', 'Opp', 'between_symmetry', 'Ps', 'Midpoint', 'cong_identity', 'Ng'}
# Ch02_cong/Cong_perm
# {'cong_symmetry', 'cong_left_commutativity'}
# {'cong_right_commutativity', 'cong_symmetry', 'cong_4312', 'cong_3421', 'cong_left_commutativity', 'cong_commutativity', 'cong_4321'}
# Ch06_out_lines/or_bet_out
# {'not_out_bet'}
# {'not_out_bet', 'out_dec'}
# Ch11_angles/in_angle_trivial_2
# {'out_trivial', 'out341__inangle'}
# {'in_angle_trivial_1', 'l11_24'}
# Ch11_angles/conga_sym_equiv
# {'CongA', 'conga_sym'}
# {'conga_sym'}
# Ch13_4_cos/lcos_const
# {'Lcos', 'Q_Cong', 'lg_sym'}
# {'Lcos', 'lg_sym'}
# Ch13_4_cos/lcos2_uniqueness
# {'lcos_eql_lcos', 'l13_6', 'lcos2'}
# {'lcos_lg_anga', 'l13_6', 'lcos_eql_lcos', 'lcos2'}
# Ch14_sum/opp_uniqueness
# {'sum_uniquenessB', 'sum_comm', 'Opp'}
# {'Parallelogram_strict', 'Cong_3', 'l7_13', 'col_trivial_2', 'one_side_symmetry', 'os_distincts', 'bet_neq12__neq', 'l6_21', 'cong3_conga', 'conga_diff56', 'out_conga', 'cong_diff_4', 'col_permutation_2', 'l7_2', 'sum_plg', 'not_col_exists', 'cong_diff_3', 'Midpoint', 'l9_9', 'cong_symmetry', 'not_col_permutation_1', 'between_inner_transitivity', 'all_coplanar', 'conga_sym', 'l9_31', 'par_col_par_2', 'col_cong2_bet2', 'l11_22a', 'between_cong', 'par_right_comm', 'midpoint_bet', 'sum_uniquenessB', 'outer_transitivity_between', 'col_two_sides', 'one_side_transitivity', 'Par_strict', 'col_permutation_3', 'par_distincts', 'le_anti_symmetry', 'col_permutation_1', 'l12_17', 'col_trivial_1', 'par_left_comm', 'OS', 'l11_13', 'col_transitivity_1', 'l9_8_2', 'col_permutation_4', 'l5_1', 'l2_11', 'Par', 'invert_two_sides', 'midpoint_col', 'conga_trans', 'par_trans', 'cong_diff', 'midpoint_existence', 'cong_diff_2', 'midpoint_distinct_2', 'segment_construction', 'conga_right_comm', 'l7_3', 'not_col_permutation_5', 'symmetric_point_uniqueness', 'between_trivial2', 'outer_pasch', 'Le', 'is_midpoint_id', 'cong_transitivity', 'l12_6', 'l7_17', 'col_cong2_bet1', 'eq_dec_points', 'mid_preserves_col', 'bet_neq23__neq', 'cong2_conga_cong', 'not_col_distincts', 'bet_neq21__neq', 'l7_20', 'cong_4312', 'bet_neq32__neq', 'par_distinct', 'is_midpoint_id_2', 'par_strict_not_col_3', 'l9_2', 'col_permutation_5', 'par_strict_not_col_4', 'cong_reflexivity', 'col_trivial_3', 'l7_9', 'l9_9_bis', 'conga_left_comm', 'l4_3', 'par_strict_symmetry', 'TS', 'l9_19', 'between_symmetry', 'between_trivial', 'cong_left_commutativity', 'one_or_two_sides', 'symmetric_point_construction', 'par_strict_not_col_1', 'outer_transitivity_between2', 'l7_9_bis', 'bet_col', 'between_exchange2', 'col3', 'l6_6', 'col_one_side', 'l11_14', 'bet_cong_eq', 'par_strict_par', 'cong_identity', 'l7_3_2', 'Parallelogram_flat', 'between_exchange4', 'bet_out', 'out_trivial', 'conga_comm', 'l5_6', 'cong_trivial_identity', 'l5_5_2', 'par_comm', 'Parallelogram', 'cong_right_commutativity', 'l6_13_1', 'parallel_uniqueness', 'midpoint_distinct_1', 'Opp', 'par_symmetry', 'conga_refl', 'l12_22_b', 'par_strict_right_comm', 'between_exchange3', 'l7_15', 'between_identity', 'l5_2', 'sum_comm', 'par_strict_not_col_2', 'l12_21_a', 'cong_commutativity', 'cong_4321', 'par_strict_left_comm', 'invert_one_side', 'Out', 'par_not_col_strict', 'l11_22b', 'not_col_permutation_4', 'not_two_sides_id', 'one_side_reflexivity', 'cong_3421', 'two_sides_not_col', 'Plg'}
# Ch14_order/opp_neg_pos
# {'Out', 'l5_2', 'opp_midpoint', 'Ps', 'Midpoint', 'cong_identity', 'Ng'}
# {'Out', 'l5_2', 'opp_midpoint', 'l6_6', 'Ps', 'Midpoint', 'cong_identity', 'Ng'}
# Ch15_lengths/image_preserves_bet1
# {'image_preserves_bet', 'l7_15', 'Reflect', 'l7_2'}
# {'Reflect', 'l7_15', 'l7_2', 'image_preserves_bet', 'eq_dec_points'}
# Ch04_cong_bet/l4_3
# {'cong_commutativity', 'cong_trivial_identity', 'l4_2', 'IFSC'}
# {'cong_symmetry', 'IFSC', 'l4_2', 'cong_commutativity', 'cong_trivial_identity'}
# Ch05_bet_le/lt_comm
# {'cong_right_commutativity', 'Le', 'lt_right_comm', 'Lt', 'lt_left_comm'}
# {'lt_left_comm', 'lt_right_comm'}
# Ch09_plane/one_side_transitivity
# {'l9_8_2', 'OS'}
# {'OS', 'l9_8_1', 'l9_8_2', 'l9_2'}
# Ch10_line_reflexivity/osym_not_col
# {'col_trivial_1', 'image_id', 'l10_4', 'is_image_is_image_spec', 'ReflectL'}
# {'Reflect', 'perp_distinct', 'col_trivial_1', 'image_id', 'l10_4', 'is_image_is_image_spec', 'ReflectL'}
# Ch11_angles/out_in_angle
# {'between_exchange3', 'Out', 'l5_3', 'between_symmetry', 'InAngle'}
# {'l5_1', 'between_exchange4', 'midpoint_existence', 'between_exchange3', 'midpoint_bet', 'between_exchange2', 'outer_transitivity_between', 'between_inner_transitivity', 'Out', 'l7_2', 'l5_3', 'between_symmetry', 'between_equality', 'InAngle', 'eq_dec_points'}
# Ch11_angles/bet_in_angle_bet
# {'between_exchange4', 'between_inner_transitivity', 'Out', 'outer_transitivity_between', 'between_symmetry', 'between_equality', 'InAngle'}
# {'l5_1', 'between_exchange4', 'between_exchange2', 'between_inner_transitivity', 'Out', 'outer_transitivity_between', 'between_equality', 'InAngle'}
# Ch13_4_cos/lcos_not_lg_null
# {'anga_distincts', 'cong_symmetry', 'Q_Cong', 'Q_Cong_Null', 'Lcos', 'cong_identity'}
# {'anga_distincts', 'cong_symmetry', 'Q_Cong', 'Q_Cong_Null', 'Lcos', 'cong_left_commutativity', 'cong_transitivity', 'cong_identity'}
# Ch06_out_lines/l6_4_2
# {'between_trivial2', 'Out', 'Col', 'between_trivial', 'between_symmetry'}
# {'between_trivial2', 'Out', 'Col', 'between_symmetry', 'between_trivial', 'eq_dec_points'}
# Ch06_out_lines/out_trivial
# {'Out', 'between_trivial'}
# {'Out', 'between_symmetry', 'between_trivial2'}
# Ch06_out_lines/out_bet_out_1
# {'between_exchange2', 'between_inner_transitivity', 'Out', 'not_bet_and_out', 'between_symmetry'}
# {'between_exchange2', 'between_inner_transitivity', 'Out', 'not_bet_and_out', 'between_symmetry', 'eq_dec_points'}
# Ch07_midpoint/l7_9_bis
# {'Midpoint', 'cong_4321', 'between_symmetry', 'l7_9'}
# {'cong_symmetry', 'l7_9', 'between_symmetry', 'Midpoint', 'cong_4321'}
# Ch07_midpoint/col_cong2_bet2
# {'outer_transitivity_between', 'col_cong_bet', 'bet_cong_eq', 'cong_3421', 'between_symmetry', 'between_trivial', 'cong_identity'}
# {'cong_symmetry', 'outer_transitivity_between', 'col_cong_bet', 'bet_cong_eq', 'cong_3421', 'between_trivial', 'between_symmetry', 'cong_identity', 'eq_dec_points'}
# Ch08_orthogonality/l8_16_2
# {'col_permutation_1', 'l8_2', 'col_trivial_3', 'Perp', 'col_trivial_1', 'l8_13_2'}
# {'col_permutation_5', 'col_permutation_3', 'l8_2', 'col_trivial_3', 'Perp', 'col_trivial_1', 'l8_13_2'}
# Ch11_angles/l11_14
# {'conga_right_comm', 'between_symmetry', 'conga_pseudo_refl', 'l11_13'}
# {'conga_pseudo_refl', 'bet_neq21__neq', 'conga_right_comm', 'between_symmetry', 'bet_neq12__neq', 'l11_13'}
# Ch12_parallel_inter_dec/not_par_one_not_par
# {'par_trans', 'par_symmetry'}
# {'Par_dec', 'not_par_inter', 'par_symmetry', 'par_left_comm', 'par_trans'}
# Ch03_bet/between_trivial
# {'cong_reverse_identity', 'cong_symmetry', 'segment_construction'}
# {'cong_reverse_identity', 'cong_4321', 'segment_construction', 'cong_symmetry'}
# Ch06_out_lines/out_to_bet
# {'between_equality', 'Out', 'between_symmetry', 'not_out_bet'}
# {'out_dec', 'Out', 'between_symmetry', 'not_out_bet', 'between_equality'}
# Ch08_orthogonality/cong_perp_or_mid
# {'col_permutation_5', 'perp_in_col_perp_in', 'midpoint_distinct_1', 'bet_col', 'per_perp_in', 'perp_in_right_comm', 'l7_20', 'cong_commutativity', 'Midpoint', 'l7_17', 'Per'}
# {'col_permutation_5', 'cong_symmetry', 'perp_in_col_perp_in', 'Per', 'midpoint_distinct_1', 'bet_col', 'col_permutation_1', 'per_perp_in', 'perp_in_right_comm', 'not_col_distincts', 'l7_20', 'cong_commutativity', 'Midpoint', 'l7_17', 'col_permutation_4'}
# Ch08_orthogonality/Perp_in_cases
# {'perp_in_right_comm', 'Perp_at'}
# {'perp_in_sym', 'perp_in_left_comm', 'perp_in_right_comm', 'perp_in_comm'}
# Ch10_line_reflexivity/l10_8
# {'col_permutation_5', 'col_permutation_3', 'Reflect', 'col_trivial_2', 'l7_3', 'ReflectL'}
# {'col_permutation_5', 'col_permutation_3', 'Reflect', 'col_trivial_2', 'l7_3', 'ReflectL', 'eq_dec_points'}
# Ch10_line_reflexivity/perp_exists
# {'l10_15', 'perp_sym', 'l8_18_existence', 'perp_right_comm', 'not_col_exists'}
# {'col_permutation_5', 'col_permutation_3', 'l10_15', 'perp_sym', 'perp_right_comm', 'l8_18_existence', 'not_col_exists', 'col_permutation_4'}
# Ch11_angles/lea_right_comm
# {'conga_right_comm', 'LeA', 'l11_29_a', 'l11_29_b'}
# {'conga_right_comm', 'l11_29_b', 'l11_29_a'}
# Ch12_parallel/Par_strict_perm
# {'par_strict_symmetry', 'par_strict_right_comm', 'par_strict_comm'}
# {'par_strict_symmetry', 'par_strict_left_comm', 'par_strict_right_comm', 'par_strict_comm'}
# Ch13_1/perp2_refl
# {'l10_15', 'col_trivial_3', 'Perp2', 'perp_sym', 'col_trivial_1', 'l8_18_existence', 'not_col_exists'}
# {'col_trivial_3', 'l10_15', 'Perp2', 'perp_sym', 'col_trivial_1', 'l8_18_existence', 'not_col_exists', 'perp_comm'}
# Ch13_2_length/lg_sym
# {'lg_cong_lg', 'cong_reflexivity', 'cong_right_commutativity'}
# {'cong_symmetry', 'cong_reflexivity', 'lg_cong_lg', 'cong_right_commutativity'}
# Ch13_3_angles/ex_points_anga
# {'anga_is_ang', 'Q_CongA_Acute', 'ex_points_ang'}
# {'anga_is_ang', 'ex_points_ang'}
# Ch13_4_cos/lcos_eqa_lcos
# {'eqA_preserves_ang', 'eqA_preserves_anga', 'anga_is_ang', 'EqA', 'Lcos'}
# {'eqA_preserves_ang', 'lcos_lg_anga', 'anga_is_ang', 'EqA', 'Lcos', 'eqA_preserves_anga'}
# Ch14_sum/pj_col_project
# {'col_permutation_5', 'Proj', 'Pj', 'par_symmetry', 'col_permutation_4'}
# {'col_permutation_5', 'Proj', 'Pj', 'project_trivial', 'par_symmetry', 'col_permutation_4'}
# Ch04_col/l4_19
# {'col_permutation_5', 'cong_symmetry', 'l4_18', 'bet_col', 'between_identity', 'cong_identity'}
# {'col_permutation_5', 'cong_symmetry', 'l4_18', 'bet_col', 'between_identity', 'cong_identity', 'eq_dec_points'}
# Ch07_midpoint/cong_cong_half_2
# {'cong_symmetry', 'cong_cong_half_1', 'l7_2', 'cong_commutativity', 'Midpoint'}
# {'cong_commutativity', 'cong_symmetry', 'l7_2', 'cong_cong_half_1'}
# Ch08_orthogonality/l8_18_uniqueness
# {'l8_2', 'l8_15_1', 'col_trivial_1', 'Perp_at', 'l8_7'}
# {'between_trivial2', 'bet_col', 'l8_2', 'l8_15_1', 'col_trivial_1', 'between_symmetry', 'Perp_at', 'l8_7'}
# Ch09_plane/diff_col_ex
# {'between_identity', 'point_construction_different', 'bet_col'}
# {'between_identity', 'point_construction_different', 'eq_dec_points', 'bet_col'}
# Ch10_line_reflexivity_2D/cong_on_bissect
# {'perp_comm', 'perp_perp_col', 'cong_perp_or_mid', 'col_trivial_3', 'perp_sym', 'cong_commutativity', 'perp_in_perp'}
# {'cong_symmetry', 'perp_perp_col', 'cong_perp_or_mid', 'perp_in_perp', 'col_trivial_3', 'perp_sym', 'perp_right_comm', 'cong_commutativity', 'perp_comm', 'perp_left_comm'}
# Ch11_angles/conga_ex_cong3
# {'Out'}
# {'cong_symmetry', 'CongA', 'cong2_conga_cong', 'out_trivial', 'l6_6', 'l11_10', 'cong_commutativity', 'segment_construction_3'}
# Ch11_angles/per2_cong2__cong_3
# {'cong_commutativity', 'per2_cong2__cong_conga2', 'Cong_3'}
# {'cong_commutativity', 'cong_symmetry', 'per2_cong2__cong_conga2', 'Cong_3'}
# Ch12_parallel/not_par_not_col
# {'col_permutation_4', 'Par', 'col_trivial_1'}
# {'col_permutation_5', 'Par', 'col_permutation_1', 'col_trivial_1'}
# Ch12_parallel/not_strict_par
# {'Par', 'col_permutation_3', 'col_permutation_1', 'col_transitivity_1', 'Par_strict'}
# {'not_strict_par1', 'not_strict_par2'}
# Ch12_parallel/acute_col_perp__out
# {'col_trivial_3', 'not_col_distincts', 'perp_not_col2', 'perp_sym', 'l12_9'}
# {'perp_distinct', 'l10_15', 'one_side_symmetry', 'in_angle_one_side', 'not_col_distincts', 'os_distincts', 'l11_24', 'col_permutation_5', 'par_strict_not_col_4', 'col_trivial_3', 'perp_sym', 'acute_per__lta', 'perp_left_comm', 'l8_3', 'lta_comm', 'par_strict_comm', 'per_not_col', 'perp_comm', 'par_strict_left_comm', 'invert_one_side', 'nlta', 'col_one_side_out', 'perp_in_per', 'par_not_col_strict', 'perp_in_sym', 'perp_not_col2', 'one_side_transitivity', 'lea_in_angle', 'l12_9', 'l12_6', 'perp_perp_in'}
# Ch13_5_Pappus_Pascal/lcos2_lcos
# {'lcos_eql_lcos', 'Eq_Lcos2', 'Eq_Lcos', 'l13_6_bis', 'lcos2'}
# {'lcos_lg_anga', 'lcos_eql_lcos', 'Eq_Lcos2', 'Eq_Lcos', 'l13_6_bis', 'lcos2'}
# Ch02_cong/cong_3421
# {'cong_pseudo_reflexivity', 'cong_inner_transitivity'}
# {'cong_right_commutativity', 'cong_symmetry'}
# Ch02_cong/cong_symmetry
# {'cong_inner_transitivity', 'cong_pseudo_reflexivity'}
# {'cong_reflexivity', 'cong_inner_transitivity'}
# Ch05_bet_le/lt_right_comm
# {'cong_right_commutativity', 'Le', 'Lt', 'le_right_comm'}
# {'cong_right_commutativity', 'Lt', 'le_right_comm'}
# Ch06_out_lines/not_col_exists
# {'Col', 'perp_exists', 'perp_not_col'}
# {'col_permutation_5', 'lower_dim_ex', 'Col', 'col_transitivity_2', 'col_transitivity_1', 'eq_dec_points'}
# Ch08_orthogonality/l8_14_2_2
# {'Perp', 'Perp_at'}
# {'l8_14_2_1b_bis', 'Perp', 'Perp_at'}
# Ch08_orthogonality/perp_in_right_comm
# {'col_permutation_5', 'Perp_at'}
# {'perp_in_sym', 'perp_in_left_comm'}
# Ch12_parallel/not_par_inter_uniqueness
# {'col_permutation_5', 'l6_21', 'Par', 'col_permutation_3'}
# {'col_permutation_5', 'Par', 'col_permutation_3', 'l6_21', 'eq_dec_points'}
# Ch12_parallel/col_not_col_not_par
# {'col_permutation_5', 'Par', 'col_permutation_2', 'col3', 'Par_strict'}
# {'col_permutation_5', 'Par', 'col_permutation_2', 'col3', 'col_permutation_4', 'Par_strict'}
# Ch13_1/per2_col_eq
# {'perp_distinct', 'col_permutation_1', 'per_perp_in', 'col_trivial_3', 'l8_18_uniqueness', 'perp_not_col', 'perp_right_comm', 'col_permutation_4', 'perp_left_comm', 'perp_col', 'perp_in_perp_bis'}
# {'col_permutation_5', 'perp_col', 'perp_in_comm', 'perp_distinct', 'l8_9', 'per_perp_in', 'col_trivial_3', 'col_permutation_1', 'l8_18_uniqueness', 'perp_not_col', 'eq_dec_points', 'perp_right_comm', 'perp_comm', 'perp_left_comm', 'col_permutation_4', 'perp_in_perp_bis'}
# Ch13_1/perp_per_bet
# {'l11_47', 'perp_in_left_comm'}
# {'l11_47', 'col_trivial_3', 'perp_in_left_comm'}
# Ch13_4_cos/perp_acute_out
# {'col_trivial_2', 'l12_9', 'perp_not_col', 'perp_left_comm'}
# {'perp_col', 'l11_16', 'perp_distinct', 'col_permutation_1', 'l8_18_uniqueness', 'col_trivial_2', 'one_side_symmetry', 'not_col_distincts', 'col_trivial_1', 'in_angle_one_side', 'perp_right_comm', 'l11_24', 'OS', 'LtA', 'conga_distinct', 'col_permutation_5', 'Par', 'perp_in_comm', 'col_permutation_2', 'l8_2', 'col_trivial_3', 'LeA', 'perp_sym', 'Acute', 'l9_9_bis', 'perp_left_comm', 'perp_in_perp_bis', 'InAngle', 'TS', 'out_col', 'out_distinct', 'l11_17', 'perp_in_right_comm', 'between_symmetry', 'conga_sym', 'per_not_col', 'perp_comm', 'par_strict_left_comm', 'invert_one_side', 'l11_29_a', 'bet_col', 'per_perp_in', 'perp_in_per', 'Out', 'perp_not_col', 'one_side_transitivity', 'l12_9', 'l12_6', 'perp_perp_in'}
# Ch14_order/ltP_neq
# {'LtP', 'Ps', 'diff_pos_diff_neg', 'not_pos_and_neg'}
# {'Ar2', 'Out', 'LtP', 'diff_null', 'ltP_ar2', 'diff_uniqueness', 'Ps'}
# Ch05_bet_le/le_reflexivity
# {'Le', 'cong_reflexivity', 'between_trivial'}
# {'Le', 'cong_reflexivity', 'between_trivial', 'between_symmetry'}
# Ch05_bet_le/le1221
# {'cong_right_commutativity', 'cong_reflexivity', 'between_trivial', 'Le'}
# {'cong_symmetry', 'cong__le', 'cong_right_commutativity', 'cong_reflexivity'}
# Ch06_out_lines/col3
# {'col_permutation_1', 'col_permutation_2', 'col_permutation_5', 'col_transitivity_1'}
# {'col_permutation_2', 'col_permutation_1', 'eq_dec_points', 'col_transitivity_1'}
# Ch07_midpoint/cong_col_mid
# {'l7_20', 'cong_left_commutativity'}
# {'cong_symmetry', 'l7_20', 'cong_left_commutativity'}
# Ch08_orthogonality/perp_comm
# {'col_permutation_5', 'Perp', 'Perp_at'}
# {'perp_right_comm', 'perp_left_comm'}
# Ch10_line_reflexivity_2D/cong_mid_perp__col
# {'perp_perp_col', 'Per', 'midpoint_distinct_1', 'midpoint_col', 'perp_distinct', 'per_perp_in', 'col_trivial_3', 'cong_commutativity', 'perp_sym', 'perp_in_perp', 'perp_comm', 'col_permutation_4', 'perp_left_comm', 'perp_col'}
# {'cong_symmetry', 'perp_perp_col', 'Per', 'perp_distinct', 'midpoint_col', 'perp_in_comm', 'perp_in_perp', 'col_trivial_3', 'per_perp_in', 'midpoint_distinct_1', 'eq_dec_points', 'perp_sym', 'cong_commutativity', 'perp_comm', 'col_permutation_4', 'perp_left_comm', 'perp_col'}
# Ch10_line_reflexivity/l10_5
# {'l10_2_uniqueness', 'l10_4'}
# {'symmetric_point_uniqueness', 'Reflect', 'l10_2_uniqueness', 'l7_2', 'l10_4', 'is_image_is_image_spec', 'eq_dec_points'}
# Ch12_parallel/parallel_existence1
# {'col_permutation_5', 'par_right_comm', 'parallel_existence', 'par_col_par', 'col_permutation_4'}
# {'col_permutation_5', 'par_right_comm', 'eq_dec_points', 'parallel_existence', 'par_col_par', 'col_permutation_4'}
# Ch13_1/perp_bet_obtuse
# {'col_permutation_5', 'perp_distinct', 'bet_col', 'out_trivial', 'perp_out_acute', 'between_symmetry', 'acute_bet_obtuse', 'perp_left_comm', 'perp_col'}
# {'col_permutation_5', 'perp_distinct', 'bet_col', 'col_permutation_1', 'out_trivial', 'perp_out_acute', 'perp_right_comm', 'between_symmetry', 'acute_bet_obtuse', 'perp_comm', 'perp_left_comm', 'perp_col'}
# Ch13_3_angles/anga_is_ang
# {'Q_CongA_Acute', 'acute_distincts', 'Q_CongA'}
# {'Ang', 'Q_CongA_Acute', 'acute_distincts', 'Q_CongA'}
# Ch13_3_angles/ang_const_o
# {'or_bet_out', 'Q_CongA_nFlat', 'angle_construction_2', 'out_trivial', 'col_trivial_1', 'Q_CongA', 'Q_CongA_nNull', 'conga_refl'}
# {'or_bet_out', 'Q_CongA_nFlat', 'angle_construction_2', 'out_trivial', 'col_trivial_1', 'ang_distincts', 'Q_CongA', 'Q_CongA_nNull', 'conga_refl', 'swap_diff'}
# Ch13_4_cos/lcos3_uniqueness
# {'lcos_eql_lcos', 'Lcos3', 'l13_6'}
# {'lcos_lg_anga', 'l13_6', 'lcos_eql_lcos', 'Lcos3'}
# Ch05_bet_le/le_cases
# {'cong_symmetry', 'Le', 'le_trivial', 'l5_5_2', 'segment_construction_2'}
# {'cong_symmetry', 'Le', 'le_trivial', 'l5_5_2', 'segment_construction_2', 'eq_dec_points'}
# Ch07_midpoint/Mid_cases
# {'cong_commutativity', 'cong_symmetry', 'Midpoint', 'between_symmetry'}
# {'l7_2'}
# Ch08_orthogonality/l8_14_3
# {'Col', 'l8_8', 'Perp_at'}
# {'l8_14_2_1b', 'Perp_at', 'l8_12'}
# Ch09_plane/ts2__ex_bet2
# {'TS', 'col_permutation_3', 'bet_col', 'col_permutation_2', 'col_trivial_2', 'segment_construction', 'between_symmetry', 'col_transitivity_1', 'cong_identity'}
# {'col_permutation_5', 'invert_two_sides', 'bet_col', 'not_col_distincts', 'col_two_sides', 'col_two_sides_bet'}
# Ch10_line_reflexivity_2D/per_per_cong_gen
# {'col_permutation_5', 'per_per_col', 'Reflect', 'l8_2', 'col_trivial_2', 'l7_2', 'l7_20', 'ReflectL', 'per_per_cong'}
# {'Reflect', 'per_per_cong'}
# Ch10_line_reflexivity/l10_4
# {'l10_4_spec', 'Reflect', 'l7_2'}
# {'l10_4_spec', 'Reflect', 'l7_2', 'is_image_is_image_spec', 'eq_dec_points'}
# Ch10_line_reflexivity/exists_cong_per
# {'ex_per_cong', 'l8_2', 'col_trivial_2', 'segment_construction', 'cong_3421', 'not_col_exists', 'cong_trivial_identity', 'l8_5'}
# {'ex_per_cong', 'cong_symmetry', 'between_trivial2', 'bet_col', 'l8_2', 'segment_construction', 'cong_3421', 'between_symmetry', 'not_col_exists', 'cong_trivial_identity', 'l8_5', 'eq_dec_points'}
# Ch11_angles/segment_construction_0
# {'segment_construction'}
# {'cong_trivial_identity', 'another_point', 'segment_construction_3', 'eq_dec_points'}
# Ch11_angles/acute_trivial
# {'col_trivial_2', 'LtA', 'ex_per_cong', 'l8_2', 'LeA', 'perp_sym', 'out_conga_out', 'Acute', 'not_col_exists', 'cong_diff_3', 'conga_refl', 'perp_in_perp_bis', 'out_col', 'perp_not_eq_1', 'in_angle_trivial_1', 'between_trivial', 'per_perp_in', 'Out', 'perp_not_col'}
# {'col_trivial_2', 'out_trivial', 'not_col_distincts', 'LtA', 'ex_per_cong', 'col_permutation_5', 'l8_2', 'LeA', 'out_conga_out', 'Acute', 'not_col_exists', 'cong_diff_3', 'conga_refl', 'perp_in_perp_bis', 'out_col', 'perp_not_eq_1', 'in_angle_trivial_1', 'perp_comm', 'per_perp_in', 'perp_not_col'}
# Ch12_parallel/par_id
# {'col_trivial_1', 'Par', 'col_permutation_4', 'Par_strict'}
# {'col_permutation_5', 'Par', 'col_permutation_1', 'col_trivial_1', 'Par_strict'}
# Ch12_parallel/par_strict_par
# {'Par', 'Par_strict'}
# {'Par'}
# Ch13_1/per13_preserves_bet_inv
# {'col_permutation_3', 'perp_distinct', 'not_col_distincts', 'OS', 'col_permutation_5', 'col_permutation_2', 'col_trivial_3', 'perp_sym', 'perp_left_comm', 'perp_in_perp_bis', 'TS', 'l8_9', 'between_identity', 'between_symmetry', 'out_one_side', 'bet_col', 'per_perp_in', 'Out', 'perp_not_col', 'l12_9'}
# {'col_permutation_3', 'perp_distinct', 'one_side_symmetry', 'not_col_distincts', 'bet_neq21__neq', 'OS', 'col_permutation_4', 'col_permutation_5', 'perp_in_comm', 'col_permutation_2', 'col_trivial_3', 'perp_sym', 'perp_left_comm', 'perp_in_perp_bis', 'par_strict_symmetry', 'TS', 'l8_9', 'between_identity', 'between_symmetry', 'out_one_side', 'per_not_col', 'perp_comm', 'between_equality', 'invert_one_side', 'col_one_side_out', 'bet_col', 'per_perp_in', 'Out', 'eq_dec_points', 'perp_not_col', 'one_side_transitivity', 'l12_9', 'l12_6', 'perp_col'}
# Ch13_2_length/lg_cong_lg
# {'cong_transitivity', 'cong_symmetry', 'Q_Cong'}
# {'cong_transitivity', 'Q_Cong'}
# Ch13_3_angles/not_null_not_col
# {'Q_CongA_Acute', 'out_conga_out', 'conga_sym', 'acute_col_out', 'Q_CongA_Null_Acute', 'anga_acute'}
# {'out_conga_out', 'acute_col_out', 'anga_conga', 'Q_CongA_Null_Acute', 'anga_acute'}
# Ch13_4_cos/lcos_lg_not_null
# {'anga_distincts', 'cong_symmetry', 'Q_Cong', 'Q_Cong_Null', 'Lcos', 'cong_identity'}
# {'anga_distinct', 'cong_identity', 'Q_Cong_Null', 'lg_cong', 'Lcos'}
# Ch15_lengths/not_triangular_equality1
# {'length_id_2', 'Sum', 'between_trivial2', 'Ar2'}
# {'between_trivial2', 'Ar2', 'col_trivial_2', 'length_id_2', 'between_symmetry', 'Sum'}
# Ch03_bet/between_exchange2
# {'between_inner_transitivity', 'between_identity', 'between_symmetry', 'outer_transitivity_between2'}
# {'between_inner_transitivity', 'outer_transitivity_between2', 'between_symmetry', 'eq_dec_points'}
# Ch05_bet_le/le__nlt
# {'Le', 'cong_symmetry', 'Lt', 'not_and_lt'}
# {'cong_symmetry', 'Lt', 'not_and_lt'}
# Ch05_bet_le/cong__nlt
# {'Le', 'cong_symmetry', 'between_trivial', 'le__nlt'}
# {'cong_symmetry', 'Le', 'between_trivial', 'between_symmetry', 'le__nlt'}
# Ch07_midpoint/symmetric_point_uniqueness
# {'l7_9', 'l7_2'}
# {'cong_symmetry', 'construction_uniqueness', 'Midpoint', 'cong_identity', 'eq_dec_points'}
# Ch07_midpoint/Mid_perm
# {'Midpoint', 'cong_4321', 'between_symmetry'}
# {'cong_symmetry', 'cong_4321', 'Midpoint', 'between_symmetry'}
# Ch07_midpoint/col_cong2_bet1
# {'cong_symmetry', 'outer_transitivity_between2', 'col_cong_bet', 'bet_cong_eq', 'between_trivial', 'between_symmetry', 'cong_left_commutativity', 'cong_identity'}
# {'cong_symmetry', 'outer_transitivity_between2', 'col_cong_bet', 'bet_cong_eq', 'between_trivial', 'between_symmetry', 'cong_left_commutativity', 'cong_identity', 'eq_dec_points'}
# Ch08_orthogonality/perp_in_comm
# {'col_permutation_5', 'Perp_at'}
# {'perp_in_right_comm', 'perp_in_left_comm'}
# Ch11_angles/lta_right_comm
# {'conga_right_comm', 'lea_right_comm', 'LtA', 'LeA'}
# {'conga_right_comm', 'lea_right_comm', 'LtA'}
# Ch12_parallel/acute_col_perp__out_1
# {'col_trivial_3', 'not_col_distincts', 'perp_not_col2', 'l12_9', 'perp_comm'}
# {'perp_distinct', 'col_permutation_1', 'bet_neq21__neq', 'not_col_distincts', 'bet_neq12__neq', 'col_permutation_4', 'cong_diff_4', 'perp_sym', 'cong_diff_3', 'acute_conga__acute', 'perp_left_comm', 'acute_sym', 'perp_perp_in', 'acute_distincts', 'segment_construction', 'between_symmetry', 'not_out_bet', 'per_not_col', 'perp_comm', 'bet_col', 'perp_in_per', 'perp_in_sym', 'l6_6', 'not_bet_and_out', 'l11_14', 'l6_2', 'acute_col_perp__out', 'perp_col'}
# Ch12_parallel/par_one_or_two_sides
# {'col_permutation_5', 'Par', 'col_permutation_3', 'par_two_sides_two_sides', 'col_permutation_2', 'col_permutation_1', 'not_two_sides_one_side', 'col_trivial_3', 'col_trivial_1', 'col_permutation_4', 'par_comm', 'Par_strict'}
# {'col_permutation_5', 'two_sides_dec', 'col_permutation_3', 'Par', 'par_two_sides_two_sides', 'col_permutation_2', 'col_permutation_1', 'col_trivial_3', 'not_two_sides_one_side', 'col_trivial_1', 'col_permutation_4', 'par_comm', 'Par_strict'}
# Ch13_3_angles/ang_const
# {'not_col_exists', 'conga_trivial_1', 'Q_CongA', 'angle_construction_2'}
# {'conga_trivial_1', 'angle_construction_2', 'not_col_exists', 'Q_CongA', 'conga_refl', 'eq_dec_points', 'swap_diff'}
# Ch14_sum/opp0_uniqueness
# {'cong_reverse_identity', 'Midpoint', 'opp_midpoint'}
# {'col_permutation_5', 'col_permutation_3', 'par_distincts', 'Proj', 'col_permutation_1', 'col_trivial_3', 'col_trivial_2', 'Sump', 'sum_to_sump', 'col_trivial_1', 'Opp', 'par_symmetry', 'par_trans', 'par_left_comm', 'col_transitivity_1', 'l6_21', 'col_permutation_4'}
# Ch05_bet_le/le_transitivity
# {'between_exchange4', 'Cong_3', 'Le', 'cong_transitivity', 'l4_5'}
# {'between_exchange4', 'Cong_3', 'Le', 'between_symmetry', 'cong_transitivity', 'l4_5'}
# Ch06_out_lines/l6_13_1
# {'cong_reflexivity', 'Out', 'l6_11_uniqueness', 'Le', 'cong_identity'}
# {'cong_symmetry', 'between_identity', 'cong_reflexivity', 'Out', 'l6_11_uniqueness', 'Le', 'cong_identity'}
# Ch08_orthogonality/per_double_cong
# {'symmetric_point_uniqueness', 'Per'}
# {'l7_9', 'Per', 'l7_2'}
# Ch09_plane/mid_preserves_col
# {'Col', 'l7_15'}
# {'col_permutation_5', 'col_permutation_3', 'l7_15', 'bet_col', 'midpoint_col', 'col_permutation_4'}
# Ch12_parallel/par_two_sides_two_sides
# {'TS', 'Par', 'col_trivial_1', 'outer_pasch', 'Col', 'between_symmetry', 'Par_strict'}
# {'col_permutation_5', 'TS', 'Par', 'col_permutation_3', 'par_distincts', 'bet_col', 'col_permutation_2', 'col_permutation_1', 'col_trivial_2', 'col_trivial_1', 'outer_pasch', 'Col', 'between_symmetry', 'col_transitivity_1', 'col_permutation_4', 'Par_strict'}
# Ch12_parallel_inter_dec/not_par_inter_exists
# {'Par', 'col_trivial_2', 'col_trivial_1', 'all_coplanar', 'Par_strict'}
# {'Par', 'col_trivial_2', 'inter_dec', 'col_trivial_1', 'all_coplanar', 'eq_dec_points', 'Par_strict'}
# Ch12_parallel_inter_dec/not_par_strict_inter_exists
# {'col_trivial_2', 'col_trivial_1', 'all_coplanar', 'Par_strict'}
# {'col_trivial_2', 'inter_dec', 'col_trivial_1', 'all_coplanar', 'eq_dec_points', 'Par_strict'}
# Ch03_bet/another_point
# {'col_trivial_1'}
# {'point_construction_different'}
# Ch04_cong_bet/l4_3_1
# {'cong_commutativity', 'between_symmetry', 'l4_3'}
# {'cong_commutativity', 'cong_symmetry', 'between_symmetry', 'l4_3'}
# Ch06_out_lines/bet_out__bet
# {'between_inner_transitivity', 'between_exchange2', 'Out', 'outer_transitivity_between', 'between_symmetry'}
# {'between_symmetry', 'between_trivial', 'eq_dec_points', 'l6_2'}
# Ch06_out_lines/l6_21
# {'col_permutation_5', 'col_permutation_2', 'col_permutation_1', 'not_col_distincts', 'col_transitivity_1'}
# {'col_permutation_5', 'col_permutation_2', 'col_permutation_1', 'not_col_distincts', 'col_transitivity_1', 'col_permutation_4', 'eq_dec_points'}
# Ch07_midpoint/l7_3_2
# {'Midpoint', 'cong_pseudo_reflexivity', 'between_trivial'}
# {'Midpoint', 'cong_reflexivity', 'between_symmetry', 'between_trivial2'}
# Ch11_angles/two_sides_in_angle
# {'or_bet_out', 'TS', 'col_permutation_3', 'col_trivial_2', 'Out', 'l5_2', 'col_trivial_1', 'InAngle'}
# {'or_bet_out', 'TS', 'col_permutation_3', 'col_trivial_2', 'Out', 'l5_2', 'col_trivial_1', 'l6_6', 'InAngle', 'eq_dec_points'}
# Ch11_angles/l11_36
# {'in_angle_reverse', 'l11_29_a', 'LeA', 'between_symmetry', 'conga_sym', 'l11_13'}
# {'l11_29_a', 'in_angle_reverse', 'LeA', 'between_symmetry', 'conga_sym', 'l11_13', 'l11_29_b'}
# Ch13_4_cos/lcos_uniqueness
# {'l13_6'}
# {'l11_16', 'out_trivial', 'conga_comm', 'anga_conga', 'conga_distinct', 'col_permutation_5', 'Q_Cong', 'col_permutation_2', 'EqL', 'lg_cong_lg', 'out_conga_out', 'cong_symmetry', 'out_col', 'l8_9', 'conga_sym', 'cong_commutativity', 'Lcos', 'lg_cong', 'cong_transitivity', 'l11_50_2', 'eq_dec_points'}
# Ch13_4_cos/lcos2_eq_lcos3_eq
# {'lcos_lg_not_null', 'lcos_lg_anga', 'Lcos3', 'Eq_Lcos3', 'Eq_Lcos2', 'lcos2', 'lcos_exists'}
# {'lcos_lg_not_null', 'lcos3_lcos_2_1', 'lcos2_lg_anga', 'lcos_lg_anga', 'Eq_Lcos3', 'Eq_Lcos2', 'lcos_exists', 'lcos2_lg_not_null'}
# Ch14_prod/prod_uniqueness
# {'col_trivial_2', 'perp_not_col', 'l8_18_existence', 'l12_9', 'not_col_exists', 'perp_left_comm'}
# {'col_permutation_5', 'Prodp', 'par_distincts', 'parallel_uniqueness', 'Proj', 'col_trivial_2', 'Prod', 'col_trivial_1', 'eq_dec_points', 'par_symmetry', 'prod_to_prodp', 'par_left_comm', 'l6_21', 'par_col_par_2', 'col_permutation_4'}
# Ch02_cong/l2_11
# {'cong_symmetry', 'cong_identity', 'cong_commutativity', 'cong_trivial_identity', 'five_segment'}
# {'cong_symmetry', 'cong_identity', 'cong_commutativity', 'cong_trivial_identity', 'eq_dec_points', 'five_segment'}
# Ch05_bet_le/third_point
# {'Col', 'between_symmetry'}
# {'between_symmetry'}
# Ch07_midpoint/col_bet2_cong2
# {'cong_right_commutativity', 'cong_reflexivity', 'between_symmetry', 'cong_4321', 'l4_3'}
# {'cong_right_commutativity', 'cong_symmetry', 'cong_reflexivity', 'between_symmetry', 'cong_4321', 'l4_3'}
# Ch10_line_reflexivity/l10_2_existence
# {'cong_symmetry', 'between_trivial2', 'Reflect', 'ReflectL', 'Col', 'between_symmetry', 'cong_transitivity', 'Midpoint', 'symmetric_point_construction'}
# {'l10_2_existence_spec', 'symmetric_point_construction', 'Reflect', 'eq_dec_points'}
# Ch12_parallel/pars__os3412
# {'par_strict_symmetry', 'l12_6', 'Par_strict'}
# {'par_strict_symmetry', 'l12_6'}
# Ch05_bet_le/bet_cong_eq
# {'cong_right_commutativity', 'between_cong', 'le_anti_symmetry', 'cong_reflexivity', 'cong_left_commutativity', 'between_symmetry', 'cong_4321', 'l5_5_2'}
# {'cong_right_commutativity', 'cong_symmetry', 'between_cong', 'le_anti_symmetry', 'cong_reflexivity', 'between_symmetry', 'cong_left_commutativity', 'l5_6', 'cong_commutativity', 'l5_5_2'}
# Ch06_out_lines/col_transitivity_1
# {'l6_16_1', 'between_symmetry', 'between_trivial', 'Col'}
# {'col_permutation_5', 'col_permutation_3', 'col_permutation_1', 'Col', 'between_trivial', 'between_symmetry', 'l6_16_1', 'eq_dec_points'}
# Ch06_out_lines/col_transitivity_2
# {'l6_16_1', 'between_symmetry', 'between_trivial', 'Col'}
# {'col_permutation_5', 'col_permutation_1', 'col_transitivity_1'}
# Ch08_orthogonality/perp_proj
# {'col_permutation_2', 'col_trivial_1'}
# {'col_permutation_1', 'Perp', 'Perp_at', 'perp_in_perp', 'perp_col'}
# Ch08_orthogonality/perp_not_col
# {'col_permutation_1', 'l8_2', 'col_trivial_3', 'Perp_at', 'l8_5', 'l8_7', 'perp_perp_in'}
# {'perp_in_left_comm', 'perp_distinct', 'perp_in_per', 'perp_in_sym', 'perp_in_right_comm', 'per_not_col', 'col_permutation_4', 'perp_perp_in'}
# Ch11_angles/angle_construction_3
# {'not_col_exists', 'conga_trivial_1', 'angle_construction_2'}
# {'not_col_exists', 'conga_trivial_1', 'eq_dec_points', 'angle_construction_2'}
# Ch06_out_lines/not_out_bet
# {'between_trivial2', 'Out', 'Col', 'between_trivial', 'between_symmetry'}
# {'between_trivial2', 'Out', 'Col', 'between_symmetry', 'between_trivial', 'eq_dec_points'}
# Ch09_plane/col123__nos
# {'Col', 'TS', 'OS'}
# {'one_side_not_col123'}
# Ch09_plane/l9_18
# {'col_permutation_5', 'TS', 'bet_col', 'col_permutation_2', 'between_identity', 'col_permutation_1', 'l6_21'}
# {'col_permutation_5', 'TS', 'bet_col', 'col_permutation_2', 'col_permutation_1', 'between_identity', 'not_col_permutation_4', 'not_col_permutation_5', 'l6_21', 'col_permutation_4'}
# Ch10_line_reflexivity_2D/per_per_cong
# {'col_permutation_5', 'ReflectL', 'col_permutation_1', 'l8_2', 'col_trivial_2', 'perp_sym', 'l7_2', 'l7_20', 'perp_right_comm', 'cong_identity', 'per_perp', 'perp_col', 'per_per_col'}
# {'col_permutation_5', 'ReflectL', 'col_permutation_1', 'l8_2', 'col_trivial_2', 'perp_sym', 'eq_dec_points', 'l7_2', 'perp_right_comm', 'l7_20', 'cong_identity', 'per_perp', 'perp_col', 'per_per_col'}
# Ch05_bet_le/cong__le
# {'Le', 'between_trivial'}
# {'between_trivial', 'between_symmetry'}
# ...
# Ch06_out_lines/l6_16_1
# {'col_permutation_1', 'l6_21', 'col_trivial_2', 'col_permutation_3'}
# {'l5_1', 'outer_transitivity_between2', 'between_exchange4', 'between_exchange3', 'between_exchange2', 'between_inner_transitivity', 'outer_transitivity_between', 'l5_2', 'Col', 'l5_3', 'between_symmetry'}
# Ch11_angles/l11_22a
# {'not_col_distincts', 'perp_not_col', 'not_col_exists', 'l12_9', 'l8_21_aux', 'perp_comm', 'perp_left_comm', 'conga_distinct'}
# {'col_permutation_3', 'conga__or_out_ts', 'out_trivial', 'col_trivial_1', 'conga_comm', 'OS', 'col_transitivity_1', 'l11_13', 'segment_construction_3', 'l9_2', 'col_permutation_4', 'col_permutation_5', 'l2_11', 'CongA', 'cong3_conga', 'invert_two_sides', 'col_permutation_2', 'out_to_bet', 'conga_trans', 'l9_5', 'conga_line', 'l11_10', 'not_bet_out', 'l11_22_bet', 'l9_9', 'cong_symmetry', 'out_col', 'TS', 'between_identity', 'segment_construction', 'between_symmetry', 'conga_sym', 'cong_commutativity', 'five_segment', 'bet_dec', 'Out', 'l6_6', 'Col', 'not_bet_and_out', 'cong_identity', 'l11_4_1', 'eq_dec_points'}
# Ch12_parallel/l12_6
# {'Par_strict', 'col_permutation_3', 'col_trivial_1', 'par_strict_one_side'}
# {'col_permutation_5', 'TS', 'bet_col', 'col_permutation_1', 'not_two_sides_one_side', 'col_trivial_3', 'col_trivial_1', 'Par_strict'}
# Ch06_out_lines/out_bet__out
# {'between_exchange2', 'between_identity', 'Out', 'outer_transitivity_between', 'between_symmetry', 'between_equality'}
# {'bet_out', 'between_exchange2', 'between_identity', 'outer_transitivity_between', 'l6_6', 'between_symmetry', 'between_equality'}
# Ch07_midpoint/cong_mid2__cong
# {'cong_symmetry', 'le_anti_symmetry', 'cong__le', 'le_mid2__le13', 'cong_commutativity', 'cong_4321', 'Midpoint'}
# {'cong_transitivity', 'cong_symmetry', 'l2_11'}
# Ch08_orthogonality/perp_sym
# {'l8_2', 'Perp', 'Perp_at'}
# {'Perp', 'l8_12'}
# Ch09_plane/l9_9_bis
# {'l9_9', 'OS'}
# {'l9_9', 'l9_8_1', 'OS'}
# Ch11_angles/angle_construction_1
# {'angle_construction_2', 'not_col_distincts', 'conga_sym', 'col_conga_col'}
# {'l11_16', 'perp_distinct', 'Cong_3', 'col_trivial_2', 'out_trivial', 'col_trivial_1', 'perp_right_comm', 'col_transitivity_1', 'l11_13', 'segment_construction_3', 'col_permutation_4', 'ex_per_cong', 'cong3_conga', 'perp_in_comm', 'col_permutation_2', 'l8_2', 'Perp', 'perp_sym', 'l11_10', 'l8_8', 'perp_left_comm', 'cong_symmetry', 'perp_perp_in', 'out_col', 'segment_construction', 'l8_18_existence', 'between_symmetry', 'not_out_bet', 'Perp_at', 'cong_commutativity', 'invert_one_side', 'out_dec', 'perp_in_per', 'Out', 'perp_in_sym', 'eq_dec_points', 'l6_6', 'l10_12', 'col_one_side', 'Col', 'cong_identity', 'perp_col'}
# Ch13_5_Pappus_Pascal/l13_10_aux1
# {'Perp', 'perp_not_col', 'Col', 'between_trivial', 'l12_9', 'perp_left_comm'}
# {'perp_col', 'col_permutation_3', 'col_trivial_2', 'out_trivial', 'per23_preserves_bet', 'anga_exists', 'col_permutation_5', 'out_conga', 'Par', 'perp_in_comm', 'perp_in_left_comm', 'col_trivial_3', 'anga_sym', 'perp_sym', 'perp_not_eq_2', 'conga_refl', 'perp_left_comm', 'perp_not_eq_1', 'perp_in_right_comm', 'between_symmetry', 'perp_comm', 'perp_acute', 'par_reflexivity', 'between_trivial2', 'bet_col', 'Proj', 'perp_in_per', 'Out', 'perp_not_col', 'l11_14', 'l12_9', 'anga_conga_anga', 'per13_preserves_bet', 'perp_perp_in', 'Par_strict'}
# Ch08_orthogonality/per_not_colp
# {'col_permutation_3', 'perp_distinct', 'col_permutation_1', 'per_perp_in', 'col_trivial_2', 'col_trivial_3', 'l8_18_uniqueness', 'perp_not_col', 'perp_sym', 'perp_comm', 'perp_left_comm', 'perp_col', 'perp_in_perp_bis'}
# {'col_permutation_5', 'col_permutation_1', 'l8_2', 'per_col', 'perp_comm', 'per_perp', 'l8_7'}
# Ch11_angles/l11_aux
# {'col_trivial_2', 'perp_not_col', 'l8_18_existence', 'l12_9', 'perp_left_comm'}
# {'cong_right_commutativity', 'cong_symmetry', 'l2_11', 'l5_1', 'between_exchange4', 'cong_diff_4', 'Out', 'bet_neq21__neq', 'cong_preserves_bet', 'cong_4312', 'between_symmetry', 'cong_left_commutativity', 'cong_commutativity', 'cong_4321', 'l4_3'}
# Ch04_col/Col_perm
# {'Col', 'col_permutation_3'}
# {'col_permutation_5', 'col_permutation_3', 'col_permutation_2', 'col_permutation_1', 'col_permutation_4'}
# Ch08_orthogonality/l8_9
# {'l8_3', 'l8_2', 'Col', 'between_symmetry', 'l8_8'}
# {'col_permutation_5', 'l8_3', 'col_permutation_1', 'l8_2', 'l8_5', 'l8_7', 'eq_dec_points'}
# Ch10_line_reflexivity_2D/image_preserves_col
# {'cong_symmetry', 'l10_10_spec', 'l4_13', 'Cong_3'}
# {'col_permutation_2', 'image_preserves_bet', 'col_permutation_1', 'bet_col'}
# Ch10_line_reflexivity/image_image_in
# {'col_trivial_2', 'perp_not_col', 'l12_9', 'ReflectL', 'perp_left_comm'}
# {'col_permutation_5', 'l8_16_1', 'perp_distinct', 'midpoint_bet', 'ReflectL_at', 'col_trivial_3', 'col_trivial_2', 'eq_dec_points', 'perp_sym', 'l7_2', 'perp_right_comm', 'is_midpoint_id', 'Col', 'l6_21', 'ReflectL', 'perp_col'}
# Ch11_angles/out341__inangle
# {'Out', 'between_trivial', 'InAngle'}
# {'out_distinct', 'col_in_angle'}
# Ch12_parallel/perp_perp_col_col
# {'col_trivial_2', 'perp_not_col', 'perp_right_comm', 'l12_9', 'perp_comm'}
# {'col_permutation_5', 'perp_perp_col', 'col_permutation_3', 'perp_distinct', 'col_permutation_2', 'col_permutation_1', 'col_trivial_3', 'col_trivial_2', 'Perp', 'eq_dec_points', 'col_trivial_1', 'col_transitivity_2', 'perp_left_comm', 'perp_col'}
# Ch09_plane/l9_10
# {'TS', 'between_trivial2', 'l7_2', 'Col', 'is_midpoint_id', 'between_symmetry', 'col_transitivity_1', 'Midpoint', 'symmetric_point_construction'}
# {'TS', 'midpoint_bet', 'col_permutation_2', 'col_trivial_1', 'l7_2', 'Col', 'is_midpoint_id', 'col_transitivity_1', 'symmetric_point_construction', 'col_permutation_4'}
# Ch11_angles/triangle_strict_inequality_2
# {'cong_right_commutativity', 'cong_symmetry', 'cong_transitivity', 'le_anti_symmetry', 'Out', 'not_col_distincts', 'bet2_le2__le2356', 'not_out_bet', 'cong_commutativity', 'cong_identity', 'l5_5_2'}
# {'cong_symmetry', 'l2_11', 'triangle_strict_inequality', 'cong_reflexivity', 'segment_construction', 'cong2_lt__lt', 'cong_transitivity'}
# Ch12_parallel/perp_inter_exists
# {'l8_18_existence', 'col_trivial_3', 'perp_sym', 'perp_perp_col'}
# {'col_permutation_5', 'col_permutation_4'}
# Ch12_parallel/par_not_col_strict
# {'col_permutation_5', 'Par', 'col_permutation_1', 'col_trivial_1', 'col_transitivity_1', 'Par_strict'}
# {'par_strict_symmetry', 'col_permutation_5', 'Par', 'col_permutation_2', 'col3', 'par_symmetry', 'all_coplanar', 'col_transitivity_1', 'col_permutation_4', 'Par_strict'}
# Ch11_angles/per2_cong2__cong_conga2
# {'perp_distinct', 'per_perp_in', 'not_col_distincts', 'perp_not_col', 'l12_9', 'perp_left_comm', 'perp_in_perp_bis'}
# {'l11_52', 'l11_16', 'l11_46', 'per_not_col'}
# Ch14_sum/sum_O_O
# {'col_trivial_3', 'Sum', 'Ar2', 'pj_trivial'}
# {'Ar2', 'pj_trivial', 'col_trivial_3', 'col_trivial_2', 'Sum'}
# Ch03_bet/outer_transitivity_between2
# {'between_exchange2', 'outer_transitivity_between'}
# {'cong_reflexivity', 'construction_uniqueness', 'segment_construction', 'between_exchange3'}
# Ch07_midpoint/midpoint_distinct_3
# {'Midpoint', 'between_identity', 'cong_identity', 'l7_2'}
# {'Midpoint', 'between_identity', 'midpoint_distinct_1'}
# Ch10_line_reflexivity/l10_2_uniqueness_spec
# {'col_trivial_2', 'perp_not_col', 'l12_9', 'ReflectL', 'perp_left_comm'}
# {'is_image_is_image_spec', 'l10_2_uniqueness', 'perp_distinct'}
# Ch13_3_angles/anga_not_lg_null
# {'cong_symmetry', 'Q_Cong', 'Q_CongA_Acute', 'Q_Cong_Null', 'cong_identity', 'conga_distinct'}
# {'anga_is_ang', 'ang_not_lg_null'}
# Ch13_4_cos/perp_obtuse_bet
# {'col_trivial_2', 'l12_9', 'perp_not_col', 'perp_left_comm'}
# {'col_permutation_5', 'CongA', 'l11_16', 'perp_in_comm', 'Obtuse', 'col_permutation_1', 'perp_in_per', 'Out', 'LeA', 'perp_not_col', 'perp_out_acute', 'perp_right_comm', 'between_symmetry', 'GtA', 'perp_comm', 'LtA', 'perp_perp_in', 'obtuse_not_acute'}
# Ch11_angles/gta_distincts
# {'LeA', 'GtA', 'conga_diff2', 'LtA', 'conga_left_comm', 'InAngle'}
# {'lta_distincts'}
# Ch11_angles/l11_51
# {'cong_4312', 'cong3_conga', 'Cong_3'}
# {'cong_commutativity', 'cong3_conga'}
# Ch08_orthogonality/l8_2
# {'symmetric_point_uniqueness', 'cong_commutativity', 'l7_13', 'l7_2', 'cong_transitivity', 'symmetric_point_construction', 'Per'}
# {'cong_commutativity', 'l7_13', 'l7_2', 'cong_transitivity', 'symmetric_point_construction', 'Per'}
# Ch11_angles/out321__inangle
# {'col_trivial_3', 'Out', 'Col', 'between_symmetry', 'between_trivial', 'InAngle'}
# {'out_distinct', 'col_in_angle'}
# Ch11_angles/lta_distincts
# {'conga_diff56', 'LeA', 'conga_sym', 'LtA', 'conga_left_comm', 'InAngle'}
# {'lea_distincts'}
# Ch08_orthogonality/midpoint_existence_aux
# {'perp_perp_col', 'perp_not_col', 'perp_sym', 'l12_9', 'perp_comm', 'perp_left_comm'}
# {'perp_distinct', 'col_trivial_2', 'not_col_distincts', 'col_permutation_4', 'col_permutation_5', 'col_trivial_3', 'perp_sym', 'perp_left_comm', 'perp_per_2', 'cong_symmetry', 'l8_9', 'between_identity', 'cong_left_commutativity', 'between_symmetry', 'inner_pasch', 'perp_comm', 'perp_per_1', 'bet_col', 'perp_cong', 'eq_dec_points', 'Le', 'l7_21', 'cong_identity', 'l7_3_2', 'perp_col'}
# Ch05_bet_le/lt_diff
# {'cong_symmetry', 'cong_reflexivity', 'Le', 'cong_inner_transitivity', 'between_symmetry', 'between_trivial', 'le__nlt', 'Lt'}
# {'cong_trivial_identity', 'le_zero'}
# Ch09_plane/ts_distincts
# {'TS', 'cong_reflexivity', 'segment_construction', 'Col', 'between_symmetry', 'cong_left_commutativity', 'l7_3', 'Midpoint', 'cong_identity'}
# {'between_identity', 'not_col_distincts'}
# Ch11_angles/col_in_angle
# {'Out', 'between_trivial', 'InAngle'}
# {'between_trivial', 'between_symmetry'}
# Ch15_lengths/length_sym
# {'cong_right_commutativity', 'Length'}
# {'cong_right_commutativity', 'cong_symmetry', 'Length'}
# Ch10_line_reflexivity/l10_6_uniqueness_spec
# {'col_trivial_2', 'perp_not_col', 'l12_9', 'ReflectL', 'perp_left_comm'}
# {'l10_6_uniqueness', 'is_image_is_image_spec', 'perp_distinct'}
# Ch11_angles/conga_refl
# {'l11_21_b', 'cong_reflexivity', 'Out', 'between_trivial', 'l11_51'}
# {'l11_3_bis', 'cong_reflexivity', 'between_symmetry', 'between_trivial2'}
# Ch07_midpoint/col_cong2_bet3
# {'between_trivial2', 'between_exchange3', 'between_inner_transitivity', 'cong_reflexivity', 'outer_transitivity_between', 'col_cong_bet', 'Col', 'cong_3421', 'bet_cong_eq', 'between_symmetry', 'between_trivial', 'col_transitivity_1', 'cong_commutativity', 'cong_identity', 'cong_4321'}
# {'cong_diff', 'cong_symmetry', 'bet_col', 'eq_dec_points', 'between_trivial', 'between_symmetry', 'cong_left_commutativity', 'cong_identity', 'col_cong2_bet2'}
# Ch08_orthogonality/per_not_col
# {'l8_14_2_1a', 'per_perp_in', 'l8_2', 'perp_not_col', 'Col', 'between_symmetry', 'perp_comm'}
# {'midpoint_col', 'midpoint_distinct_2', 'l7_20', 'l7_3', 'l7_17', 'Per'}
# Ch08_orthogonality/perp_not_col2
# {'col_permutation_2', 'l8_2', 'col_trivial_3', 'col_permutation_1', 'Perp', 'Perp_at', 'per_not_col', 'col_permutation_4'}
# {'col_permutation_5', 'l8_14_2_1b_bis', 'col_permutation_3', 'col_trivial_3', 'col_trivial_1', 'perp_not_eq_2', 'l8_14_3'}
# Ch12_parallel/par_reflexivity
# {'Col', 'between_trivial', 'Par', 'Par_strict'}
# {'col_trivial_3', 'Par', 'col_trivial_1', 'Par_strict'}
# Ch08_orthogonality/l8_24
# {'col_trivial_2', 'perp_not_col', 'perp_right_comm', 'l12_9', 'perp_comm'}
# {'perp_distinct', 'col_permutation_1', 'col_trivial_2', 'col_transitivity_1', 'col_permutation_4', 'col_permutation_5', 'cong_right_commutativity', 'col_permutation_2', 'perp_sym', 'perp_left_comm', 'perp_per_2', 'cong_symmetry', 'l8_9', 'between_identity', 'between_symmetry', 'inner_pasch', 'perp_comm', 'perp_per_1', 'perp_cong', 'eq_dec_points', 'Col', 'Le', 'l7_21', 'cong_identity', 'perp_col'}
# Ch09_plane/os_distincts
# {'col_permutation_1', 'TS', 'col_trivial_2', 'OS'}
# {'ts_distincts'}
# Ch11_angles/l11_44_2
# {'Gt', 'between_trivial2', 'or_lt_cong_gt', 'l11_44_2_a', 'Col', 'l11_44_1_a', 'between_symmetry', 'between_trivial', 'lta_not_conga', 'not_and_lta'}
# {'col_permutation_3', 'l11_44_2_b', 'l11_44_2_a'}
# Ch14_sum/sum22_comm
# {'sum3', 'sum3_comm_1_2', 'sum22'}
# {'sum_comm', 'sum22', 'sum22_col'}
# Ch13_1/perp2_perp_in
# {'between_trivial2', 'between_identity', 'col_trivial_2', 'Perp2', 'perp_sym', 'is_midpoint_id', 'l12_9', 'Midpoint', 'perp_per_1', 'perp_left_comm', 'Per'}
# {'col_permutation_5', 'perp_in_col_perp_in', 'col_permutation_3', 'perp_not_eq_1', 'perp_inter_perp_in_n', 'Perp2', 'perp_in_sym', 'perp_in_right_comm', 'col3', 'eq_dec_points', 'not_col_distincts', 'col_permutation_4'}
# Ch06_out_lines/out2__bet
# {'between_equality', 'Out', 'between_symmetry'}
# {'l6_4_1'}
# Ch08_orthogonality/perp_in_distinct
# {'Perp_at'}
# {'l8_14_2_1a', 'perp_distinct'}
# Ch13_3_angles/is_anga_conga_is_anga
# {'Ang_Acute', 'Q_CongA_Acute', 'conga_trans'}
# {'Ang_Acute', 'anga_is_ang', 'conga_trans', 'Q_CongA'}
# Ch11_angles/in_angle_two_sides
# {'TS', 'bet_col', 'col_permutation_1', 'col_trivial_3', 'Out', 'between_symmetry', 'InAngle'}
# {'TS', 'out_col', 'col_permutation_2', 'col_permutation_1', 'col_trivial_3', 'InAngle'}
# Ch12_parallel/par_left_comm
# {'Par', 'col_trivial_3', 'Col', 'between_symmetry', 'between_trivial', 'all_coplanar', 'Par_strict'}
# {'col_permutation_5', 'Par', 'col_permutation_1', 'Par_strict'}
# Ch12_parallel/par_right_comm
# {'Par', 'col_trivial_3', 'Col', 'between_symmetry', 'between_trivial', 'all_coplanar', 'Par_strict'}
# {'par_symmetry', 'par_left_comm'}
# Ch12_parallel/par_strict_symmetry
# {'Col', 'all_coplanar', 'Par_strict'}
# {'col_permutation_4', 'Par_strict'}
# Ch07_midpoint/l7_25
# {'Midpoint', 'midpoint_existence'}
# {'point_construction_different', 'col_permutation_3', 'Cong_3', 'l4_17', 'l7_20', 'l4_5', 'col_transitivity_1', 'l6_21', 'col_permutation_4', 'five_segment_with_def', 'cong_reverse_identity', 'Midpoint', 'OFSC', 'cong_symmetry', 'l4_13', 'IFSC', 'between_exchange3', 'between_identity', 'l5_2', 'segment_construction', 'cong_left_commutativity', 'between_trivial', 'between_symmetry', 'inner_pasch', 'cong_commutativity', 'outer_transitivity_between2', 'bet_col', 'Col', 'l4_2', 'cong_pseudo_reflexivity', 'cong_identity', 'l7_3_2', 'eq_dec_points'}
# Ch10_line_reflexivity_2D/image_gen_preserves_ncol
# {'image_preserves_col', 'is_image_is_image_spec', 'l10_4_spec'}
# {'image_gen_preserves_col', 'l10_4'}
# Ch13_3_angles/ang_distincts
# {'CongA', 'Q_CongA'}
# {'ex_lg', 'ang_not_null_lg', 'ang_sym', 'Q_Cong_Null'}
# Ch13_3_angles/ang_distinct
# {'CongA', 'Q_CongA'}
# {'is_ang_distinct'}
# Ch08_orthogonality/l8_22_bis
# {'l8_3', 'l8_2', 'col_trivial_3', 'l8_7', 'l12_9', 'perp_per_1', 'perp_left_comm'}
# {'perp_comm', 'perp_per_1', 'l8_22', 'perp_right_comm'}
# Ch11_angles/acute_distincts
# {'Acute', 'LtA', 'LeA', 'conga_distinct'}
# {'lta_distincts'}
# Ch02_cong/not_cong_2143
# {'cong_commutativity'}
# {'cong_symmetry', 'cong_4321'}
# Ch05_bet_le/le_diff
# {'Le', 'cong_identity', 'between_identity'}
# {'le_zero'}
# Ch09_plane/diff_col_ex3
# {'point_construction_different', 'between_trivial2', 'diff_col_ex', 'outer_transitivity_between', 'Col', 'between_symmetry', 'between_trivial', 'between_equality'}
# {'col_permutation_5', 'diff_col_ex', 'col_permutation_2', 'Col', 'between_symmetry', 'col_transitivity_1', 'diff_bet_ex3', 'col_permutation_4', 'eq_dec_points'}
# Ch12_parallel/par_strict_left_comm
# {'Col', 'between_symmetry', 'all_coplanar', 'Par_strict'}
# {'col_permutation_5', 'col_permutation_1', 'Par_strict'}
# Ch12_parallel/par_strict_comm
# {'Col', 'between_symmetry', 'all_coplanar', 'Par_strict'}
# {'par_strict_left_comm', 'par_strict_right_comm'}
# Ch12_parallel/par_strict_right_comm
# {'Col', 'between_symmetry', 'all_coplanar', 'Par_strict'}
# {'col_permutation_5', 'col_permutation_1', 'Par_strict'}
# Ch02_cong/not_cong_1243
# {'cong_symmetry', 'cong_3421'}
# {'cong_symmetry', 'cong_4312'}
# Ch02_cong/not_cong_4312
# {'cong_3421'}
# {'cong_symmetry', 'cong_left_commutativity'}
# Ch02_cong/not_cong_3421
# {'cong_3421'}
# {'cong_right_commutativity', 'cong_symmetry'}
# 331

# %%
def display_data(datas) :
    seuil=[]
    done=[]
    notdone=[]
    gaveup=[]
    ressourceout=[]
    timeout=[]
    for i in range(len(datas)) :
        seuil.append(datas[i][0])
        done.append(len(list(itertools.chain.from_iterable([data[1] for data in datas[:(i+1)]]))))
        notdone.append(len(datas[i][2]))
        gaveup.append(len(datas[i][3]))
        ressourceout.append(len(datas[i][4]))
        timeout.append(len(datas[i][5]))
    x=seuil
    y1=done
    y2=notdone
    y3=gaveup
    y4=ressourceout
    y5=timeout
    plt.plot(x,y1,linewidth=2.0,label = "done")
    plt.xlim(x[0]+0.01,x[-1]-0.01)
    plt.legend()
    print(done[len(done)-1],"/",(done[len(done)-1]+notdone[len(notdone)-1]))
    print(datas[len(datas)-1][2])
    return list(itertools.chain.from_iterable([data[1] for data in datas[:(i+1)]]))

# %%
done=display_data(b)
# Out:
# 646 / 1237
# ['l4_16', 'l4_19', 'l4_14', 'l4_2', 'l4_6', 'l4_5', 'between_cong', 'l5_5_2', 'l5_2', 'l5_6', 'l5_3', 'l5_1', 'cong2_lt__lt', 'fourth_point', 'bet__lt1213', 'le_anti_symmetry', 'bet__lt2313', 'l5_12_b', 'le1234_lt__lt', 'nlt__le', 'le3456_lt__lt', 'bet_le_eq', 'not_and_lt', 'nle__lt', 'lt1123', 'bet2_le2__le', 'l6_21', 'out2_bet_out', 'l6_13_1', 'bet2_le2__le1346', 'bet2_le2__le2356', 'bet2_le2__le1245', 'out_cong_cong', 'col_out2_col', 'bet2_out_out', 'l7_9', 'l7_17', 'l7_13', 'l7_20', 'cong_col_mid', 'l7_21', 'l7_22_aux', 'l7_22', 'bet_col1', 'cong_cong_half_1', 'mid__lt', 'lt_mid2__lt12', 'col_cong2_bet4', 'le_mid2__le13', 'lt_mid2__lt13', 'bet2_lt_le__lt', 'l8_7', 'l8_10', 'l8_12', 'per_col', 'l8_13_2', 'l8_14_2_1b_bis', 'l8_15_1', 'l8_15_2', 'perp_in_per', 'perp_col0', 'l8_16_1', 'per_perp_in', 'perp_in_sym', 'l8_18_uniqueness', 'Perp_in_perm', 'l8_20_1', 'perp_col1', 'l8_21_aux', 'l8_18_existence', 'perp_perp_in', 'perp_col', 'perp_col2', 'per_cong', 'perp_cong', 'midpoint_existence', 'perp_in_id', 'l8_22_bis', 'l8_24', 'l8_22', 'perp_in_col_perp_in', 'perp_col2_bis', 'perp_in_perp_bis', 'col_per_perp', 'per_cong_mid', 'col_per2_cases', 'l9_3', 'per_mid_per', 'l9_4_1', 'l9_4_1_aux', 'col_preserves_two_sides', 'out_out_two_sides', 'l9_4_2', 'l9_5', 'l9_4_2_aux', 'outer_pasch', 'not_two_sides_id', 'l9_9', 'l9_8_2', 'one_side_reflexivity', 'one_side_chara', 'l9_17', 'l9_18', 'l9_19', 'col_two_sides', 'col_one_side', 'out_out_one_side', 'l9_31', 'bet_ts__ts', 'col2_os__os', 'ts_ts_os', 'os_out_os', 'col_one_side_out', 'os_ts1324__os', 'ts2__ex_bet2', 'ts2__inangle', 'TS__ncol', 'out_one_side_1', 'per_per_col', 'all_coplanar', 'image_in_col', 'perp_perp_col', 'l10_10_spec', 'l10_10', 'image_gen_preserves_inter', 'intersection_with_image_gen', 'image_preserves_per', 'image_preserves_bet', 'l10_12', 'l10_16', 'image_cong_col', 'ex_sym', 'ex_sym1', 'l10_2_uniqueness', 'l10_2_uniqueness_spec', 'l10_6_uniqueness_spec', 'l10_2_existence_spec', 'l10_6_existence_spec', 'l10_6_existence', 'l10_7', 'is_image_col_cong', 'is_image_spec_col_cong', 'midpoint_preserves_image', 'image_id', 'image_image_in', 'image_in_gen_is_image', 'l10_14', 'l10_15', 'perp_exists', 'ex_per_cong', 'l11_aux', 'l11_3', 'l11_3_bis', 'l11_4_1', 'l11_4_2', 'cong3_conga', 'out_conga', 'conga_trans', 'conga_pseudo_refl', 'cong3_conga2', 'conga_trivial_1', 'out2__conga', 'l11_13', 'conga_right_comm', 'conga_line', 'l11_14', 'l11_16', 'l11_18_2', 'l11_17', 'l11_21_a', 'l11_21_b', 'conga__or_out_ts', 'cong2_conga_cong', 'angle_construction_2', 'ex_conga_ts', 'l11_19', 'l11_15', 'l11_22_bet', 'l11_22a', 'l11_22', 'l11_22b', 'in_angle_out', 'l11_25', 'l11_25_aux', 'out_in_angle_out', 'l11_28', 'in_angle_one_side', 'bet_conga_bet', 'inangle_one_side', 'l11_29_a', 'l11_29_b', 'eq_conga_out', 'col_conga_col', 'out_conga_out', 'conga_preserves_in_angle', 'lea_refl', 'l11_31_2', 'l11_30', 'lea121345', 'inangle__lea', 'in_angle_asym', 'lea_trans', 'in_angle_trans', 'lea_asym', 'col_perp_perp_col', 'not_two_sides_one_side', 'in_angle_reverse', 'in_angle_trans2', 'l11_41_aux', 'l11_41', 'conga_preserves_lta', 'conga_preserves_gta', 'lta_trans', 'l11_43_aux', 'lea_comm', 'acute_lea_acute', 'l11_43', 'lea_acute_obtuse', 'obtuse_gea_obtuse', 'l11_44_1_a', 'l11_44_2_a', 'l11_44_2_b', 'l11_46', 'l11_47', 'l11_49', 'l11_50_1', 'l11_50_2', 'l11_52', 'l11_53', 'per2_cong2__cong_conga2', 'hilbert_s_version_of_pasch_aux', 'per2_cong2__cong_3', 'not_one_side_two_sides', 'two_sides_cases', 'one_or_two_sides', 'not_par_two_sides', 'not_par_other_side', 'not_par_same_side', 'os_ts__inangle', 'out_lea__out', 'obtuse_conga__obtuse', 'bet_lea__bet', 'lea123456_lta__lta', 'lea456789_lta__lta', 'acute_per__lta', 'obtuse_per__lta', 'out__acute', 'acute_obtuse__lta', 'lea_total', 'bet__obtuse', 'lea_in_angle', 'bet_obtuse__acute', 'gea_total', 'or_lta_conga_gta', 'angle_partition', 'acute_chara', 'obtuse_chara', 'conga__acute', 'lea__nlta', 'lta__nlea', 'nlta__lea', 'nlea__lta', 'triangle_strict_in ...

# %%
v,u=0,0
for th in done :
    if th in th_valid :
        v+=1
    else :
        u+=1
print(v,u)
# Out:
# 624 22

# %%
len(list(set(done+th_valid)))
# Out:
# 754

# %%
def test_dep(dep_dir,zf_test_dir) :
    for chapter in geocoq :

        dep_path=dep_dir+chapter+"/"
        zf_path=zf_test_dir+chapter+"/"

        for lemme_name in geocoq[chapter] :

            ensure_dir(zf_path+lemme_name+".zf")
            

            dep_file=open(dep_path+lemme_name+".dep","r")

            for line in dep_file.readlines() :
                if line.startswith("lemme :") :
                    inter_lemmes = line.split()[2:]
                if line.startswith("rewrite :") :
                    rewrites = line.split()[2:]

            dep_file.close()
            
            
            zf_file=open(zf_path+lemme_name+".zf","w+")
            
            zf_file.write("include \"../tarski_term_def.zf\".\n")
            for dep in inter_lemmes :
                if dep==lemme :
                    zf_file.write("#include itself\n")
                else :
                    zf_file.write("#"+dep+"\n")
                    zf_file.write(ax_th_declaration[dep])
                    
            for dep in rewrites :
                if dep in zf_cant_handle_commat :
                    dep=dep.replace('\'','')
                zf_file.write(rewrite_declaration[dep])

            zf_file.write("goal "+th_declaration_to_text(ax_th_declaration[lemme_name]))
            zf_file.close()

# %%
test_dep("./dependencies_v2/","./test_dep_zf/")
